# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r'F:\MV\Dataset\HAM1000\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6], dtype=int64)

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense

# Define the depthwise separable CNN model
def depthwise_resnet(input_shape, num_classes):
    model = Sequential()

    # Depthwise separable convolution block 1
    model.add(DepthwiseConv2D(3, padding='same', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Conv2D(64, (1, 1)))
    model.add(BatchNormalization())
    model.add(ReLU())

    # Depthwise separable convolution block 2
    model.add(DepthwiseConv2D(3, strides=(2, 2), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Conv2D(128, (1, 1)))
    model.add(BatchNormalization())
    model.add(ReLU())

    # Depthwise separable convolution block 3
    model.add(DepthwiseConv2D(3, strides=(2, 2), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Conv2D(256, (1, 1)))
    model.add(BatchNormalization())
    model.add(ReLU())

    # Global average pooling and dense layers
    model.add(GlobalAveragePooling2D())
    model.add(Dense(num_classes, activation='softmax'))

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the depthwise separable CNN model
model = depthwise_resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  depthwise_conv2d (Depthwise  (None, 28, 28, 3)        30
#  Conv2D)
#
#  batch_normalization (BatchN  (None, 28, 28, 3)        12
#  ormalization)
#
#  re_lu (ReLU)                (None, 28, 28, 3)         0
#
#  conv2d (Conv2D)             (None, 28, 28, 64)        256
#
#  batch_normalization_1 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 28, 28, 64)        0
#
#  depthwise_conv2d_1 (Depthwi  (None, 14, 14, 64)       640
#  seConv2D)
#
#  batch_normalization_2 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 128)       8320
#
#  batch_normalization_3 (Batc  (None, 14, 14, 128)      512
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 14, 14, 128)       0
#
#  depthwise_conv2d_2 (Depthwi  (None, 7, 7, 128)        1280
#  seConv2D)
#
#  batch_normalization_4 (Batc  (None, 7, 7, 128)        512
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 7, 7, 128)         0
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 256)         33024
#
#  batch_normalization_5 (Batc  (None, 7, 7, 256)        1024
#  hNormalization)
#
#  re_lu_5 (ReLU)              (None, 7, 7, 256)         0
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                 1799
#
# =================================================================
# Total params: 47,921
# Trainable params: 46,635
# Non-trainable params: 1,286
# _________________________________________________________________

# %%
history = model.fit(X_train ,
                    y_train ,
                    epochs=50 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/50
# 276/276 [==============================] - 7s 13ms/step - loss: 1.3192 - accuracy: 0.5251 - val_loss: 2.5711 - val_accuracy: 0.1953 - lr: 0.0010
# Epoch 2/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.8460 - accuracy: 0.7104 - val_loss: 2.0208 - val_accuracy: 0.3135 - lr: 0.0010
# Epoch 3/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.6242 - accuracy: 0.7892 - val_loss: 0.6906 - val_accuracy: 0.7556 - lr: 0.0010
# Epoch 4/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.4960 - accuracy: 0.8344 - val_loss: 1.0694 - val_accuracy: 0.6197 - lr: 0.0010
# Epoch 5/50
# 273/276 [============================>.] - ETA: 0s - loss: 0.4237 - accuracy: 0.8594
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 276/276 [==============================] - 3s 11ms/step - loss: 0.4233 - accuracy: 0.8594 - val_loss: 0.6325 - val_accuracy: 0.7443 - lr: 0.0010
# Epoch 6/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.3330 - accuracy: 0.8946 - val_loss: 0.4602 - val_accuracy: 0.8360 - lr: 5.0000e-04
# Epoch 7/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.3037 - accuracy: 0.9026 - val_loss: 0.4577 - val_accuracy: 0.8319 - lr: 5.0000e-04
# Epoch 8/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.2837 - accuracy: 0.9120 - val_loss: 0.2981 - val_accuracy: 0.9075 - lr: 5.0000e-04
# Epoch 9/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.2693 - accuracy: 0.9153 - val_loss: 0.3704 - val_accuracy: 0.8802 - lr: 5.0000e-04
# Epoch 10/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.2525 - accuracy: 0.9213 - val_loss: 0.2984 - val_accuracy: 0.9133 - lr: 5.0000e-04
# Epoch 11/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.2321 - accuracy: 0.9305 - val_loss: 0.3937 - val_accuracy: 0.8585 - lr: 5.0000e-04
# Epoch 12/50
# 273/276 [============================>.] - ETA: 0s - loss: 0.2253 - accuracy: 0.9315
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 276/276 [==============================] - 3s 12ms/step - loss: 0.2247 - accuracy: 0.9318 - val_loss: 0.3471 - val_accuracy: 0.8807 - lr: 5.0000e-04
# Epoch 13/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1929 - accuracy: 0.9449 - val_loss: 0.2456 - val_accuracy: 0.9219 - lr: 2.5000e-04
# Epoch 14/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1849 - accuracy: 0.9467 - val_loss: 0.2309 - val_accuracy: 0.9309 - lr: 2.5000e-04
# Epoch 15/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1794 - accuracy: 0.9495 - val_loss: 0.2247 - val_accuracy: 0.9261 - lr: 2.5000e-04
# Epoch 16/50
# 271/276 [============================>.] - ETA: 0s - loss: 0.1783 - accuracy: 0.9488
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1784 - accuracy: 0.9488 - val_loss: 0.2171 - val_accuracy: 0.9302 - lr: 2.5000e-04
# Epoch 17/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1631 - accuracy: 0.9557 - val_loss: 0.2006 - val_accuracy: 0.9408 - lr: 1.2500e-04
# Epoch 18/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1603 - accuracy: 0.9565 - val_loss: 0.1963 - val_accuracy: 0.9420 - lr: 1.2500e-04
# Epoch 19/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1567 - accuracy: 0.9576 - val_loss: 0.1925 - val_accuracy: 0.9437 - lr: 1.2500e-04
# Epoch 20/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1537 - accuracy: 0.9583 - val_loss: 0.1987 - val_accuracy: 0.9407 - lr: 1.2500e-04
# Epoch 21/50
# 271/276 [============================>.] - ETA: 0s - loss: 0.1504 - accuracy: 0.9592
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1512 - accuracy: 0.9587 - val_loss: 0.1916 - val_accuracy: 0.9437 - lr: 1.2500e-04
# Epoch 22/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1441 - accuracy: 0.9617 - val_loss: 0.1830 - val_accuracy: 0.9461 - lr: 6.2500e-05
# Epoch 23/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1428 - accuracy: 0.9624 - val_loss: 0.1836 - val_accuracy: 0.9460 - lr: 6.2500e-05
# Epoch 24/50
# 276/276 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9628
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1426 - accuracy: 0.9628 - val_loss: 0.1880 - val_accuracy: 0.9424 - lr: 6.2500e-05
# Epoch 25/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1399 - accuracy: 0.9633 - val_loss: 0.1783 - val_accuracy: 0.9473 - lr: 3.1250e-05
# Epoch 26/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1383 - accuracy: 0.9642 - val_loss: 0.1754 - val_accuracy: 0.9498 - lr: 3.1250e-05
# Epoch 27/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1368 - accuracy: 0.9650 - val_loss: 0.1757 - val_accuracy: 0.9487 - lr: 3.1250e-05
# Epoch 28/50
# 275/276 [============================>.] - ETA: 0s - loss: 0.1377 - accuracy: 0.9637
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1379 - accuracy: 0.9637 - val_loss: 0.1774 - val_accuracy: 0.9482 - lr: 3.1250e-05
# Epoch 29/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1372 - accuracy: 0.9647 - val_loss: 0.1756 - val_accuracy: 0.9492 - lr: 1.5625e-05
# Epoch 30/50
# 272/276 [============================>.] - ETA: 0s - loss: 0.1342 - accuracy: 0.9663
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1e-05.
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1346 - accuracy: 0.9661 - val_loss: 0.1747 - val_accuracy: 0.9493 - lr: 1.5625e-05
# Epoch 31/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1349 - accuracy: 0.9653 - val_loss: 0.1746 - val_accuracy: 0.9495 - lr: 1.0000e-05
# Epoch 32/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1330 - accuracy: 0.9661 - val_loss: 0.1738 - val_accuracy: 0.9495 - lr: 1.0000e-05
# Epoch 33/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1332 - accuracy: 0.9660 - val_loss: 0.1741 - val_accuracy: 0.9497 - lr: 1.0000e-05
# Epoch 34/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1347 - accuracy: 0.9661 - val_loss: 0.1739 - val_accuracy: 0.9497 - lr: 1.0000e-05
# Epoch 35/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1323 - accuracy: 0.9665 - val_loss: 0.1747 - val_accuracy: 0.9499 - lr: 1.0000e-05
# Epoch 36/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1334 - accuracy: 0.9659 - val_loss: 0.1745 - val_accuracy: 0.9494 - lr: 1.0000e-05
# Epoch 37/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1327 - accuracy: 0.9662 - val_loss: 0.1738 - val_accuracy: 0.9501 - lr: 1.0000e-05
# Epoch 38/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1333 - accuracy: 0.9663 - val_loss: 0.1735 - val_accuracy: 0.9491 - lr: 1.0000e-05
# Epoch 39/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1328 - accuracy: 0.9665 - val_loss: 0.1732 - val_accuracy: 0.9497 - lr: 1.0000e-05
# Epoch 40/50
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1333 - accuracy: 0.9659 - val_loss: 0.1733 - val_accuracy: 0.9493 - lr: 1.0000e-05
# Epoch 41/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1330 - accuracy: 0.9660 - val_loss: 0.1723 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 42/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1319 - accuracy: 0.9663 - val_loss: 0.1733 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 43/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1307 - accuracy: 0.9674 - val_loss: 0.1741 - val_accuracy: 0.9495 - lr: 1.0000e-05
# Epoch 44/50
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1318 - accuracy: 0.9662 - val_loss: 0.1727 - val_accuracy: 0.9502 - lr: 1.0000e-05
# Epoch 45/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1315 - accuracy: 0.9664 - val_loss: 0.1734 - val_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 46/50
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1318 - accuracy: 0.9660 - val_loss: 0.1716 - val_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 47/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1323 - accuracy: 0.9659 - val_loss: 0.1717 - val_accuracy: 0.9504 - lr: 1.0000e-05
# Epoch 48/50
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1309 - accuracy: 0.9667 - val_loss: 0.1722 - val_accuracy: 0.9507 - lr: 1.0000e-05
# Epoch 49/50
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1312 - accuracy: 0.9670 - val_loss: 0.1723 - val_accuracy: 0.9502 - lr: 1.0000e-05
# Epoch 50/50
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1308 - accuracy: 0.9662 - val_loss: 0.1719 - val_accuracy: 0.9511 - lr: 1.0000e-05

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 3s 3ms/step - loss: 0.1167 - accuracy: 0.9707
# 367/367 [==============================] - 1s 3ms/step - loss: 0.1719 - accuracy: 0.9511
# Train Loss:  0.11670540273189545
# Train Accuracy:  0.9706542491912842
# --------------------
# Test Loss:  0.17191392183303833
# Test Accuracy:  0.9510823488235474

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 1s 2ms/step

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#model.save('Skin Cancer.h5')
