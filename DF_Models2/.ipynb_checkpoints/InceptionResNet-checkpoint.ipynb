# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r'F:\MV\Dataset\HAM1000\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6], dtype=int64)

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Concatenate, AveragePooling2D, GlobalAveragePooling2D, Dense

def inception_resnet_block(x, scale=0.1):
    conv1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)

    conv2_1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)
    conv2_1 = Conv2D(32, (3, 3), padding='same', activation='relu')(conv2_1)

    conv3_1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)
    conv3_1 = Conv2D(32, (5, 5), padding='same', activation='relu')(conv3_1)

    inception_block = Concatenate(axis=-1)([conv1, conv2_1, conv3_1])

    # Residual connection
    scaled_block = Conv2D(int(x.shape[-1]), (1, 1), padding='same', activation='linear')(inception_block)
    scaled_block = BatchNormalization()(scaled_block)

    out = Concatenate(axis=-1)([x, scaled_block])
    out = ReLU()(out * scale)

    return out

def inception_resnet(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(input_tensor)

    # Inception-ResNet blocks
    for _ in range(3):  # You can adjust the number of blocks as needed
        x = inception_resnet_block(x)

    # Global average pooling and dense layer
    x = GlobalAveragePooling2D()(x)
    output_tensor = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=output_tensor)

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the Inception-ResNet model
model = inception_resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 28, 28, 64)   1792        ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 32)   9248        ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 32)   25632       ['conv2d_4[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 96)   0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 64)   6208        ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 28, 28, 64)  256         ['conv2d_6[0][0]']
#  alization)
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 128)  0           ['conv2d[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 28, 28, 128)  0           ['concatenate_1[0][0]']
#
#  re_lu (ReLU)                   (None, 28, 28, 128)  0           ['tf.math.multiply[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   4128        ['re_lu[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 32)   4128        ['re_lu[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   4128        ['re_lu[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 32)   9248        ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 32)   25632       ['conv2d_10[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 28, 28, 96)   0           ['conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  12416       ['concatenate_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  rmalization)
#
#  concatenate_3 (Concatenate)    (None, 28, 28, 256)  0           ['re_lu[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 28, 28, 256)  0          ['concatenate_3[0][0]']
#  )
#
#  re_lu_1 (ReLU)                 (None, 28, 28, 256)  0           ['tf.math.multiply_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 32)   8224        ['re_lu_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 32)   8224        ['re_lu_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 32)   8224        ['re_lu_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 32)   9248        ['conv2d_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 32)   25632       ['conv2d_16[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 96)   0           ['conv2d_13[0][0]',
#                                                                   'conv2d_15[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 256)  24832       ['concatenate_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 256)  1024       ['conv2d_18[0][0]']
#  rmalization)
#
#  concatenate_5 (Concatenate)    (None, 28, 28, 512)  0           ['re_lu_1[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 28, 28, 512)  0          ['concatenate_5[0][0]']
#  )
#
#  re_lu_2 (ReLU)                 (None, 28, 28, 512)  0           ['tf.math.multiply_2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['re_lu_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 7)            3591        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 198,567
# Trainable params: 197,671
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
tf.keras.backend.clear_session()

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=250 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[EarlyStopping(monitor='loss', patience=10, restore_best_weights = True)])
# Out:
# Epoch 1/250
# 276/276 [==============================] - 27s 84ms/step - loss: 1.5173 - accuracy: 0.4500 - val_loss: 2.3435 - val_accuracy: 0.2482
# Epoch 2/250
# 276/276 [==============================] - 22s 80ms/step - loss: 1.1235 - accuracy: 0.5815 - val_loss: 2.0259 - val_accuracy: 0.2990
# Epoch 3/250
# 276/276 [==============================] - 22s 81ms/step - loss: 0.9618 - accuracy: 0.6430 - val_loss: 2.3735 - val_accuracy: 0.3682
# Epoch 4/250
# 276/276 [==============================] - 22s 81ms/step - loss: 0.8377 - accuracy: 0.6925 - val_loss: 1.4775 - val_accuracy: 0.4700
# Epoch 5/250
# 276/276 [==============================] - 22s 81ms/step - loss: 0.7221 - accuracy: 0.7345 - val_loss: 1.0275 - val_accuracy: 0.6182
# Epoch 6/250
# 276/276 [==============================] - 22s 81ms/step - loss: 0.6321 - accuracy: 0.7716 - val_loss: 0.9081 - val_accuracy: 0.6404
# Epoch 7/250
# 276/276 [==============================] - 22s 81ms/step - loss: 0.5542 - accuracy: 0.7997 - val_loss: 1.0586 - val_accuracy: 0.6091
# Epoch 8/250
# 276/276 [==============================] - 22s 81ms/step - loss: 0.5105 - accuracy: 0.8177 - val_loss: 0.8532 - val_accuracy: 0.6833
# Epoch 9/250
# 276/276 [==============================] - 22s 81ms/step - loss: 0.4428 - accuracy: 0.8443 - val_loss: 0.6186 - val_accuracy: 0.7696
# Epoch 10/250
# 276/276 [==============================] - 23s 82ms/step - loss: 0.4008 - accuracy: 0.8620 - val_loss: 0.5939 - val_accuracy: 0.7774
# Epoch 11/250
# 276/276 [==============================] - 23s 82ms/step - loss: 0.3579 - accuracy: 0.8765 - val_loss: 0.5078 - val_accuracy: 0.8181
# Epoch 12/250
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3126 - accuracy: 0.8940 - val_loss: 0.6642 - val_accuracy: 0.7397
# Epoch 13/250
# 276/276 [==============================] - 23s 84ms/step - loss: 0.2781 - accuracy: 0.9079 - val_loss: 0.6325 - val_accuracy: 0.7828
# Epoch 14/250
# 276/276 [==============================] - 23s 84ms/step - loss: 0.2478 - accuracy: 0.9184 - val_loss: 0.5939 - val_accuracy: 0.7959
# Epoch 15/250
# 276/276 [==============================] - 23s 84ms/step - loss: 0.2228 - accuracy: 0.9276 - val_loss: 1.4744 - val_accuracy: 0.5753
# Epoch 16/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.2470 - accuracy: 0.9181 - val_loss: 0.3524 - val_accuracy: 0.8729
# Epoch 17/250
# 276/276 [==============================] - 24s 85ms/step - loss: 0.1747 - accuracy: 0.9460 - val_loss: 0.3220 - val_accuracy: 0.8900
# Epoch 18/250
# 276/276 [==============================] - 24s 85ms/step - loss: 0.1754 - accuracy: 0.9440 - val_loss: 2.9529 - val_accuracy: 0.4753
# Epoch 19/250
# 276/276 [==============================] - 24s 85ms/step - loss: 0.2458 - accuracy: 0.9191 - val_loss: 0.8308 - val_accuracy: 0.7062
# Epoch 20/250
# 276/276 [==============================] - 24s 86ms/step - loss: 0.1676 - accuracy: 0.9465 - val_loss: 0.3376 - val_accuracy: 0.8728
# Epoch 21/250
# 276/276 [==============================] - 24s 86ms/step - loss: 0.1272 - accuracy: 0.9622 - val_loss: 0.3909 - val_accuracy: 0.8672
# Epoch 22/250
# 276/276 [==============================] - 24s 86ms/step - loss: 0.1183 - accuracy: 0.9656 - val_loss: 1.0477 - val_accuracy: 0.7124
# Epoch 23/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.1224 - accuracy: 0.9625 - val_loss: 0.5765 - val_accuracy: 0.8069
# Epoch 24/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.1514 - accuracy: 0.9511 - val_loss: 1.0505 - val_accuracy: 0.6554
# Epoch 25/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.1066 - accuracy: 0.9681 - val_loss: 0.3306 - val_accuracy: 0.8699
# Epoch 26/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.0774 - accuracy: 0.9784 - val_loss: 0.5884 - val_accuracy: 0.8169
# Epoch 27/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.1001 - accuracy: 0.9701 - val_loss: 0.2778 - val_accuracy: 0.8993
# Epoch 28/250
# 276/276 [==============================] - 24s 85ms/step - loss: 0.0815 - accuracy: 0.9753 - val_loss: 0.4200 - val_accuracy: 0.8399
# Epoch 29/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.0707 - accuracy: 0.9802 - val_loss: 0.5088 - val_accuracy: 0.8486
# Epoch 30/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.0968 - accuracy: 0.9707 - val_loss: 0.4117 - val_accuracy: 0.8586
# Epoch 31/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.1001 - accuracy: 0.9688 - val_loss: 0.4500 - val_accuracy: 0.8488
# Epoch 32/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.0903 - accuracy: 0.9730 - val_loss: 0.1415 - val_accuracy: 0.9524
# Epoch 33/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.0709 - accuracy: 0.9795 - val_loss: 0.6024 - val_accuracy: 0.8052
# Epoch 34/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.1035 - accuracy: 0.9666 - val_loss: 0.1201 - val_accuracy: 0.9646
# Epoch 35/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.0606 - accuracy: 0.9832 - val_loss: 3.3091 - val_accuracy: 0.4734
# Epoch 36/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.1422 - accuracy: 0.9571 - val_loss: 0.3355 - val_accuracy: 0.8884
# Epoch 37/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.0556 - accuracy: 0.9851 - val_loss: 0.0910 - val_accuracy: 0.9749
# Epoch 38/250
# 276/276 [==============================] - 23s 85ms/step - loss: 0.0294 - accuracy: 0.9930 - val_loss: 0.1668 - val_accuracy: 0.9482
# Epoch 39/250
# 276/276 [==============================] - 24s 85ms/step - loss: 0.0471 - accuracy: 0.9877 - val_loss: 1.1021 - val_accuracy: 0.6962
# Epoch 40/250
# 276/276 [==============================] - 24s 86ms/step - loss: 0.1439 - accuracy: 0.9533 - val_loss: 0.2383 - val_accuracy: 0.9159
# Epoch 41/250
# 276/276 [==============================] - 24s 87ms/step - loss: 0.0501 - accuracy: 0.9858 - val_loss: 0.2202 - val_accuracy: 0.9343
# Epoch 42/250
# 276/276 [==============================] - 24s 87ms/step - loss: 0.0542 - accuracy: 0.9845 - val_loss: 2.9584 - val_accuracy: 0.5565
# Epoch 43/250
# 276/276 [==============================] - 24s 87ms/step - loss: 0.1355 - accuracy: 0.9580 - val_loss: 0.1334 - val_accuracy: 0.9636
# Epoch 44/250
# 276/276 [==============================] - 24s 87ms/step - loss: 0.0341 - accuracy: 0.9917 - val_loss: 0.1923 - val_accuracy: 0.9391
# Epoch 45/250
# 276/276 [==============================] - 24s 87ms/step - loss: 0.0380 - accuracy: 0.9905 - val_loss: 0.1738 - val_accuracy: 0.9447
# Epoch 46/250
# 276/276 [==============================] - 24s 87ms/step - loss: 0.0636 - accuracy: 0.9806 - val_loss: 0.6016 - val_accuracy: 0.7998
# Epoch 47/250
# 276/276 [==============================] - 24s 87ms/step - loss: 0.0571 - accuracy: 0.9829 - val_loss: 0.3933 - val_accuracy: 0.8770
# Epoch 48/250
# 276/276 [==============================] - 24s 87ms/step - loss: 0.0447 - accuracy: 0.9869 - val_loss: 0.9406 - val_accuracy: 0.7290

# %%
import tensorflow as tf
model.save_weights('weights\InceptionResNet.h5')

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    s
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 9s 9ms/step - loss: 0.1052 - accuracy: 0.9663
# 367/367 [==============================] - 3s 9ms/step - loss: 0.1668 - accuracy: 0.9482
# Train Loss:  0.10517501831054688
# Train Accuracy:  0.9662509560585022
# --------------------
# Test Loss:  0.16679419577121735
# Test Accuracy:  0.9481847882270813

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 3s 7ms/step

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#model.save('Skin Cancer.h5')

# %%
from keras import backend as K
import gc

del model

K.clear_session()
gc.collect()
# Out:
# 19106

# %%
#You need to install numba using 'pip install numba'

from numba import cuda

cuda.select_device(0)
cuda.close()
