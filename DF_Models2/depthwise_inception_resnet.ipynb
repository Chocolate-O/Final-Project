# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r'F:\MV\Dataset\HAM1000\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6], dtype=int64)

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Concatenate, Conv2D, MaxPooling2D, AveragePooling2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense, Add

def depthwise_inception_resnet(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Inception-ResNet module
    def inception_resnet_block(x, scale=1.0):
        conv1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)

        conv2_1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)
        conv2_1 = DepthwiseConv2D(3, padding='same', activation='relu')(conv2_1)

        conv2_2 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)
        conv2_2 = DepthwiseConv2D(5, padding='same', activation='relu')(conv2_2)

        inception_block = Concatenate(axis=-1)([conv1, conv2_1, conv2_2])

        # Residual connection
        scaled_block = Conv2D(int(x.shape[-1]), (1, 1), padding='same', activation='linear')(inception_block)
        scaled_block = BatchNormalization()(scaled_block)

        out = Add()([x, scaled_block])
        out = ReLU()(out * scale)

        return out

    # Initial convolution
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(input_tensor)

    # Depthwise Inception-ResNet blocks
    x = inception_resnet_block(x)
    x = inception_resnet_block(x)
    x = inception_resnet_block(x)

    # Global average pooling and dense layers
    x = GlobalAveragePooling2D()(x)
    output_tensor = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=output_tensor)

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the InceptionNet model
model = depthwise_inception_resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 28, 28, 64)   1792        ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 28, 28, 32)  320         ['conv2d_2[0][0]']
#  v2D)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 28, 28, 32)  832         ['conv2d_3[0][0]']
#  onv2D)
#
#  concatenate (Concatenate)      (None, 28, 28, 96)   0           ['conv2d_1[0][0]',
#                                                                   'depthwise_conv2d[0][0]',
#                                                                   'depthwise_conv2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 64)   6208        ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 28, 28, 64)  256         ['conv2d_4[0][0]']
#  alization)
#
#  add (Add)                      (None, 28, 28, 64)   0           ['conv2d[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 28, 28, 64)   0           ['add[0][0]']
#
#  re_lu (ReLU)                   (None, 28, 28, 64)   0           ['tf.math.multiply[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 32)   2080        ['re_lu[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   2080        ['re_lu[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 32)   2080        ['re_lu[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 28, 28, 32)  320         ['conv2d_6[0][0]']
#  onv2D)
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 28, 28, 32)  832         ['conv2d_7[0][0]']
#  onv2D)
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 96)   0           ['conv2d_5[0][0]',
#                                                                   'depthwise_conv2d_2[0][0]',
#                                                                   'depthwise_conv2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 64)   6208        ['concatenate_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 64)   0           ['re_lu[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 28, 28, 64)  0           ['add_1[0][0]']
#  )
#
#  re_lu_1 (ReLU)                 (None, 28, 28, 64)   0           ['tf.math.multiply_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 32)   2080        ['re_lu_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 32)   2080        ['re_lu_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 32)   2080        ['re_lu_1[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 28, 28, 32)  320         ['conv2d_10[0][0]']
#  onv2D)
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 28, 28, 32)  832         ['conv2d_11[0][0]']
#  onv2D)
#
#  concatenate_2 (Concatenate)    (None, 28, 28, 96)   0           ['conv2d_9[0][0]',
#                                                                   'depthwise_conv2d_4[0][0]',
#                                                                   'depthwise_conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 64)   6208        ['concatenate_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_12[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 28, 28, 64)   0           ['re_lu_1[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 28, 28, 64)  0           ['add_2[0][0]']
#  )
#
#  re_lu_2 (ReLU)                 (None, 28, 28, 64)   0           ['tf.math.multiply_2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['re_lu_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 7)            455         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 43,815
# Trainable params: 43,431
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=300 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[EarlyStopping(monitor='loss', patience=10, restore_best_weights = True)])
# Out:
# Epoch 1/300
# 276/276 [==============================] - 17s 44ms/step - loss: 3.7660 - accuracy: 0.3214 - val_loss: 5.3220 - val_accuracy: 0.1665
# Epoch 2/300
# 276/276 [==============================] - 12s 42ms/step - loss: 1.6019 - accuracy: 0.4544 - val_loss: 5.6221 - val_accuracy: 0.2192
# Epoch 3/300
# 276/276 [==============================] - 12s 42ms/step - loss: 1.5972 - accuracy: 0.4990 - val_loss: 6.0716 - val_accuracy: 0.2035
# Epoch 4/300
# 276/276 [==============================] - 12s 44ms/step - loss: 1.3799 - accuracy: 0.5245 - val_loss: 6.8539 - val_accuracy: 0.2245
# Epoch 5/300
# 276/276 [==============================] - 12s 42ms/step - loss: 1.3300 - accuracy: 0.5545 - val_loss: 3.1891 - val_accuracy: 0.3612
# Epoch 6/300
# 276/276 [==============================] - 11s 42ms/step - loss: 1.2453 - accuracy: 0.5794 - val_loss: 2.4321 - val_accuracy: 0.3667
# Epoch 7/300
# 276/276 [==============================] - 12s 42ms/step - loss: 1.0668 - accuracy: 0.6193 - val_loss: 4.9663 - val_accuracy: 0.2025
# Epoch 8/300
# 276/276 [==============================] - 11s 42ms/step - loss: 1.0773 - accuracy: 0.6313 - val_loss: 4.0120 - val_accuracy: 0.2950
# Epoch 9/300
# 276/276 [==============================] - 11s 42ms/step - loss: 1.0522 - accuracy: 0.6446 - val_loss: 4.3574 - val_accuracy: 0.3202
# Epoch 10/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.8275 - accuracy: 0.6957 - val_loss: 3.2971 - val_accuracy: 0.3541
# Epoch 11/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.8471 - accuracy: 0.6896 - val_loss: 1.9257 - val_accuracy: 0.4949
# Epoch 12/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.8503 - accuracy: 0.7061 - val_loss: 4.0081 - val_accuracy: 0.2684
# Epoch 13/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.9864 - accuracy: 0.6871 - val_loss: 1.2621 - val_accuracy: 0.6166
# Epoch 14/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7159 - accuracy: 0.7370 - val_loss: 3.6246 - val_accuracy: 0.3660
# Epoch 15/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7909 - accuracy: 0.7325 - val_loss: 1.1585 - val_accuracy: 0.6061
# Epoch 16/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.6489 - accuracy: 0.7650 - val_loss: 1.8863 - val_accuracy: 0.5126
# Epoch 17/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.6546 - accuracy: 0.7703 - val_loss: 1.7440 - val_accuracy: 0.5581
# Epoch 18/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.6218 - accuracy: 0.7798 - val_loss: 1.5193 - val_accuracy: 0.4749
# Epoch 19/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.5177 - accuracy: 0.8119 - val_loss: 1.2640 - val_accuracy: 0.6104
# Epoch 20/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.5396 - accuracy: 0.8106 - val_loss: 1.7092 - val_accuracy: 0.5578
# Epoch 21/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.5255 - accuracy: 0.8171 - val_loss: 2.5199 - val_accuracy: 0.3957
# Epoch 22/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.4877 - accuracy: 0.8296 - val_loss: 1.8190 - val_accuracy: 0.5620
# Epoch 23/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.5028 - accuracy: 0.8267 - val_loss: 1.1683 - val_accuracy: 0.6211
# Epoch 24/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.3904 - accuracy: 0.8640 - val_loss: 2.0781 - val_accuracy: 0.5117
# Epoch 25/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.4726 - accuracy: 0.8372 - val_loss: 1.6628 - val_accuracy: 0.5237
# Epoch 26/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.4421 - accuracy: 0.8493 - val_loss: 2.0195 - val_accuracy: 0.5068
# Epoch 27/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.5192 - accuracy: 0.8273 - val_loss: 0.9473 - val_accuracy: 0.7073
# Epoch 28/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.3806 - accuracy: 0.8708 - val_loss: 2.0208 - val_accuracy: 0.4593
# Epoch 29/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.3138 - accuracy: 0.8948 - val_loss: 7.1131 - val_accuracy: 0.2634
# Epoch 30/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.8914 - accuracy: 0.7038 - val_loss: 0.9043 - val_accuracy: 0.6629
# Epoch 31/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.4439 - accuracy: 0.8432 - val_loss: 4.2220 - val_accuracy: 0.3729
# Epoch 32/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.4343 - accuracy: 0.8497 - val_loss: 1.1360 - val_accuracy: 0.6524
# Epoch 33/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.3505 - accuracy: 0.8807 - val_loss: 0.8079 - val_accuracy: 0.7386
# Epoch 34/300
# 276/276 [==============================] - 12s 43ms/step - loss: 0.3107 - accuracy: 0.8922 - val_loss: 1.3069 - val_accuracy: 0.6505
# Epoch 35/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.2983 - accuracy: 0.8987 - val_loss: 4.4542 - val_accuracy: 0.3853
# Epoch 36/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.3484 - accuracy: 0.8823 - val_loss: 0.4160 - val_accuracy: 0.8469
# Epoch 37/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.2449 - accuracy: 0.9189 - val_loss: 0.4738 - val_accuracy: 0.8173
# Epoch 38/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.2370 - accuracy: 0.9220 - val_loss: 0.5468 - val_accuracy: 0.8025
# Epoch 39/300
# 276/276 [==============================] - 13s 45ms/step - loss: 0.2168 - accuracy: 0.9293 - val_loss: 8.5528 - val_accuracy: 0.2744
# Epoch 40/300
# 276/276 [==============================] - 13s 47ms/step - loss: 0.3730 - accuracy: 0.8801 - val_loss: 2.4761 - val_accuracy: 0.4128
# Epoch 41/300
# 276/276 [==============================] - 13s 48ms/step - loss: 0.2132 - accuracy: 0.9289 - val_loss: 0.6024 - val_accuracy: 0.7821
# Epoch 42/300
# 276/276 [==============================] - 13s 45ms/step - loss: 0.2021 - accuracy: 0.9349 - val_loss: 0.2046 - val_accuracy: 0.9323
# Epoch 43/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.1661 - accuracy: 0.9474 - val_loss: 5.5835 - val_accuracy: 0.2862
# Epoch 44/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.2649 - accuracy: 0.9123 - val_loss: 1.2057 - val_accuracy: 0.6768
# Epoch 45/300
# 276/276 [==============================] - 13s 45ms/step - loss: 0.2087 - accuracy: 0.9307 - val_loss: 0.5568 - val_accuracy: 0.8008
# Epoch 46/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.1586 - accuracy: 0.9488 - val_loss: 0.3686 - val_accuracy: 0.8548
# Epoch 47/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.1551 - accuracy: 0.9499 - val_loss: 1.6517 - val_accuracy: 0.5549
# Epoch 48/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.2305 - accuracy: 0.9253 - val_loss: 5.9755 - val_accuracy: 0.2898
# Epoch 49/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.2190 - accuracy: 0.9297 - val_loss: 1.0855 - val_accuracy: 0.6993
# Epoch 50/300
# 276/276 [==============================] - 14s 49ms/step - loss: 0.1469 - accuracy: 0.9532 - val_loss: 3.4619 - val_accuracy: 0.4256
# Epoch 51/300
# 276/276 [==============================] - 14s 50ms/step - loss: 0.1881 - accuracy: 0.9436 - val_loss: 0.6316 - val_accuracy: 0.8099
# Epoch 52/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.1784 - accuracy: 0.9411 - val_loss: 4.1828 - val_accuracy: 0.3947
# Epoch 53/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.1823 - accuracy: 0.9414 - val_loss: 0.4049 - val_accuracy: 0.8622
# Epoch 54/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.1385 - accuracy: 0.9561 - val_loss: 0.7065 - val_accuracy: 0.7909
# Epoch 55/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.1368 - accuracy: 0.9583 - val_loss: 1.4175 - val_accuracy: 0.6024
# Epoch 56/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.1228 - accuracy: 0.9626 - val_loss: 0.2055 - val_accuracy: 0.9306
# Epoch 57/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.1275 - accuracy: 0.9596 - val_loss: 0.5989 - val_accuracy: 0.8094
# Epoch 58/300
# 276/276 [==============================] - 13s 47ms/step - loss: 0.1344 - accuracy: 0.9574 - val_loss: 4.9727 - val_accuracy: 0.3696
# Epoch 59/300
# 276/276 [==============================] - 14s 50ms/step - loss: 0.1584 - accuracy: 0.9512 - val_loss: 0.6272 - val_accuracy: 0.8041
# Epoch 60/300
# 276/276 [==============================] - 14s 50ms/step - loss: 0.1069 - accuracy: 0.9678 - val_loss: 0.4895 - val_accuracy: 0.8261
# Epoch 61/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.0996 - accuracy: 0.9716 - val_loss: 1.4107 - val_accuracy: 0.6325
# Epoch 62/300
# 276/276 [==============================] - 14s 50ms/step - loss: 0.1190 - accuracy: 0.9652 - val_loss: 2.1442 - val_accuracy: 0.5314
# Epoch 63/300
# 276/276 [==============================] - 14s 50ms/step - loss: 0.1104 - accuracy: 0.9668 - val_loss: 0.2497 - val_accuracy: 0.9160
# Epoch 64/300
# 276/276 [==============================] - 13s 47ms/step - loss: 0.0800 - accuracy: 0.9763 - val_loss: 0.6882 - val_accuracy: 0.7851
# Epoch 65/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.1088 - accuracy: 0.9667 - val_loss: 7.2191 - val_accuracy: 0.2869
# Epoch 66/300
# 276/276 [==============================] - 13s 48ms/step - loss: 0.1552 - accuracy: 0.9521 - val_loss: 1.8008 - val_accuracy: 0.6143
# Epoch 67/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.0906 - accuracy: 0.9732 - val_loss: 4.0948 - val_accuracy: 0.4459
# Epoch 68/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.1254 - accuracy: 0.9628 - val_loss: 0.1481 - val_accuracy: 0.9559
# Epoch 69/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.0726 - accuracy: 0.9789 - val_loss: 0.5299 - val_accuracy: 0.8277
# Epoch 70/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.0820 - accuracy: 0.9766 - val_loss: 0.3134 - val_accuracy: 0.8894
# Epoch 71/300
# 276/276 [==============================] - 13s 48ms/step - loss: 0.0717 - accuracy: 0.9795 - val_loss: 2.2542 - val_accuracy: 0.5862
# Epoch 72/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.1084 - accuracy: 0.9658 - val_loss: 3.4675 - val_accuracy: 0.4471
# Epoch 73/300
# 276/276 [==============================] - 12s 44ms/step - loss: 0.1711 - accuracy: 0.9512 - val_loss: 2.5640 - val_accuracy: 0.5346
# Epoch 74/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.0899 - accuracy: 0.9741 - val_loss: 1.1353 - val_accuracy: 0.7120
# Epoch 75/300
# 276/276 [==============================] - 13s 45ms/step - loss: 0.1639 - accuracy: 0.9535 - val_loss: 0.2486 - val_accuracy: 0.9114
# Epoch 76/300
# 276/276 [==============================] - 12s 45ms/step - loss: 0.0508 - accuracy: 0.9871 - val_loss: 0.1435 - val_accuracy: 0.9522
# Epoch 77/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.0551 - accuracy: 0.9853 - val_loss: 0.2411 - val_accuracy: 0.9160
# Epoch 78/300
# 276/276 [==============================] - 13s 47ms/step - loss: 0.0846 - accuracy: 0.9743 - val_loss: 0.0922 - val_accuracy: 0.9721
# Epoch 79/300
# 276/276 [==============================] - 14s 50ms/step - loss: 0.0377 - accuracy: 0.9912 - val_loss: 0.5190 - val_accuracy: 0.8364
# Epoch 80/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.0717 - accuracy: 0.9784 - val_loss: 0.2639 - val_accuracy: 0.9096
# Epoch 81/300
# 276/276 [==============================] - 14s 50ms/step - loss: 0.0864 - accuracy: 0.9731 - val_loss: 1.2946 - val_accuracy: 0.7094
# Epoch 82/300
# 276/276 [==============================] - 13s 49ms/step - loss: 0.0918 - accuracy: 0.9718 - val_loss: 0.9322 - val_accuracy: 0.7678
# Epoch 83/300
# 276/276 [==============================] - 13s 47ms/step - loss: 0.1014 - accuracy: 0.9691 - val_loss: 0.2299 - val_accuracy: 0.9151
# Epoch 84/300
# 276/276 [==============================] - 14s 50ms/step - loss: 0.0504 - accuracy: 0.9852 - val_loss: 0.3080 - val_accuracy: 0.8910
# Epoch 85/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.0451 - accuracy: 0.9875 - val_loss: 1.2290 - val_accuracy: 0.7091
# Epoch 86/300
# 276/276 [==============================] - 13s 45ms/step - loss: 0.1201 - accuracy: 0.9647 - val_loss: 0.1772 - val_accuracy: 0.9434
# Epoch 87/300
# 276/276 [==============================] - 13s 45ms/step - loss: 0.0460 - accuracy: 0.9873 - val_loss: 0.5245 - val_accuracy: 0.8436
# Epoch 88/300
# 276/276 [==============================] - 13s 46ms/step - loss: 0.0727 - accuracy: 0.9781 - val_loss: 0.7212 - val_accuracy: 0.7955
# Epoch 89/300
# 276/276 [==============================] - 13s 47ms/step - loss: 0.0619 - accuracy: 0.9817 - val_loss: 0.1360 - val_accuracy: 0.9611

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=2 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[EarlyStopping(monitor='loss', patience=10, restore_best_weights = True)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 from tensorflow.keras.callbacks import EarlyStopping
# ----> 2 history = model.fit(X_train ,
#       3                     y_train ,
#       4                     epochs=2 ,
#       5                     batch_size=128,
#       6                     validation_data=(X_test , y_test) ,
#       7                     callbacks=[EarlyStopping(monitor='loss', patience=10, restore_best_weights = True)])
#
# NameError: name 'model' is not defined

# %%
import tensorflow as tf
model.save_weights('weights\DepwiseInceptionResNet.h5')

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 6s 6ms/step - loss: 0.4635 - accuracy: 0.8504
# 367/367 [==============================] - 2s 6ms/step - loss: 0.5190 - accuracy: 0.8364
# Train Loss:  0.463523805141449
# Train Accuracy:  0.8504019975662231
# --------------------
# Test Loss:  0.5190087556838989
# Test Accuracy:  0.8363729119300842

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 2s 4ms/step

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#model.save('Skin Cancer.h5')

# %%
# from keras import backend as K
# import gc

# del model

# K.clear_session()
# gc.collect()
# Out:
# 19167

# %%
# #You need to install numba using 'pip install numba'

# from numba import cuda

# cuda.select_device(0)
# cuda.close()
