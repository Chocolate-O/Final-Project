# %%
#pip install imblearn

# %% [markdown]
# # Extract Dataset

# %%
# import zipfile
# import os

# # 定义压缩包路径和目标文件夹路径
# zip_file_path = 'archive.zip'
# extract_folder_path = r'archive'

# # 创建目标文件夹（如果不存在）
# os.makedirs(extract_folder_path, exist_ok=True)

# # 解压缩压缩包
# with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_folder_path)

# print(f"Successfully extracted to {extract_folder_path}")

# %% [markdown]
# # Improt library

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization,Multiply,Add
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# 2023-12-24 17:51:54.929514: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 17:51:55.124712: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# modules loaded

# %% [markdown]
# # Read CSV File

# %%
data_dir = r'archive/hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6])

# %% [markdown]
# # Set Classes

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # Data Augmentation

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Concatenate, Conv2D, MaxPooling2D, AveragePooling2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense

def depthwise_inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Inception module 1
    tower_1 = Conv2D(64, (1, 1), padding='same', activation='relu')(input_tensor)

    tower_2 = Conv2D(64, (1, 1), padding='same', activation='relu')(input_tensor)
    tower_2 = DepthwiseConv2D(3, padding='same', activation='relu')(tower_2)

    tower_3 = Conv2D(64, (1, 1), padding='same', activation='relu')(input_tensor)
    tower_3 = DepthwiseConv2D(5, padding='same', activation='relu')(tower_3)

    tower_4 = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(input_tensor)
    tower_4 = Conv2D(64, (1, 1), padding='same', activation='relu')(tower_4)

    inception_block_1 = Concatenate(axis=-1)([tower_1, tower_2, tower_3, tower_4])

    # Inception module 2
    tower_5 = Conv2D(128, (1, 1), padding='same', activation='relu')(inception_block_1)

    tower_6 = Conv2D(128, (1, 1), padding='same', activation='relu')(inception_block_1)
    tower_6 = DepthwiseConv2D(3, padding='same', activation='relu')(tower_6)

    tower_7 = Conv2D(128, (1, 1), padding='same', activation='relu')(inception_block_1)
    tower_7 = DepthwiseConv2D(5, padding='same', activation='relu')(tower_7)

    tower_8 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(inception_block_1)
    tower_8 = Conv2D(128, (1, 1), padding='same', activation='relu')(tower_8)

    inception_block_2 = Concatenate(axis=-1)([tower_5, tower_6, tower_7, tower_8])

    # Global average pooling and dense layers
    x = GlobalAveragePooling2D()(inception_block_2)
    output_tensor = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=output_tensor)

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the depthwise separable CNN model
model = depthwise_inception_net(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# 2023-12-24 17:52:04.467107: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 17:52:05.128727: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22292 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:03:00.0, compute capability: 8.6
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 3)]  0           []
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 64)   256         ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 64)   256         ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 3)    0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 28, 28, 64)   256         ['input_1[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 28, 28, 64)  640         ['conv2d_1[0][0]']
#  v2D)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 28, 28, 64)  1664        ['conv2d_2[0][0]']
#  onv2D)
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   256         ['max_pooling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 256)  0           ['conv2d[0][0]',
#                                                                   'depthwise_conv2d[0][0]',
#                                                                   'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  average_pooling2d (AveragePool  (None, 28, 28, 256)  0          ['concatenate[0][0]']
#  ing2D)
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 28, 28, 128)  1280       ['conv2d_5[0][0]']
#  onv2D)
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 28, 28, 128)  3328       ['conv2d_6[0][0]']
#  onv2D)
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 128)  32896       ['average_pooling2d[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 512)  0           ['conv2d_4[0][0]',
#                                                                   'depthwise_conv2d_2[0][0]',
#                                                                   'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['concatenate_1[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 7)            3591        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 143,111
# Trainable params: 143,111
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Data Augmentation

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %% [markdown]
# # Fit the model

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=250,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[EarlyStopping(monitor='loss', patience=10, restore_best_weights = True)])
# Out:
# Epoch 1/250
# 2023-12-24 17:52:08.861695: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
#   4/276 [..............................] - ETA: 6s - loss: 18.1224 - accuracy: 0.1504
# 2023-12-24 17:52:09.447863: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 276/276 [==============================] - 10s 27ms/step - loss: 2.6377 - accuracy: 0.3206 - val_loss: 5.4386 - val_accuracy: 0.2183
# Epoch 2/250
# 276/276 [==============================] - 7s 25ms/step - loss: 1.6273 - accuracy: 0.4154 - val_loss: 3.1166 - val_accuracy: 0.2739
# Epoch 3/250
# 276/276 [==============================] - 7s 25ms/step - loss: 1.4474 - accuracy: 0.4538 - val_loss: 3.8899 - val_accuracy: 0.2798
# Epoch 4/250
# 276/276 [==============================] - 7s 25ms/step - loss: 1.3567 - accuracy: 0.4960 - val_loss: 5.5027 - val_accuracy: 0.2004
# Epoch 5/250
# 276/276 [==============================] - 7s 25ms/step - loss: 1.3374 - accuracy: 0.5186 - val_loss: 1.1788 - val_accuracy: 0.5856
# Epoch 6/250
# 276/276 [==============================] - 7s 25ms/step - loss: 1.1613 - accuracy: 0.5525 - val_loss: 4.8285 - val_accuracy: 0.2622
# Epoch 7/250
# 276/276 [==============================] - 7s 25ms/step - loss: 1.2134 - accuracy: 0.5581 - val_loss: 2.7257 - val_accuracy: 0.3192
# Epoch 8/250
# 276/276 [==============================] - 7s 25ms/step - loss: 1.1001 - accuracy: 0.5865 - val_loss: 3.1505 - val_accuracy: 0.3010
# Epoch 9/250
# 276/276 [==============================] - 7s 25ms/step - loss: 1.1064 - accuracy: 0.5907 - val_loss: 1.7379 - val_accuracy: 0.4259
# Epoch 10/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.9960 - accuracy: 0.6237 - val_loss: 1.0038 - val_accuracy: 0.6151
# Epoch 11/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.9422 - accuracy: 0.6399 - val_loss: 1.0590 - val_accuracy: 0.5880
# Epoch 12/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.9117 - accuracy: 0.6542 - val_loss: 1.6057 - val_accuracy: 0.4779
# Epoch 13/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.8962 - accuracy: 0.6576 - val_loss: 1.7123 - val_accuracy: 0.4709
# Epoch 14/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.9200 - accuracy: 0.6628 - val_loss: 1.0374 - val_accuracy: 0.5847
# Epoch 15/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.8320 - accuracy: 0.6834 - val_loss: 0.8035 - val_accuracy: 0.6978
# Epoch 16/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.8099 - accuracy: 0.6957 - val_loss: 1.0406 - val_accuracy: 0.6050
# Epoch 17/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.8021 - accuracy: 0.7006 - val_loss: 0.7908 - val_accuracy: 0.6959
# Epoch 18/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.7561 - accuracy: 0.7165 - val_loss: 1.0080 - val_accuracy: 0.6027
# Epoch 19/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.7602 - accuracy: 0.7166 - val_loss: 0.7403 - val_accuracy: 0.7212
# Epoch 20/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.7134 - accuracy: 0.7339 - val_loss: 0.7172 - val_accuracy: 0.7269
# Epoch 21/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.7043 - accuracy: 0.7388 - val_loss: 1.3620 - val_accuracy: 0.5291
# Epoch 22/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.7088 - accuracy: 0.7373 - val_loss: 0.8831 - val_accuracy: 0.6802
# Epoch 23/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.7104 - accuracy: 0.7382 - val_loss: 0.6572 - val_accuracy: 0.7594
# Epoch 24/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.6498 - accuracy: 0.7578 - val_loss: 1.0141 - val_accuracy: 0.6038
# Epoch 25/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.6690 - accuracy: 0.7527 - val_loss: 0.6747 - val_accuracy: 0.7282
# Epoch 26/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.6154 - accuracy: 0.7706 - val_loss: 0.6492 - val_accuracy: 0.7621
# Epoch 27/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.6078 - accuracy: 0.7739 - val_loss: 0.5896 - val_accuracy: 0.7846
# Epoch 28/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.5830 - accuracy: 0.7842 - val_loss: 1.0466 - val_accuracy: 0.6237
# Epoch 29/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.6368 - accuracy: 0.7689 - val_loss: 0.5905 - val_accuracy: 0.7756
# Epoch 30/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.5611 - accuracy: 0.7924 - val_loss: 0.9886 - val_accuracy: 0.6963
# Epoch 31/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.6156 - accuracy: 0.7770 - val_loss: 0.6880 - val_accuracy: 0.7488
# Epoch 32/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.5418 - accuracy: 0.8022 - val_loss: 0.5588 - val_accuracy: 0.7955
# Epoch 33/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.5182 - accuracy: 0.8122 - val_loss: 0.6018 - val_accuracy: 0.7774
# Epoch 34/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.5112 - accuracy: 0.8126 - val_loss: 1.3585 - val_accuracy: 0.5695
# Epoch 35/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.5754 - accuracy: 0.7947 - val_loss: 0.5007 - val_accuracy: 0.8216
# Epoch 36/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4977 - accuracy: 0.8215 - val_loss: 0.5544 - val_accuracy: 0.7911
# Epoch 37/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4783 - accuracy: 0.8282 - val_loss: 0.5534 - val_accuracy: 0.7993
# Epoch 38/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4745 - accuracy: 0.8274 - val_loss: 0.5067 - val_accuracy: 0.8122
# Epoch 39/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4454 - accuracy: 0.8411 - val_loss: 0.4984 - val_accuracy: 0.8209
# Epoch 40/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4479 - accuracy: 0.8386 - val_loss: 0.4482 - val_accuracy: 0.8392
# Epoch 41/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4402 - accuracy: 0.8419 - val_loss: 0.4609 - val_accuracy: 0.8463
# Epoch 42/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4281 - accuracy: 0.8475 - val_loss: 0.4732 - val_accuracy: 0.8340
# Epoch 43/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4073 - accuracy: 0.8567 - val_loss: 3.2668 - val_accuracy: 0.4612
# Epoch 44/250
# 276/276 [==============================] - 7s 25ms/step - loss: 1.0127 - accuracy: 0.6970 - val_loss: 0.6870 - val_accuracy: 0.7305
# Epoch 45/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.5533 - accuracy: 0.8026 - val_loss: 0.5376 - val_accuracy: 0.8117
# Epoch 46/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4571 - accuracy: 0.8407 - val_loss: 0.4521 - val_accuracy: 0.8407
# Epoch 47/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4170 - accuracy: 0.8523 - val_loss: 0.4945 - val_accuracy: 0.8224
# Epoch 48/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4127 - accuracy: 0.8559 - val_loss: 0.4882 - val_accuracy: 0.8272
# Epoch 49/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4258 - accuracy: 0.8509 - val_loss: 0.4582 - val_accuracy: 0.8427
# Epoch 50/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.3773 - accuracy: 0.8696 - val_loss: 0.4485 - val_accuracy: 0.8355
# Epoch 51/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.3585 - accuracy: 0.8795 - val_loss: 0.9390 - val_accuracy: 0.7275
# Epoch 52/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4778 - accuracy: 0.8339 - val_loss: 0.4470 - val_accuracy: 0.8359
# Epoch 53/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.3565 - accuracy: 0.8773 - val_loss: 0.8120 - val_accuracy: 0.7207
# Epoch 54/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4515 - accuracy: 0.8473 - val_loss: 0.3767 - val_accuracy: 0.8736
# Epoch 55/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.3428 - accuracy: 0.8822 - val_loss: 0.3504 - val_accuracy: 0.8877
# Epoch 56/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.3215 - accuracy: 0.8894 - val_loss: 0.3362 - val_accuracy: 0.8871
# Epoch 57/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.3102 - accuracy: 0.8947 - val_loss: 0.3580 - val_accuracy: 0.8803
# Epoch 58/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.3059 - accuracy: 0.8939 - val_loss: 0.3330 - val_accuracy: 0.8890
# Epoch 59/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2990 - accuracy: 0.8984 - val_loss: 0.3740 - val_accuracy: 0.8616
# Epoch 60/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2972 - accuracy: 0.8984 - val_loss: 0.3639 - val_accuracy: 0.8700
# Epoch 61/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2830 - accuracy: 0.9046 - val_loss: 0.4318 - val_accuracy: 0.8234
# Epoch 62/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.3012 - accuracy: 0.9000 - val_loss: 0.3360 - val_accuracy: 0.8826
# Epoch 63/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2660 - accuracy: 0.9120 - val_loss: 0.3523 - val_accuracy: 0.9032
# Epoch 64/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2638 - accuracy: 0.9120 - val_loss: 0.3252 - val_accuracy: 0.8803
# Epoch 65/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2565 - accuracy: 0.9134 - val_loss: 0.2863 - val_accuracy: 0.9099
# Epoch 66/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2471 - accuracy: 0.9189 - val_loss: 0.3494 - val_accuracy: 0.8743
# Epoch 67/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2487 - accuracy: 0.9163 - val_loss: 0.5356 - val_accuracy: 0.8510
# Epoch 68/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.5634 - accuracy: 0.8249 - val_loss: 0.3668 - val_accuracy: 0.8751
# Epoch 69/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2902 - accuracy: 0.9046 - val_loss: 0.3362 - val_accuracy: 0.8872
# Epoch 70/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2545 - accuracy: 0.9168 - val_loss: 0.3171 - val_accuracy: 0.8850
# Epoch 71/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2385 - accuracy: 0.9230 - val_loss: 0.3332 - val_accuracy: 0.8799
# Epoch 72/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2304 - accuracy: 0.9247 - val_loss: 0.2629 - val_accuracy: 0.9201
# Epoch 73/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2106 - accuracy: 0.9347 - val_loss: 0.2926 - val_accuracy: 0.9146
# Epoch 74/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2190 - accuracy: 0.9291 - val_loss: 0.2466 - val_accuracy: 0.9213
# Epoch 75/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2081 - accuracy: 0.9322 - val_loss: 0.2761 - val_accuracy: 0.9066
# Epoch 76/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2043 - accuracy: 0.9342 - val_loss: 0.2784 - val_accuracy: 0.9052
# Epoch 77/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1987 - accuracy: 0.9368 - val_loss: 0.2805 - val_accuracy: 0.9087
# Epoch 78/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1983 - accuracy: 0.9363 - val_loss: 0.2899 - val_accuracy: 0.8997
# Epoch 79/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2094 - accuracy: 0.9312 - val_loss: 0.2461 - val_accuracy: 0.9144
# Epoch 80/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1765 - accuracy: 0.9434 - val_loss: 0.2069 - val_accuracy: 0.9353
# Epoch 81/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1760 - accuracy: 0.9436 - val_loss: 0.3267 - val_accuracy: 0.8939
# Epoch 82/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2100 - accuracy: 0.9292 - val_loss: 0.2734 - val_accuracy: 0.9178
# Epoch 83/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1669 - accuracy: 0.9468 - val_loss: 0.1967 - val_accuracy: 0.9409
# Epoch 84/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1656 - accuracy: 0.9465 - val_loss: 0.2856 - val_accuracy: 0.9062
# Epoch 85/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1762 - accuracy: 0.9430 - val_loss: 0.2147 - val_accuracy: 0.9380
# Epoch 86/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1509 - accuracy: 0.9526 - val_loss: 0.1756 - val_accuracy: 0.9524
# Epoch 87/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1564 - accuracy: 0.9494 - val_loss: 0.3416 - val_accuracy: 0.8725
# Epoch 88/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1492 - accuracy: 0.9529 - val_loss: 0.1929 - val_accuracy: 0.9414
# Epoch 89/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1430 - accuracy: 0.9549 - val_loss: 0.2413 - val_accuracy: 0.9130
# Epoch 90/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1563 - accuracy: 0.9503 - val_loss: 0.2029 - val_accuracy: 0.9467
# Epoch 91/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1458 - accuracy: 0.9531 - val_loss: 0.1830 - val_accuracy: 0.9432
# Epoch 92/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1302 - accuracy: 0.9592 - val_loss: 0.3197 - val_accuracy: 0.8949
# Epoch 93/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.2245 - accuracy: 0.9287 - val_loss: 1.1537 - val_accuracy: 0.7521
# Epoch 94/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.4917 - accuracy: 0.8706 - val_loss: 0.2549 - val_accuracy: 0.9188
# Epoch 95/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1610 - accuracy: 0.9487 - val_loss: 0.2204 - val_accuracy: 0.9311
# Epoch 96/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1401 - accuracy: 0.9570 - val_loss: 0.1835 - val_accuracy: 0.9483
# Epoch 97/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1305 - accuracy: 0.9592 - val_loss: 0.2581 - val_accuracy: 0.9057
# Epoch 98/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1247 - accuracy: 0.9605 - val_loss: 0.1585 - val_accuracy: 0.9576
# Epoch 99/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1240 - accuracy: 0.9607 - val_loss: 0.1596 - val_accuracy: 0.9565
# Epoch 100/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1207 - accuracy: 0.9619 - val_loss: 0.1834 - val_accuracy: 0.9474
# Epoch 101/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1118 - accuracy: 0.9654 - val_loss: 0.1651 - val_accuracy: 0.9540
# Epoch 102/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1188 - accuracy: 0.9632 - val_loss: 0.1625 - val_accuracy: 0.9550
# Epoch 103/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1156 - accuracy: 0.9645 - val_loss: 0.1601 - val_accuracy: 0.9567
# Epoch 104/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1207 - accuracy: 0.9626 - val_loss: 0.1625 - val_accuracy: 0.9572
# Epoch 105/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1242 - accuracy: 0.9607 - val_loss: 0.2427 - val_accuracy: 0.9258
# Epoch 106/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1049 - accuracy: 0.9674 - val_loss: 0.1794 - val_accuracy: 0.9532
# Epoch 107/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0984 - accuracy: 0.9697 - val_loss: 0.1699 - val_accuracy: 0.9573
# Epoch 108/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0969 - accuracy: 0.9699 - val_loss: 0.1918 - val_accuracy: 0.9467
# Epoch 109/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1075 - accuracy: 0.9665 - val_loss: 0.1647 - val_accuracy: 0.9515
# Epoch 110/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1000 - accuracy: 0.9682 - val_loss: 0.1626 - val_accuracy: 0.9505
# Epoch 111/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1001 - accuracy: 0.9689 - val_loss: 0.1940 - val_accuracy: 0.9349
# Epoch 112/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1175 - accuracy: 0.9637 - val_loss: 0.1640 - val_accuracy: 0.9562
# Epoch 113/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0988 - accuracy: 0.9683 - val_loss: 0.1683 - val_accuracy: 0.9584
# Epoch 114/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0828 - accuracy: 0.9744 - val_loss: 0.1828 - val_accuracy: 0.9474
# Epoch 115/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0863 - accuracy: 0.9746 - val_loss: 0.1476 - val_accuracy: 0.9616
# Epoch 116/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1183 - accuracy: 0.9634 - val_loss: 0.1886 - val_accuracy: 0.9529
# Epoch 117/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0852 - accuracy: 0.9754 - val_loss: 0.1501 - val_accuracy: 0.9577
# Epoch 118/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0748 - accuracy: 0.9788 - val_loss: 0.1409 - val_accuracy: 0.9636
# Epoch 119/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1009 - accuracy: 0.9675 - val_loss: 0.1529 - val_accuracy: 0.9621
# Epoch 120/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0776 - accuracy: 0.9760 - val_loss: 0.1459 - val_accuracy: 0.9634
# Epoch 121/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0714 - accuracy: 0.9791 - val_loss: 0.1447 - val_accuracy: 0.9640
# Epoch 122/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0939 - accuracy: 0.9703 - val_loss: 0.2194 - val_accuracy: 0.9341
# Epoch 123/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1718 - accuracy: 0.9494 - val_loss: 0.1956 - val_accuracy: 0.9429
# Epoch 124/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0675 - accuracy: 0.9802 - val_loss: 0.1444 - val_accuracy: 0.9583
# Epoch 125/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0726 - accuracy: 0.9786 - val_loss: 0.1322 - val_accuracy: 0.9662
# Epoch 126/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0629 - accuracy: 0.9822 - val_loss: 0.1323 - val_accuracy: 0.9645
# Epoch 127/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0624 - accuracy: 0.9820 - val_loss: 0.1220 - val_accuracy: 0.9674
# Epoch 128/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0759 - accuracy: 0.9766 - val_loss: 0.1471 - val_accuracy: 0.9596
# Epoch 129/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0717 - accuracy: 0.9787 - val_loss: 0.1333 - val_accuracy: 0.9672
# Epoch 130/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0688 - accuracy: 0.9785 - val_loss: 0.2573 - val_accuracy: 0.9197
# Epoch 131/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1266 - accuracy: 0.9606 - val_loss: 0.1351 - val_accuracy: 0.9697
# Epoch 132/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0604 - accuracy: 0.9834 - val_loss: 0.1800 - val_accuracy: 0.9504
# Epoch 133/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0559 - accuracy: 0.9839 - val_loss: 0.1290 - val_accuracy: 0.9722
# Epoch 134/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0552 - accuracy: 0.9839 - val_loss: 0.1282 - val_accuracy: 0.9701
# Epoch 135/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0710 - accuracy: 0.9779 - val_loss: 0.1615 - val_accuracy: 0.9576
# Epoch 136/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0843 - accuracy: 0.9732 - val_loss: 0.1681 - val_accuracy: 0.9581
# Epoch 137/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0618 - accuracy: 0.9811 - val_loss: 0.1220 - val_accuracy: 0.9678
# Epoch 138/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0587 - accuracy: 0.9835 - val_loss: 0.1480 - val_accuracy: 0.9674
# Epoch 139/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0747 - accuracy: 0.9759 - val_loss: 0.2715 - val_accuracy: 0.9288
# Epoch 140/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1092 - accuracy: 0.9663 - val_loss: 0.2499 - val_accuracy: 0.9434
# Epoch 141/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0692 - accuracy: 0.9804 - val_loss: 0.1439 - val_accuracy: 0.9684
# Epoch 142/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0543 - accuracy: 0.9836 - val_loss: 0.1127 - val_accuracy: 0.9714
# Epoch 143/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0412 - accuracy: 0.9886 - val_loss: 0.1247 - val_accuracy: 0.9737
# Epoch 144/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0549 - accuracy: 0.9836 - val_loss: 0.2173 - val_accuracy: 0.9540
# Epoch 145/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0711 - accuracy: 0.9782 - val_loss: 0.1551 - val_accuracy: 0.9660
# Epoch 146/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0498 - accuracy: 0.9859 - val_loss: 0.1265 - val_accuracy: 0.9714
# Epoch 147/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0469 - accuracy: 0.9868 - val_loss: 0.1130 - val_accuracy: 0.9723
# Epoch 148/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0928 - accuracy: 0.9713 - val_loss: 0.1327 - val_accuracy: 0.9716
# Epoch 149/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0759 - accuracy: 0.9779 - val_loss: 0.1594 - val_accuracy: 0.9679
# Epoch 150/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0406 - accuracy: 0.9888 - val_loss: 0.1371 - val_accuracy: 0.9689
# Epoch 151/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0458 - accuracy: 0.9868 - val_loss: 0.1094 - val_accuracy: 0.9762
# Epoch 152/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0338 - accuracy: 0.9913 - val_loss: 0.1220 - val_accuracy: 0.9748
# Epoch 153/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0742 - accuracy: 0.9773 - val_loss: 0.2206 - val_accuracy: 0.9339
# Epoch 154/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0713 - accuracy: 0.9783 - val_loss: 0.1455 - val_accuracy: 0.9682
# Epoch 155/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0349 - accuracy: 0.9913 - val_loss: 0.1490 - val_accuracy: 0.9507
# Epoch 156/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0380 - accuracy: 0.9902 - val_loss: 0.1094 - val_accuracy: 0.9786
# Epoch 157/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0353 - accuracy: 0.9906 - val_loss: 0.1273 - val_accuracy: 0.9752
# Epoch 158/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0620 - accuracy: 0.9820 - val_loss: 0.5133 - val_accuracy: 0.8768
# Epoch 159/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0764 - accuracy: 0.9780 - val_loss: 0.1341 - val_accuracy: 0.9729
# Epoch 160/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0330 - accuracy: 0.9918 - val_loss: 0.1098 - val_accuracy: 0.9766
# Epoch 161/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0609 - accuracy: 0.9821 - val_loss: 0.1907 - val_accuracy: 0.9466
# Epoch 162/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0558 - accuracy: 0.9832 - val_loss: 0.1441 - val_accuracy: 0.9679
# Epoch 163/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0402 - accuracy: 0.9891 - val_loss: 0.1106 - val_accuracy: 0.9791
# Epoch 164/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0300 - accuracy: 0.9920 - val_loss: 0.1275 - val_accuracy: 0.9746
# Epoch 165/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0287 - accuracy: 0.9923 - val_loss: 0.1715 - val_accuracy: 0.9592
# Epoch 166/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1065 - accuracy: 0.9678 - val_loss: 0.1824 - val_accuracy: 0.9585
# Epoch 167/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0669 - accuracy: 0.9824 - val_loss: 0.1297 - val_accuracy: 0.9753
# Epoch 168/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0326 - accuracy: 0.9909 - val_loss: 0.1190 - val_accuracy: 0.9753
# Epoch 169/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0289 - accuracy: 0.9923 - val_loss: 0.1216 - val_accuracy: 0.9732
# Epoch 170/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0497 - accuracy: 0.9849 - val_loss: 0.1574 - val_accuracy: 0.9576
# Epoch 171/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0963 - accuracy: 0.9704 - val_loss: 0.1355 - val_accuracy: 0.9665
# Epoch 172/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0265 - accuracy: 0.9933 - val_loss: 0.1177 - val_accuracy: 0.9778
# Epoch 173/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0210 - accuracy: 0.9949 - val_loss: 0.1257 - val_accuracy: 0.9771
# Epoch 174/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0313 - accuracy: 0.9912 - val_loss: 0.1004 - val_accuracy: 0.9805
# Epoch 175/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0215 - accuracy: 0.9946 - val_loss: 0.1015 - val_accuracy: 0.9792
# Epoch 176/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0807 - accuracy: 0.9760 - val_loss: 0.1893 - val_accuracy: 0.9539
# Epoch 177/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0309 - accuracy: 0.9918 - val_loss: 0.1082 - val_accuracy: 0.9795
# Epoch 178/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0284 - accuracy: 0.9918 - val_loss: 0.1207 - val_accuracy: 0.9766
# Epoch 179/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0252 - accuracy: 0.9935 - val_loss: 0.1297 - val_accuracy: 0.9768
# Epoch 180/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0203 - accuracy: 0.9951 - val_loss: 0.1117 - val_accuracy: 0.9798
# Epoch 181/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0908 - accuracy: 0.9728 - val_loss: 0.4079 - val_accuracy: 0.9282
# Epoch 182/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0595 - accuracy: 0.9827 - val_loss: 0.0988 - val_accuracy: 0.9816
# Epoch 183/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0178 - accuracy: 0.9957 - val_loss: 0.0990 - val_accuracy: 0.9807
# Epoch 184/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0165 - accuracy: 0.9965 - val_loss: 0.1009 - val_accuracy: 0.9821
# Epoch 185/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0211 - accuracy: 0.9945 - val_loss: 0.1626 - val_accuracy: 0.9638
# Epoch 186/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0792 - accuracy: 0.9754 - val_loss: 0.5748 - val_accuracy: 0.9010
# Epoch 187/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0618 - accuracy: 0.9827 - val_loss: 0.1094 - val_accuracy: 0.9769
# Epoch 188/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0668 - accuracy: 0.9807 - val_loss: 0.4471 - val_accuracy: 0.8935
# Epoch 189/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0426 - accuracy: 0.9881 - val_loss: 0.3426 - val_accuracy: 0.9384
# Epoch 190/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1145 - accuracy: 0.9703 - val_loss: 0.0925 - val_accuracy: 0.9803
# Epoch 191/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0165 - accuracy: 0.9964 - val_loss: 0.1039 - val_accuracy: 0.9820
# Epoch 192/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0146 - accuracy: 0.9973 - val_loss: 0.1053 - val_accuracy: 0.9801
# Epoch 193/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0131 - accuracy: 0.9976 - val_loss: 0.1059 - val_accuracy: 0.9818
# Epoch 194/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0271 - accuracy: 0.9928 - val_loss: 0.1986 - val_accuracy: 0.9605
# Epoch 195/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0294 - accuracy: 0.9915 - val_loss: 0.1480 - val_accuracy: 0.9742
# Epoch 196/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0615 - accuracy: 0.9835 - val_loss: 0.6141 - val_accuracy: 0.8700
# Epoch 197/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0493 - accuracy: 0.9861 - val_loss: 0.0978 - val_accuracy: 0.9823
# Epoch 198/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0132 - accuracy: 0.9974 - val_loss: 0.0917 - val_accuracy: 0.9809
# Epoch 199/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0123 - accuracy: 0.9975 - val_loss: 0.1193 - val_accuracy: 0.9792
# Epoch 200/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0786 - accuracy: 0.9769 - val_loss: 0.2192 - val_accuracy: 0.9366
# Epoch 201/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0363 - accuracy: 0.9891 - val_loss: 0.1002 - val_accuracy: 0.9824
# Epoch 202/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0143 - accuracy: 0.9967 - val_loss: 0.1175 - val_accuracy: 0.9791
# Epoch 203/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0107 - accuracy: 0.9983 - val_loss: 0.1018 - val_accuracy: 0.9828
# Epoch 204/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0106 - accuracy: 0.9980 - val_loss: 0.1060 - val_accuracy: 0.9832
# Epoch 205/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0364 - accuracy: 0.9899 - val_loss: 0.6942 - val_accuracy: 0.8752
# Epoch 206/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0651 - accuracy: 0.9803 - val_loss: 0.1002 - val_accuracy: 0.9820
# Epoch 207/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0134 - accuracy: 0.9973 - val_loss: 0.1015 - val_accuracy: 0.9821
# Epoch 208/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0108 - accuracy: 0.9979 - val_loss: 0.1047 - val_accuracy: 0.9823
# Epoch 209/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0111 - accuracy: 0.9978 - val_loss: 0.1091 - val_accuracy: 0.9743
# Epoch 210/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1666 - accuracy: 0.9574 - val_loss: 0.1408 - val_accuracy: 0.9665
# Epoch 211/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0252 - accuracy: 0.9932 - val_loss: 0.1263 - val_accuracy: 0.9785
# Epoch 212/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0107 - accuracy: 0.9980 - val_loss: 0.0950 - val_accuracy: 0.9834
# Epoch 213/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0095 - accuracy: 0.9985 - val_loss: 0.1082 - val_accuracy: 0.9822
# Epoch 214/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0107 - accuracy: 0.9976 - val_loss: 0.1062 - val_accuracy: 0.9818
# Epoch 215/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0308 - accuracy: 0.9910 - val_loss: 0.2560 - val_accuracy: 0.9311
# Epoch 216/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0738 - accuracy: 0.9785 - val_loss: 0.1931 - val_accuracy: 0.9666
# Epoch 217/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0278 - accuracy: 0.9923 - val_loss: 0.1044 - val_accuracy: 0.9818
# Epoch 218/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0103 - accuracy: 0.9981 - val_loss: 0.0905 - val_accuracy: 0.9850
# Epoch 219/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0085 - accuracy: 0.9983 - val_loss: 0.1085 - val_accuracy: 0.9817
# Epoch 220/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0084 - accuracy: 0.9987 - val_loss: 0.1241 - val_accuracy: 0.9646
# Epoch 221/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1480 - accuracy: 0.9591 - val_loss: 0.1271 - val_accuracy: 0.9761
# Epoch 222/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0148 - accuracy: 0.9968 - val_loss: 0.1059 - val_accuracy: 0.9829
# Epoch 223/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0083 - accuracy: 0.9989 - val_loss: 0.0934 - val_accuracy: 0.9841
# Epoch 224/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0079 - accuracy: 0.9988 - val_loss: 0.1035 - val_accuracy: 0.9828
# Epoch 225/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0071 - accuracy: 0.9991 - val_loss: 0.1064 - val_accuracy: 0.9830
# Epoch 226/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0070 - accuracy: 0.9989 - val_loss: 0.1709 - val_accuracy: 0.9587
# Epoch 227/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1572 - accuracy: 0.9562 - val_loss: 0.1130 - val_accuracy: 0.9798
# Epoch 228/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0129 - accuracy: 0.9969 - val_loss: 0.1177 - val_accuracy: 0.9789
# Epoch 229/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0104 - accuracy: 0.9978 - val_loss: 0.0963 - val_accuracy: 0.9853
# Epoch 230/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0069 - accuracy: 0.9991 - val_loss: 0.0880 - val_accuracy: 0.9860
# Epoch 231/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0076 - accuracy: 0.9988 - val_loss: 0.1236 - val_accuracy: 0.9811
# Epoch 232/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0122 - accuracy: 0.9973 - val_loss: 0.1112 - val_accuracy: 0.9807
# Epoch 233/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0872 - accuracy: 0.9732 - val_loss: 0.1668 - val_accuracy: 0.9623
# Epoch 234/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0173 - accuracy: 0.9955 - val_loss: 0.1005 - val_accuracy: 0.9834
# Epoch 235/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0108 - accuracy: 0.9977 - val_loss: 0.0910 - val_accuracy: 0.9859
# Epoch 236/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0068 - accuracy: 0.9992 - val_loss: 0.1138 - val_accuracy: 0.9818
# Epoch 237/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0077 - accuracy: 0.9984 - val_loss: 0.1150 - val_accuracy: 0.9824
# Epoch 238/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0120 - accuracy: 0.9972 - val_loss: 0.1845 - val_accuracy: 0.9657
# Epoch 239/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1209 - accuracy: 0.9678 - val_loss: 0.1120 - val_accuracy: 0.9818
# Epoch 240/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0126 - accuracy: 0.9971 - val_loss: 0.1059 - val_accuracy: 0.9836
# Epoch 241/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0064 - accuracy: 0.9993 - val_loss: 0.1043 - val_accuracy: 0.9838
# Epoch 242/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0062 - accuracy: 0.9992 - val_loss: 0.1412 - val_accuracy: 0.9778
# Epoch 243/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0605 - accuracy: 0.9813 - val_loss: 0.1362 - val_accuracy: 0.9784
# Epoch 244/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0089 - accuracy: 0.9983 - val_loss: 0.1000 - val_accuracy: 0.9837
# Epoch 245/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0061 - accuracy: 0.9991 - val_loss: 0.1075 - val_accuracy: 0.9833
# Epoch 246/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0062 - accuracy: 0.9990 - val_loss: 0.1074 - val_accuracy: 0.9832
# Epoch 247/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0060 - accuracy: 0.9989 - val_loss: 0.1269 - val_accuracy: 0.9729
# Epoch 248/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.1588 - accuracy: 0.9580 - val_loss: 0.1247 - val_accuracy: 0.9746
# Epoch 249/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0186 - accuracy: 0.9963 - val_loss: 0.1061 - val_accuracy: 0.9833
# Epoch 250/250
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0077 - accuracy: 0.9988 - val_loss: 0.1419 - val_accuracy: 0.9774

# %% [markdown]
# # Grad-CAM (Gradient-weighted Class Activation Mapping)

# %%
def preprocess_input(x):
    return x / 255.0

# %%
# Set input shape and number of classes
input_shape = (224, 224, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the depthwise separable CNN model
model2 = depthwise_inception_net(input_shape, num_classes)

# Compile the model
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# model2.summary()

# %%
# last_conv_layer_name = [layer.name for layer in model2.layers if 'conv' in layer.name][-1]
# last_conv_layer = model.get_layer(last_conv_layer_name)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
import tensorflow as tf

# 假设你的数据集是一个字典，其中键是类别，值是图像路径的列表
dataset = {
    'bkl': ['archive/HAM10000_images_part_1/ISIC_0027419.jpg'],
    'nv': ['archive/HAM10000_images_part_1/ISIC_0028239.jpg'],
    'mel': ['archive/HAM10000_images_part_1/ISIC_0027190.jpg'],
    'bcc': ['archive/HAM10000_images_part_1/ISIC_0026574.jpg'],
    'vasc': ['archive/HAM10000_images_part_1/ISIC_0025321.jpg'],
    'akiec': ['archive/HAM10000_images_part_1/ISIC_0026872.jpg'],
    'df': ['archive/HAM10000_images_part_1/ISIC_0025954.jpg'],
}

# 获取最后一个卷积层的名称
last_conv_layer_name = [layer.name for layer in model2.layers if 'conv' in layer.name][-1]



# 对于每个类别，选择一个图像路径
for class_name, image_paths in dataset.items():
    img_path = image_paths[0]  # 选择第一个图像路径
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)  # 如果您的模型需要特定的预处理，请在这里进行

    # 获取模型的预测
    preds = model2.predict(x)

    # 获取预测类别的索引
    class_idx = np.argmax(preds[0])

    # 计算类别相对于最后一个卷积层输出的梯度
    with tf.GradientTape() as tape:
        last_conv_layer_output = model2.get_layer(last_conv_layer_name).output
        model_with_conv_output = tf.keras.models.Model([model2.inputs], [model2.output, last_conv_layer_output])
        preds, last_conv_output = model_with_conv_output(x)
        class_channel = preds[:, class_idx]

    # 计算梯度
    grads = tape.gradient(class_channel, last_conv_output)

    # 对梯度进行全局平均池化，得到每个通道的重要性权重
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # 对最后一个卷积层的输出进行加权求和，得到一个类激活映射
    heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_output), axis=-1)

    # 对类激活映射进行归一化
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)

    # 将PIL图像转换为NumPy数组
    img = tf.keras.preprocessing.image.img_to_array(img)

    # 将类激活映射上采样到输入图像的大小
    heatmap = cv2.resize(heatmap[0], (img.shape[1], img.shape[0]))

    # 将类激活映射转换为RGB
    heatmap = np.uint8(255 * heatmap)

    # 应用颜色映射
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

    # 将热力图叠加到原始图像上
    superimposed_img = cv2.addWeighted(img.astype('uint8'), 0.6, heatmap, 0.4, 0)

    # 创建一个新的图像
    plt.figure()

    plt.subplot(1, 2, 1)
    plt.imshow(img.astype(np.uint8))
    plt.title(f'Original Image - {class_name}')

    # 在第二个子图中显示热力图
    plt.subplot(1, 2, 2)
    plt.imshow(superimposed_img)
    plt.title(f'Heatmap - {class_name}')

    # 显示图像
    plt.show()
# Out:
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step

# %% [markdown]
# # Plot Accuracy and Loss

# %%
import matplotlib.pyplot as plt

def plot_accuracy_and_loss(history):
    # Get training and testing accuracy and loss histories
    training_accuracy = history.history['accuracy']
    testing_accuracy = history.history['val_accuracy']
    training_loss = history.history['loss']
    testing_loss = history.history['val_loss']

    # Plot training and testing accuracy curves
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(training_accuracy, label='Training Accuracy')
    plt.plot(testing_accuracy, label='Testing Accuracy')
    plt.title('Training vs Testing Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()

    # Plot training and testing loss curves
    plt.subplot(1, 2, 2)
    plt.plot(training_loss, label='Training Loss')
    plt.plot(testing_loss, label='Testing Loss')
    plt.title('Training vs Testing Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_accuracy_and_loss(history)

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 6s 6ms/step - loss: 0.0298 - accuracy: 0.9947
# 367/367 [==============================] - 2s 6ms/step - loss: 0.1419 - accuracy: 0.9774
# Train Loss:  0.029793132096529007
# Train Accuracy:  0.9947444796562195
# --------------------
# Test Loss:  0.14188823103904724
# Test Accuracy:  0.9774160385131836

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 1s 4ms/step

# %% [markdown]
# # Plot ROC , Recall , Precision , Sensitivity , Specificity , F1 Score , Precision-Recall with average value

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, auc, recall_score, precision_score, f1_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import label_binarize

def plot_curves(y_true, y_scores):
    num_classes = y_scores.shape[1]
    
    # Binarize the labels
    y_true_bin = label_binarize(y_true, classes=np.arange(num_classes))
    
    # Initialize figure
    plt.figure(figsize=(30, 30))
    
    # Plot ROC curve for each class
    plt.subplot(3, 3, 1)
    avg_auc = 0
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        avg_auc += roc_auc
        plt.plot(fpr, tpr, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
    avg_auc /= num_classes
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curves (Multi-class, Average AUC = {avg_auc:.2f})')
    plt.legend(loc="lower right")
    
    # Plot Recall curve for each class
    plt.subplot(3, 3, 2)
    avg_recall = 0
    recall_values_avg = []
    for i in range(num_classes):
        recall_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_recall += np.mean(recall_values)
        recall_values_avg.append(recall_values)
        plt.plot(np.linspace(0, 1, 100), recall_values, label=f'Class {i}')
    avg_recall /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(recall_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('Recall')
    plt.title(f'Recall Curves (Multi-class, Average Recall = {avg_recall:.2f})')
    plt.legend(loc="lower right")

    # Plot Precision curve for each class
    plt.subplot(3, 3, 3)
    avg_precision = 0
    precision_values_avg = []
    for i in range(num_classes):
        precision_values = [precision_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_precision += np.mean(precision_values)
        precision_values_avg.append(precision_values)
        plt.plot(np.linspace(0, 1, 100), precision_values, label=f'Class {i}')
    avg_precision /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(precision_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('Precision')
    plt.title(f'Precision Curves (Multi-class, Average Precision = {avg_precision:.2f})')
    plt.legend(loc="lower right")

    # Plot Sensitivity curve for each class
    plt.subplot(3, 3, 4)
    avg_sensitivity = 0
    sensitivity_values_avg = []
    for i in range(num_classes):
        sensitivity_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_sensitivity += np.mean(sensitivity_values)
        sensitivity_values_avg.append(sensitivity_values)
        plt.plot(np.linspace(0, 1, 100), sensitivity_values, label=f'Class {i}')
    avg_sensitivity /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(sensitivity_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('Sensitivity')
    plt.title(f'Sensitivity Curves (Multi-class, Average Sensitivity = {avg_sensitivity:.2f})')
    plt.legend(loc="lower right")

    # Plot Specificity curve for each class
    plt.subplot(3, 3, 5)
    avg_specificity = 0
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        tnr = 1 - fpr
        avg_specificity += np.mean(tnr)
        plt.plot(tnr, tpr, label=f'Class {i}')
    avg_specificity /= num_classes
    plt.xlabel('Specificity (True Negative Rate)')
    plt.ylabel('Sensitivity (True Positive Rate)')
    plt.title(f'Specificity Curves (Multi-class, Average Specificity = {avg_specificity:.2f})')
    plt.legend(loc='lower right')

    # Plot F1 Score curve for each class
    plt.subplot(3, 3, 6)
    avg_f1 = 0
    f1_values_avg = []
    for i in range(num_classes):
        f1_values = [f1_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_f1 += np.mean(f1_values)
        f1_values_avg.append(f1_values)
        plt.plot(np.linspace(0, 1, 100), f1_values, label=f'Class {i}')
    avg_f1 /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(f1_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('F1 Score')
    plt.title(f'F1 Score Curves (Multi-class, Average F1 Score = {avg_f1:.2f})')
    plt.legend(loc="lower right")

    # Plot Precision-Recall curve for each class
    plt.subplot(3, 3, 7)
    avg_precision_recall = 0
    for i in range(num_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_scores[:, i])
        avg_precision_recall += auc(recall, precision)
        plt.plot(recall, precision, lw=2, label=f'Class {i}')
    avg_precision_recall /= num_classes
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curves (Multi-class, Average AUC = {avg_precision_recall:.2f})')
    plt.legend(loc="lower right")

    plt.tight_layout()
    plt.show()

y_pred_probs = model.predict(X_test)
# Assuming y_pred_probs contains probabilities for each class
plot_curves(y_true, y_pred_probs)
# Out:
# 367/367 [==============================] - 1s 3ms/step

# %% [markdown]
# # Plot ROC , Recall , Precision , Sensitivity , Specificity , F1 Score , Precision-Recall with mean value

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, auc, recall_score, precision_score, f1_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import label_binarize

def plot_curves2(y_true, y_scores):
    num_classes = y_scores.shape[1]
    
    # Binarize the labels
    y_true_bin = label_binarize(y_true, classes=np.arange(num_classes))
    
    # Initialize figure
    plt.figure(figsize=(30, 30))
    
    # Lists to store mean values
    mean_fpr, mean_tpr = np.linspace(0, 1, 100), np.linspace(0, 1, 100)
    mean_recall, mean_precision = np.linspace(0, 1, 100), np.linspace(0, 1, 100)
    mean_sensitivity, mean_f1 = np.linspace(0, 1, 100), np.linspace(0, 1, 100)
    
    # Plot ROC curve for each class
    plt.subplot(3, 3, 1)
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
        mean_tpr += np.interp(mean_fpr, fpr, tpr)
    mean_tpr /= num_classes
    mean_auc = auc(mean_fpr, mean_tpr)
    plt.plot(mean_fpr, mean_tpr, color='black', linestyle='--', lw=2, label=f'Mean ROC (AUC = {mean_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves (Multi-class)')
    plt.legend(loc="lower right")
    
    # Plot Recall curve for each class
    plt.subplot(3, 3, 2)
    for i in range(num_classes):
        recall_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), recall_values, label=f'Class {i}')
        mean_recall += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), recall_values)
    mean_recall /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_recall, color='black', linestyle='--', lw=2, label='Mean Recall')
    plt.xlabel('Threshold')
    plt.ylabel('Recall')
    plt.title('Recall Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Precision curve for each class
    plt.subplot(3, 3, 3)
    for i in range(num_classes):
        precision_values = [precision_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), precision_values, label=f'Class {i}')
        mean_precision += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), precision_values)
    mean_precision /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_precision, color='black', linestyle='--', lw=2, label='Mean Precision')
    plt.xlabel('Threshold')
    plt.ylabel('Precision')
    plt.title('Precision Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Sensitivity curve for each class
    plt.subplot(3, 3, 4)
    for i in range(num_classes):
        sensitivity_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), sensitivity_values, label=f'Class {i}')
        mean_sensitivity += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), sensitivity_values)
    mean_sensitivity /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_sensitivity, color='black', linestyle='--', lw=2, label='Mean Sensitivity')
    plt.xlabel('Threshold')
    plt.ylabel('Sensitivity')
    plt.title('Sensitivity Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Specificity curve for each class
    plt.subplot(3, 3, 5)
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        tnr = 1 - fpr
        plt.plot(tnr, tpr, label=f'Class {i}')
    plt.xlabel('Specificity (True Negative Rate)')
    plt.ylabel('Sensitivity (True Positive Rate)')
    plt.title('Specificity Curves (Multi-class)')
    plt.legend(loc='lower right')

    # Plot F1 Score curve for each class
    plt.subplot(3, 3, 6)
    for i in range(num_classes):
        f1_values = [f1_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), f1_values, label=f'Class {i}')
        mean_f1 += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), f1_values)
    mean_f1 /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_f1, color='black', linestyle='--', lw=2, label='Mean F1 Score')
    plt.xlabel('Threshold')
    plt.ylabel('F1 Score')
    plt.title('F1 Score Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Precision-Recall curve for each class
    plt.subplot(3, 3, 7)
    for i in range(num_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_scores[:, i])
        plt.plot(recall, precision, lw=2, label=f'Class {i}')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curves (Multi-class)')
    plt.legend(loc="lower right")

    plt.tight_layout()
    plt.show()

# Assuming y_pred

plot_curves2(y_true, y_pred_probs)

# %% [markdown]
# # Plot Confusion Matrix

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %% [markdown]
# # Store the Weights

# %%
# import tensorflow as tf
# model.save_weights('model_weights/DepthwisedInceptionNet.h5')

# %% [markdown]
# # Clear the session

# %%
# from keras import backend as K
# import gc

# del model

# K.clear_session()
# gc.collect()
# Out:
# 71584

# %%
# #You need to install numba using 'pip install numba'

# from numba import cuda

# cuda.select_device(0)
# cuda.close()
