# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r'F:\MV\Dataset\HAM1000\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6], dtype=int64)

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Concatenate, Conv2D, MaxPooling2D, AveragePooling2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense

def depthwise_inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Inception module 1
    tower_1 = Conv2D(64, (1, 1), padding='same', activation='relu')(input_tensor)

    tower_2 = Conv2D(64, (1, 1), padding='same', activation='relu')(input_tensor)
    tower_2 = DepthwiseConv2D(3, padding='same', activation='relu')(tower_2)

    tower_3 = Conv2D(64, (1, 1), padding='same', activation='relu')(input_tensor)
    tower_3 = DepthwiseConv2D(5, padding='same', activation='relu')(tower_3)

    tower_4 = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(input_tensor)
    tower_4 = Conv2D(64, (1, 1), padding='same', activation='relu')(tower_4)

    inception_block_1 = Concatenate(axis=-1)([tower_1, tower_2, tower_3, tower_4])

    # Inception module 2
    tower_5 = Conv2D(128, (1, 1), padding='same', activation='relu')(inception_block_1)

    tower_6 = Conv2D(128, (1, 1), padding='same', activation='relu')(inception_block_1)
    tower_6 = DepthwiseConv2D(3, padding='same', activation='relu')(tower_6)

    tower_7 = Conv2D(128, (1, 1), padding='same', activation='relu')(inception_block_1)
    tower_7 = DepthwiseConv2D(5, padding='same', activation='relu')(tower_7)

    tower_8 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(inception_block_1)
    tower_8 = Conv2D(128, (1, 1), padding='same', activation='relu')(tower_8)

    inception_block_2 = Concatenate(axis=-1)([tower_5, tower_6, tower_7, tower_8])

    # Global average pooling and dense layers
    x = GlobalAveragePooling2D()(inception_block_2)
    output_tensor = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=output_tensor)

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the depthwise separable InceptionNet-style CNN model
model = depthwise_inception_net(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 3)]  0           []
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 64)   256         ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 64)   256         ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 3)    0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 28, 28, 64)   256         ['input_1[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 28, 28, 64)  640         ['conv2d_1[0][0]']
#  v2D)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 28, 28, 64)  1664        ['conv2d_2[0][0]']
#  onv2D)
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   256         ['max_pooling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 256)  0           ['conv2d[0][0]',
#                                                                   'depthwise_conv2d[0][0]',
#                                                                   'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  average_pooling2d (AveragePool  (None, 28, 28, 256)  0          ['concatenate[0][0]']
#  ing2D)
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 28, 28, 128)  1280       ['conv2d_5[0][0]']
#  onv2D)
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 28, 28, 128)  3328       ['conv2d_6[0][0]']
#  onv2D)
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 128)  32896       ['average_pooling2d[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 512)  0           ['conv2d_4[0][0]',
#                                                                   'depthwise_conv2d_2[0][0]',
#                                                                   'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['concatenate_1[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 7)            3591        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 143,111
# Trainable params: 143,111
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.backend.clear_session()

# %%
history = model.fit(X_train ,
                    y_train ,
                    epochs=50 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/50
# 276/276 [==============================] - 23s 72ms/step - loss: 2.8331 - accuracy: 0.3158 - val_loss: 5.4430 - val_accuracy: 0.1456 - lr: 0.0010
# Epoch 2/50
# 276/276 [==============================] - 19s 70ms/step - loss: 1.6797 - accuracy: 0.4139 - val_loss: 4.9046 - val_accuracy: 0.2311 - lr: 0.0010
# Epoch 3/50
# 276/276 [==============================] - 20s 71ms/step - loss: 1.4970 - accuracy: 0.4571 - val_loss: 2.5679 - val_accuracy: 0.3184 - lr: 0.0010
# Epoch 4/50
# 276/276 [==============================] - 20s 72ms/step - loss: 1.3103 - accuracy: 0.5036 - val_loss: 3.3819 - val_accuracy: 0.2704 - lr: 0.0010
# Epoch 5/50
# 275/276 [============================>.] - ETA: 0s - loss: 1.2445 - accuracy: 0.5351
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 276/276 [==============================] - 20s 71ms/step - loss: 1.2445 - accuracy: 0.5351 - val_loss: 3.3654 - val_accuracy: 0.3006 - lr: 0.0010
# Epoch 6/50
# 276/276 [==============================] - 20s 73ms/step - loss: 1.1335 - accuracy: 0.5852 - val_loss: 1.9976 - val_accuracy: 0.3925 - lr: 5.0000e-04
# Epoch 7/50
# 276/276 [==============================] - 20s 71ms/step - loss: 1.0887 - accuracy: 0.5919 - val_loss: 1.1794 - val_accuracy: 0.5487 - lr: 5.0000e-04
# Epoch 8/50
# 276/276 [==============================] - 20s 73ms/step - loss: 1.0335 - accuracy: 0.6103 - val_loss: 1.2290 - val_accuracy: 0.5216 - lr: 5.0000e-04
# Epoch 9/50
# 275/276 [============================>.] - ETA: 0s - loss: 1.0296 - accuracy: 0.6090
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 276/276 [==============================] - 21s 76ms/step - loss: 1.0296 - accuracy: 0.6090 - val_loss: 1.5587 - val_accuracy: 0.4709 - lr: 5.0000e-04
# Epoch 10/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.9824 - accuracy: 0.6393 - val_loss: 0.9483 - val_accuracy: 0.6546 - lr: 2.5000e-04
# Epoch 11/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.9349 - accuracy: 0.6512 - val_loss: 1.2939 - val_accuracy: 0.5067 - lr: 2.5000e-04
# Epoch 12/50
# 275/276 [============================>.] - ETA: 0s - loss: 0.9343 - accuracy: 0.6532
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 276/276 [==============================] - 20s 74ms/step - loss: 0.9344 - accuracy: 0.6532 - val_loss: 1.4673 - val_accuracy: 0.4224 - lr: 2.5000e-04
# Epoch 13/50
# 276/276 [==============================] - 21s 74ms/step - loss: 0.9311 - accuracy: 0.6584 - val_loss: 0.9763 - val_accuracy: 0.6185 - lr: 1.2500e-04
# Epoch 14/50
# 276/276 [==============================] - 21s 74ms/step - loss: 0.9073 - accuracy: 0.6644 - val_loss: 0.9013 - val_accuracy: 0.6623 - lr: 1.2500e-04
# Epoch 15/50
# 276/276 [==============================] - 21s 74ms/step - loss: 0.8895 - accuracy: 0.6734 - val_loss: 0.9884 - val_accuracy: 0.6106 - lr: 1.2500e-04
# Epoch 16/50
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8951 - accuracy: 0.6712 - val_loss: 0.9137 - val_accuracy: 0.6658 - lr: 1.2500e-04
# Epoch 17/50
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8798 - accuracy: 0.6762 - val_loss: 0.9172 - val_accuracy: 0.6387 - lr: 1.2500e-04
# Epoch 18/50
# 275/276 [============================>.] - ETA: 0s - loss: 0.8800 - accuracy: 0.6753
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 276/276 [==============================] - 21s 74ms/step - loss: 0.8800 - accuracy: 0.6752 - val_loss: 1.1196 - val_accuracy: 0.5852 - lr: 1.2500e-04
# Epoch 19/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8832 - accuracy: 0.6765 - val_loss: 0.8539 - val_accuracy: 0.6923 - lr: 6.2500e-05
# Epoch 20/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8525 - accuracy: 0.6904 - val_loss: 0.8758 - val_accuracy: 0.6759 - lr: 6.2500e-05
# Epoch 21/50
# 275/276 [============================>.] - ETA: 0s - loss: 0.8577 - accuracy: 0.6866
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8576 - accuracy: 0.6866 - val_loss: 0.8453 - val_accuracy: 0.6882 - lr: 6.2500e-05
# Epoch 22/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8416 - accuracy: 0.6962 - val_loss: 0.8375 - val_accuracy: 0.7040 - lr: 3.1250e-05
# Epoch 23/50
# 276/276 [==============================] - 21s 74ms/step - loss: 0.8456 - accuracy: 0.6921 - val_loss: 0.8395 - val_accuracy: 0.6966 - lr: 3.1250e-05
# Epoch 24/50
# 275/276 [============================>.] - ETA: 0s - loss: 0.8465 - accuracy: 0.6935
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8465 - accuracy: 0.6934 - val_loss: 0.8303 - val_accuracy: 0.6953 - lr: 3.1250e-05
# Epoch 25/50
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8372 - accuracy: 0.6964 - val_loss: 0.8257 - val_accuracy: 0.7007 - lr: 1.5625e-05
# Epoch 26/50
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8336 - accuracy: 0.7005 - val_loss: 0.8261 - val_accuracy: 0.7091 - lr: 1.5625e-05
# Epoch 27/50
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8338 - accuracy: 0.6972 - val_loss: 0.8235 - val_accuracy: 0.7061 - lr: 1.5625e-05
# Epoch 28/50
# 275/276 [============================>.] - ETA: 0s - loss: 0.8313 - accuracy: 0.7015
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1e-05.
# 276/276 [==============================] - 21s 77ms/step - loss: 0.8314 - accuracy: 0.7015 - val_loss: 0.8279 - val_accuracy: 0.7035 - lr: 1.5625e-05
# Epoch 29/50
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8330 - accuracy: 0.6981 - val_loss: 0.8218 - val_accuracy: 0.7115 - lr: 1.0000e-05
# Epoch 30/50
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8307 - accuracy: 0.7011 - val_loss: 0.8228 - val_accuracy: 0.7058 - lr: 1.0000e-05
# Epoch 31/50
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8308 - accuracy: 0.6999 - val_loss: 0.8207 - val_accuracy: 0.7113 - lr: 1.0000e-05
# Epoch 32/50
# 276/276 [==============================] - 21s 74ms/step - loss: 0.8293 - accuracy: 0.7011 - val_loss: 0.8212 - val_accuracy: 0.7114 - lr: 1.0000e-05
# Epoch 33/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8286 - accuracy: 0.7010 - val_loss: 0.8206 - val_accuracy: 0.7021 - lr: 1.0000e-05
# Epoch 34/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8279 - accuracy: 0.6996 - val_loss: 0.8181 - val_accuracy: 0.7125 - lr: 1.0000e-05
# Epoch 35/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8284 - accuracy: 0.6998 - val_loss: 0.8197 - val_accuracy: 0.7111 - lr: 1.0000e-05
# Epoch 36/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8262 - accuracy: 0.7030 - val_loss: 0.8189 - val_accuracy: 0.7072 - lr: 1.0000e-05
# Epoch 37/50
# 276/276 [==============================] - 21s 77ms/step - loss: 0.8265 - accuracy: 0.7009 - val_loss: 0.8203 - val_accuracy: 0.7100 - lr: 1.0000e-05
# Epoch 38/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8260 - accuracy: 0.7014 - val_loss: 0.8177 - val_accuracy: 0.7070 - lr: 1.0000e-05
# Epoch 39/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8285 - accuracy: 0.6995 - val_loss: 0.8158 - val_accuracy: 0.7113 - lr: 1.0000e-05
# Epoch 40/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8243 - accuracy: 0.7026 - val_loss: 0.8156 - val_accuracy: 0.7116 - lr: 1.0000e-05
# Epoch 41/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8238 - accuracy: 0.7034 - val_loss: 0.8197 - val_accuracy: 0.7093 - lr: 1.0000e-05
# Epoch 42/50
# 276/276 [==============================] - 21s 76ms/step - loss: 0.8232 - accuracy: 0.7024 - val_loss: 0.8173 - val_accuracy: 0.7163 - lr: 1.0000e-05
# Epoch 43/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8229 - accuracy: 0.7026 - val_loss: 0.8139 - val_accuracy: 0.7099 - lr: 1.0000e-05
# Epoch 44/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8221 - accuracy: 0.7032 - val_loss: 0.8132 - val_accuracy: 0.7126 - lr: 1.0000e-05
# Epoch 45/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8219 - accuracy: 0.7018 - val_loss: 0.8150 - val_accuracy: 0.7148 - lr: 1.0000e-05
# Epoch 46/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8228 - accuracy: 0.7044 - val_loss: 0.8122 - val_accuracy: 0.7171 - lr: 1.0000e-05
# Epoch 47/50
# 276/276 [==============================] - 20s 74ms/step - loss: 0.8210 - accuracy: 0.7038 - val_loss: 0.8118 - val_accuracy: 0.7145 - lr: 1.0000e-05
# Epoch 48/50
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8204 - accuracy: 0.7041 - val_loss: 0.8112 - val_accuracy: 0.7085 - lr: 1.0000e-05
# Epoch 49/50
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8217 - accuracy: 0.7036 - val_loss: 0.8108 - val_accuracy: 0.7126 - lr: 1.0000e-05
# Epoch 50/50
# 276/276 [==============================] - 21s 75ms/step - loss: 0.8197 - accuracy: 0.7051 - val_loss: 0.8112 - val_accuracy: 0.7108 - lr: 1.0000e-05

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 8s 7ms/step - loss: 0.8183 - accuracy: 0.7038
# 367/367 [==============================] - 3s 8ms/step - loss: 0.8112 - accuracy: 0.7108
# Train Loss:  0.8182716369628906
# Train Accuracy:  0.7038436532020569
# --------------------
# Test Loss:  0.8112056255340576
# Test Accuracy:  0.7108402848243713

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 3s 7ms/step

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#model.save('Skin Cancer.h5')

# %%
from keras import backend as K
import gc

del model

K.clear_session()
gc.collect()
# Out:
# 127

# %%
from numba import cuda

cuda.select_device(0)
cuda.close()
