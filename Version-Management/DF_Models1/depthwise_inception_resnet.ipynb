# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r'F:\MV\Dataset\HAM1000\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6], dtype=int64)

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Concatenate, Conv2D, MaxPooling2D, AveragePooling2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense, Add

def depthwise_inception_resnet(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Inception-ResNet module
    def inception_resnet_block(x, scale=1.0):
        conv1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)

        conv2_1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)
        conv2_1 = DepthwiseConv2D(3, padding='same', activation='relu')(conv2_1)

        conv2_2 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)
        conv2_2 = DepthwiseConv2D(5, padding='same', activation='relu')(conv2_2)

        inception_block = Concatenate(axis=-1)([conv1, conv2_1, conv2_2])

        # Residual connection
        scaled_block = Conv2D(int(x.shape[-1]), (1, 1), padding='same', activation='linear')(inception_block)
        scaled_block = BatchNormalization()(scaled_block)

        out = Add()([x, scaled_block])
        out = ReLU()(out * scale)

        return out

    # Initial convolution
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(input_tensor)

    # Depthwise Inception-ResNet blocks
    x = inception_resnet_block(x)
    x = inception_resnet_block(x)
    x = inception_resnet_block(x)

    # Global average pooling and dense layers
    x = GlobalAveragePooling2D()(x)
    output_tensor = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=output_tensor)

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the InceptionNet model
model = depthwise_inception_resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 28, 28, 64)   1792        ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 28, 28, 32)  320         ['conv2d_2[0][0]']
#  v2D)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 28, 28, 32)  832         ['conv2d_3[0][0]']
#  onv2D)
#
#  concatenate (Concatenate)      (None, 28, 28, 96)   0           ['conv2d_1[0][0]',
#                                                                   'depthwise_conv2d[0][0]',
#                                                                   'depthwise_conv2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 64)   6208        ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 28, 28, 64)  256         ['conv2d_4[0][0]']
#  alization)
#
#  add (Add)                      (None, 28, 28, 64)   0           ['conv2d[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 28, 28, 64)   0           ['add[0][0]']
#
#  re_lu (ReLU)                   (None, 28, 28, 64)   0           ['tf.math.multiply[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 32)   2080        ['re_lu[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   2080        ['re_lu[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 32)   2080        ['re_lu[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 28, 28, 32)  320         ['conv2d_6[0][0]']
#  onv2D)
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 28, 28, 32)  832         ['conv2d_7[0][0]']
#  onv2D)
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 96)   0           ['conv2d_5[0][0]',
#                                                                   'depthwise_conv2d_2[0][0]',
#                                                                   'depthwise_conv2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 64)   6208        ['concatenate_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 64)   0           ['re_lu[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 28, 28, 64)  0           ['add_1[0][0]']
#  )
#
#  re_lu_1 (ReLU)                 (None, 28, 28, 64)   0           ['tf.math.multiply_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 32)   2080        ['re_lu_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 32)   2080        ['re_lu_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 32)   2080        ['re_lu_1[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 28, 28, 32)  320         ['conv2d_10[0][0]']
#  onv2D)
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 28, 28, 32)  832         ['conv2d_11[0][0]']
#  onv2D)
#
#  concatenate_2 (Concatenate)    (None, 28, 28, 96)   0           ['conv2d_9[0][0]',
#                                                                   'depthwise_conv2d_4[0][0]',
#                                                                   'depthwise_conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 64)   6208        ['concatenate_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_12[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 28, 28, 64)   0           ['re_lu_1[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 28, 28, 64)  0           ['add_2[0][0]']
#  )
#
#  re_lu_2 (ReLU)                 (None, 28, 28, 64)   0           ['tf.math.multiply_2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['re_lu_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 7)            455         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 43,815
# Trainable params: 43,431
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train ,
                    y_train ,
                    epochs=150 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/50
# 276/276 [==============================] - 24s 43ms/step - loss: 3.4112 - accuracy: 0.3321 - val_loss: 2.1718 - val_accuracy: 0.3315 - lr: 0.0010
# Epoch 2/50
# 276/276 [==============================] - 12s 44ms/step - loss: 1.4424 - accuracy: 0.4639 - val_loss: 2.6792 - val_accuracy: 0.3223 - lr: 0.0010
# Epoch 3/50
# 274/276 [============================>.] - ETA: 0s - loss: 1.3558 - accuracy: 0.5179
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 276/276 [==============================] - 11s 42ms/step - loss: 1.3548 - accuracy: 0.5182 - val_loss: 9.3078 - val_accuracy: 0.1454 - lr: 0.0010
# Epoch 4/50
# 276/276 [==============================] - 11s 41ms/step - loss: 1.3012 - accuracy: 0.5745 - val_loss: 4.0318 - val_accuracy: 0.1873 - lr: 5.0000e-04
# Epoch 5/50
# 275/276 [============================>.] - ETA: 0s - loss: 1.0510 - accuracy: 0.6067
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 276/276 [==============================] - 11s 41ms/step - loss: 1.0510 - accuracy: 0.6067 - val_loss: 2.4722 - val_accuracy: 0.3120 - lr: 5.0000e-04
# Epoch 6/50
# 276/276 [==============================] - 12s 42ms/step - loss: 1.0190 - accuracy: 0.6259 - val_loss: 1.4909 - val_accuracy: 0.5324 - lr: 2.5000e-04
# Epoch 7/50
# 276/276 [==============================] - 12s 42ms/step - loss: 0.9366 - accuracy: 0.6494 - val_loss: 1.0910 - val_accuracy: 0.5695 - lr: 2.5000e-04
# Epoch 8/50
# 276/276 [==============================] - 12s 42ms/step - loss: 0.9329 - accuracy: 0.6480 - val_loss: 1.1289 - val_accuracy: 0.5635 - lr: 2.5000e-04
# Epoch 9/50
# 274/276 [============================>.] - ETA: 0s - loss: 0.9170 - accuracy: 0.6568
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 276/276 [==============================] - 12s 42ms/step - loss: 0.9167 - accuracy: 0.6569 - val_loss: 1.6329 - val_accuracy: 0.4304 - lr: 2.5000e-04
# Epoch 10/50
# 276/276 [==============================] - 12s 42ms/step - loss: 0.8764 - accuracy: 0.6751 - val_loss: 0.8599 - val_accuracy: 0.6750 - lr: 1.2500e-04
# Epoch 11/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.8746 - accuracy: 0.6719 - val_loss: 0.8896 - val_accuracy: 0.6530 - lr: 1.2500e-04
# Epoch 12/50
# 275/276 [============================>.] - ETA: 0s - loss: 0.8490 - accuracy: 0.6840
# Epoch 12: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 276/276 [==============================] - 12s 43ms/step - loss: 0.8491 - accuracy: 0.6840 - val_loss: 0.9285 - val_accuracy: 0.6513 - lr: 1.2500e-04
# Epoch 13/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.8277 - accuracy: 0.6964 - val_loss: 0.8503 - val_accuracy: 0.6628 - lr: 6.2500e-05
# Epoch 14/50
# 275/276 [============================>.] - ETA: 0s - loss: 0.8188 - accuracy: 0.6994
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 276/276 [==============================] - 12s 43ms/step - loss: 0.8188 - accuracy: 0.6994 - val_loss: 0.9071 - val_accuracy: 0.6433 - lr: 6.2500e-05
# Epoch 15/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.8105 - accuracy: 0.7032 - val_loss: 0.8366 - val_accuracy: 0.6835 - lr: 3.1250e-05
# Epoch 16/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.8095 - accuracy: 0.7036 - val_loss: 0.8226 - val_accuracy: 0.6973 - lr: 3.1250e-05
# Epoch 17/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.8048 - accuracy: 0.7056 - val_loss: 0.8222 - val_accuracy: 0.6987 - lr: 3.1250e-05
# Epoch 18/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.8041 - accuracy: 0.7079 - val_loss: 0.8095 - val_accuracy: 0.6918 - lr: 3.1250e-05
# Epoch 19/50
# 275/276 [============================>.] - ETA: 0s - loss: 0.8051 - accuracy: 0.7053
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 276/276 [==============================] - 12s 43ms/step - loss: 0.8052 - accuracy: 0.7053 - val_loss: 0.8482 - val_accuracy: 0.6906 - lr: 3.1250e-05
# Epoch 20/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7954 - accuracy: 0.7108 - val_loss: 0.7851 - val_accuracy: 0.7053 - lr: 1.5625e-05
# Epoch 21/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7920 - accuracy: 0.7118 - val_loss: 0.7868 - val_accuracy: 0.7035 - lr: 1.5625e-05
# Epoch 22/50
# 275/276 [============================>.] - ETA: 0s - loss: 0.7881 - accuracy: 0.7142
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-05.
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7882 - accuracy: 0.7142 - val_loss: 0.7940 - val_accuracy: 0.7026 - lr: 1.5625e-05
# Epoch 23/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7862 - accuracy: 0.7152 - val_loss: 0.7795 - val_accuracy: 0.7132 - lr: 1.0000e-05
# Epoch 24/50
# 276/276 [==============================] - 12s 44ms/step - loss: 0.7869 - accuracy: 0.7142 - val_loss: 0.7783 - val_accuracy: 0.7083 - lr: 1.0000e-05
# Epoch 25/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7828 - accuracy: 0.7159 - val_loss: 0.7877 - val_accuracy: 0.7079 - lr: 1.0000e-05
# Epoch 26/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7832 - accuracy: 0.7166 - val_loss: 0.7803 - val_accuracy: 0.7131 - lr: 1.0000e-05
# Epoch 27/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7848 - accuracy: 0.7154 - val_loss: 0.7806 - val_accuracy: 0.7114 - lr: 1.0000e-05
# Epoch 28/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7813 - accuracy: 0.7174 - val_loss: 0.7813 - val_accuracy: 0.7074 - lr: 1.0000e-05
# Epoch 29/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7806 - accuracy: 0.7173 - val_loss: 0.7763 - val_accuracy: 0.7126 - lr: 1.0000e-05
# Epoch 30/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7811 - accuracy: 0.7148 - val_loss: 0.7714 - val_accuracy: 0.7191 - lr: 1.0000e-05
# Epoch 31/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7799 - accuracy: 0.7170 - val_loss: 0.7869 - val_accuracy: 0.7035 - lr: 1.0000e-05
# Epoch 32/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7805 - accuracy: 0.7146 - val_loss: 0.7729 - val_accuracy: 0.7154 - lr: 1.0000e-05
# Epoch 33/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7787 - accuracy: 0.7153 - val_loss: 0.8024 - val_accuracy: 0.6952 - lr: 1.0000e-05
# Epoch 34/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7753 - accuracy: 0.7190 - val_loss: 0.7670 - val_accuracy: 0.7150 - lr: 1.0000e-05
# Epoch 35/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7761 - accuracy: 0.7179 - val_loss: 0.7966 - val_accuracy: 0.7039 - lr: 1.0000e-05
# Epoch 36/50
# 276/276 [==============================] - 12s 45ms/step - loss: 0.7767 - accuracy: 0.7174 - val_loss: 0.7650 - val_accuracy: 0.7166 - lr: 1.0000e-05
# Epoch 37/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7762 - accuracy: 0.7192 - val_loss: 0.7641 - val_accuracy: 0.7235 - lr: 1.0000e-05
# Epoch 38/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7744 - accuracy: 0.7190 - val_loss: 0.7733 - val_accuracy: 0.7110 - lr: 1.0000e-05
# Epoch 39/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7745 - accuracy: 0.7216 - val_loss: 0.7953 - val_accuracy: 0.6993 - lr: 1.0000e-05
# Epoch 40/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7721 - accuracy: 0.7198 - val_loss: 0.7785 - val_accuracy: 0.7079 - lr: 1.0000e-05
# Epoch 41/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7719 - accuracy: 0.7207 - val_loss: 0.7801 - val_accuracy: 0.7158 - lr: 1.0000e-05
# Epoch 42/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7712 - accuracy: 0.7220 - val_loss: 0.7756 - val_accuracy: 0.7067 - lr: 1.0000e-05
# Epoch 43/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7710 - accuracy: 0.7205 - val_loss: 0.7769 - val_accuracy: 0.7121 - lr: 1.0000e-05
# Epoch 44/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7679 - accuracy: 0.7210 - val_loss: 0.7625 - val_accuracy: 0.7204 - lr: 1.0000e-05
# Epoch 45/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7684 - accuracy: 0.7220 - val_loss: 0.7584 - val_accuracy: 0.7234 - lr: 1.0000e-05
# Epoch 46/50
# 276/276 [==============================] - 12s 43ms/step - loss: 0.7643 - accuracy: 0.7229 - val_loss: 0.7640 - val_accuracy: 0.7217 - lr: 1.0000e-05
# Epoch 47/50
# 276/276 [==============================] - 12s 42ms/step - loss: 0.7653 - accuracy: 0.7234 - val_loss: 0.7620 - val_accuracy: 0.7203 - lr: 1.0000e-05
# Epoch 48/50
# 276/276 [==============================] - 12s 42ms/step - loss: 0.7637 - accuracy: 0.7229 - val_loss: 0.7866 - val_accuracy: 0.7032 - lr: 1.0000e-05
# Epoch 49/50
# 276/276 [==============================] - 12s 42ms/step - loss: 0.7668 - accuracy: 0.7223 - val_loss: 0.7548 - val_accuracy: 0.7174 - lr: 1.0000e-05
# Epoch 50/50
# 276/276 [==============================] - 12s 42ms/step - loss: 0.7617 - accuracy: 0.7246 - val_loss: 0.7566 - val_accuracy: 0.7248 - lr: 1.0000e-05

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 5s 5ms/step - loss: 0.7520 - accuracy: 0.7297
# 367/367 [==============================] - 2s 5ms/step - loss: 0.7566 - accuracy: 0.7248
# Train Loss:  0.7519626617431641
# Train Accuracy:  0.729695200920105
# --------------------
# Test Loss:  0.75658118724823
# Test Accuracy:  0.7248167991638184

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 2s 4ms/step

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#model.save('Skin Cancer.h5')

# %%
from keras import backend as K
import gc

del model

K.clear_session()
gc.collect()
# Out:
# 11315

# %%
#You need to install numba using 'pip install numba'

from numba import cuda

cuda.select_device(0)
cuda.close()
