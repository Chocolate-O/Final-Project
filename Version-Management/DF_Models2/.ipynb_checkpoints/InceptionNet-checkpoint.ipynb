# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r'F:\MV\Dataset\HAM1000\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6], dtype=int64)

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Concatenate, Flatten, Dense

def inception_block(x, filters):
    conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu')(x)

    conv3x3 = Conv2D(filters[1], (1, 1), padding='same', activation='relu')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu')(conv3x3)

    conv5x5 = Conv2D(filters[3], (1, 1), padding='same', activation='relu')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu')(conv5x5)

    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    maxpool = Conv2D(filters[5], (1, 1), padding='same', activation='relu')(maxpool)

    inception_block = Concatenate(axis=-1)([conv1x1, conv3x3, conv5x5, maxpool])
    return inception_block

def inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(input_tensor)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception blocks
    x = inception_block(x, filters=[64, 128, 128, 32, 32, 32])
    x = inception_block(x, filters=[128, 192, 192, 64, 64, 64])

    # MaxPooling and Fully Connected layers
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=x)

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the InceptionNet model
model = inception_net(input_shape, num_classes)

# Compile the model
model.compile(optimizer=Adam(0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 14, 14, 64)   9472        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 7, 7, 64)     0           ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 7, 7, 128)    8320        ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 7, 7, 32)     2080        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 64)    0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 64)     4160        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 7, 7, 128)    147584      ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 7, 7, 32)     25632       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 7, 7, 32)     2080        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 7, 7, 256)    0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 192)    49344       ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 64)     16448       ['concatenate[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 256)   0           ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 128)    32896       ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 192)    331968      ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 64)     102464      ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 7, 7, 64)     16448       ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 7, 7, 448)    0           ['conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 448)   0           ['concatenate_1[0][0]']
#
#  flatten (Flatten)              (None, 7168)         0           ['max_pooling2d_3[0][0]']
#
#  dense (Dense)                  (None, 512)          3670528     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 7)            3591        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 4,423,015
# Trainable params: 4,423,015
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=60 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/60
# 276/276 [==============================] - 4s 14ms/step - loss: 0.8653 - accuracy: 0.6904 - val_loss: 1.5726 - val_accuracy: 0.4769 - lr: 1.0000e-04
# Epoch 2/60
# 276/276 [==============================] - 4s 14ms/step - loss: 0.6568 - accuracy: 0.7733 - val_loss: 4.9424 - val_accuracy: 0.2678 - lr: 1.0000e-04
# Epoch 3/60
# 276/276 [==============================] - 4s 14ms/step - loss: 0.7170 - accuracy: 0.7758 - val_loss: 0.5689 - val_accuracy: 0.7973 - lr: 1.0000e-04
# Epoch 4/60
# 276/276 [==============================] - 4s 14ms/step - loss: 0.4194 - accuracy: 0.8647 - val_loss: 6.7230 - val_accuracy: 0.1927 - lr: 1.0000e-04
# Epoch 5/60
# 275/276 [============================>.] - ETA: 0s - loss: 0.6281 - accuracy: 0.8211
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 276/276 [==============================] - 4s 14ms/step - loss: 0.6281 - accuracy: 0.8211 - val_loss: 3.1466 - val_accuracy: 0.3335 - lr: 1.0000e-04
# Epoch 6/60
# 276/276 [==============================] - 4s 14ms/step - loss: 0.3781 - accuracy: 0.8957 - val_loss: 0.3084 - val_accuracy: 0.9085 - lr: 5.0000e-05
# Epoch 7/60
# 276/276 [==============================] - 4s 14ms/step - loss: 0.2464 - accuracy: 0.9341 - val_loss: 0.2949 - val_accuracy: 0.9061 - lr: 5.0000e-05
# Epoch 8/60
# 272/276 [============================>.] - ETA: 0s - loss: 0.2190 - accuracy: 0.9415
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 276/276 [==============================] - 4s 15ms/step - loss: 0.2191 - accuracy: 0.9414 - val_loss: 0.4543 - val_accuracy: 0.8209 - lr: 5.0000e-05
# Epoch 9/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1859 - accuracy: 0.9537 - val_loss: 0.3864 - val_accuracy: 0.8798 - lr: 2.5000e-05
# Epoch 10/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1938 - accuracy: 0.9503 - val_loss: 0.2014 - val_accuracy: 0.9462 - lr: 2.5000e-05
# Epoch 11/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1552 - accuracy: 0.9653 - val_loss: 0.2017 - val_accuracy: 0.9448 - lr: 2.5000e-05
# Epoch 12/60
# 272/276 [============================>.] - ETA: 0s - loss: 0.1465 - accuracy: 0.9654
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1462 - accuracy: 0.9655 - val_loss: 0.2050 - val_accuracy: 0.9435 - lr: 2.5000e-05
# Epoch 13/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1279 - accuracy: 0.9734 - val_loss: 0.1750 - val_accuracy: 0.9526 - lr: 1.2500e-05
# Epoch 14/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1217 - accuracy: 0.9757 - val_loss: 0.1638 - val_accuracy: 0.9598 - lr: 1.2500e-05
# Epoch 15/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1162 - accuracy: 0.9768 - val_loss: 0.1612 - val_accuracy: 0.9576 - lr: 1.2500e-05
# Epoch 16/60
# 273/276 [============================>.] - ETA: 0s - loss: 0.1100 - accuracy: 0.9782
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1e-05.
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1098 - accuracy: 0.9783 - val_loss: 0.3384 - val_accuracy: 0.8684 - lr: 1.2500e-05
# Epoch 17/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1200 - accuracy: 0.9736 - val_loss: 0.1936 - val_accuracy: 0.9380 - lr: 1.0000e-05
# Epoch 18/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1062 - accuracy: 0.9779 - val_loss: 0.1644 - val_accuracy: 0.9579 - lr: 1.0000e-05
# Epoch 19/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0977 - accuracy: 0.9800 - val_loss: 0.1436 - val_accuracy: 0.9659 - lr: 1.0000e-05
# Epoch 20/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0921 - accuracy: 0.9822 - val_loss: 0.1786 - val_accuracy: 0.9490 - lr: 1.0000e-05
# Epoch 21/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0891 - accuracy: 0.9824 - val_loss: 0.2704 - val_accuracy: 0.8963 - lr: 1.0000e-05
# Epoch 22/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0938 - accuracy: 0.9805 - val_loss: 0.1566 - val_accuracy: 0.9585 - lr: 1.0000e-05
# Epoch 23/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0847 - accuracy: 0.9842 - val_loss: 0.1317 - val_accuracy: 0.9665 - lr: 1.0000e-05
# Epoch 24/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0760 - accuracy: 0.9864 - val_loss: 0.1221 - val_accuracy: 0.9705 - lr: 1.0000e-05
# Epoch 25/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0734 - accuracy: 0.9878 - val_loss: 0.1352 - val_accuracy: 0.9626 - lr: 1.0000e-05
# Epoch 26/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0703 - accuracy: 0.9874 - val_loss: 0.1138 - val_accuracy: 0.9743 - lr: 1.0000e-05
# Epoch 27/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0674 - accuracy: 0.9883 - val_loss: 0.1124 - val_accuracy: 0.9722 - lr: 1.0000e-05
# Epoch 28/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0633 - accuracy: 0.9895 - val_loss: 0.1312 - val_accuracy: 0.9650 - lr: 1.0000e-05
# Epoch 29/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0611 - accuracy: 0.9892 - val_loss: 0.1044 - val_accuracy: 0.9753 - lr: 1.0000e-05
# Epoch 30/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0567 - accuracy: 0.9903 - val_loss: 0.1987 - val_accuracy: 0.9198 - lr: 1.0000e-05
# Epoch 31/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0699 - accuracy: 0.9856 - val_loss: 0.1275 - val_accuracy: 0.9634 - lr: 1.0000e-05
# Epoch 32/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0536 - accuracy: 0.9910 - val_loss: 0.1691 - val_accuracy: 0.9511 - lr: 1.0000e-05
# Epoch 33/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0599 - accuracy: 0.9884 - val_loss: 0.0935 - val_accuracy: 0.9799 - lr: 1.0000e-05
# Epoch 34/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0467 - accuracy: 0.9932 - val_loss: 0.0927 - val_accuracy: 0.9769 - lr: 1.0000e-05
# Epoch 35/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0430 - accuracy: 0.9941 - val_loss: 0.1022 - val_accuracy: 0.9726 - lr: 1.0000e-05
# Epoch 36/60
# 276/276 [==============================] - 5s 17ms/step - loss: 0.0410 - accuracy: 0.9944 - val_loss: 0.0943 - val_accuracy: 0.9765 - lr: 1.0000e-05
# Epoch 37/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0407 - accuracy: 0.9939 - val_loss: 0.0904 - val_accuracy: 0.9775 - lr: 1.0000e-05
# Epoch 38/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0395 - accuracy: 0.9943 - val_loss: 0.1264 - val_accuracy: 0.9631 - lr: 1.0000e-05
# Epoch 39/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0352 - accuracy: 0.9953 - val_loss: 0.1090 - val_accuracy: 0.9738 - lr: 1.0000e-05
# Epoch 40/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0337 - accuracy: 0.9955 - val_loss: 0.0970 - val_accuracy: 0.9777 - lr: 1.0000e-05
# Epoch 41/60
# 276/276 [==============================] - 4s 16ms/step - loss: 0.0338 - accuracy: 0.9948 - val_loss: 0.0815 - val_accuracy: 0.9830 - lr: 1.0000e-05
# Epoch 42/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0304 - accuracy: 0.9963 - val_loss: 0.0903 - val_accuracy: 0.9769 - lr: 1.0000e-05
# Epoch 43/60
# 276/276 [==============================] - 5s 16ms/step - loss: 0.0291 - accuracy: 0.9968 - val_loss: 0.0909 - val_accuracy: 0.9756 - lr: 1.0000e-05
# Epoch 44/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0262 - accuracy: 0.9972 - val_loss: 0.1090 - val_accuracy: 0.9696 - lr: 1.0000e-05
# Epoch 45/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0265 - accuracy: 0.9969 - val_loss: 0.0879 - val_accuracy: 0.9770 - lr: 1.0000e-05
# Epoch 46/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0251 - accuracy: 0.9970 - val_loss: 0.0835 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 47/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0234 - accuracy: 0.9977 - val_loss: 0.0886 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 48/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0212 - accuracy: 0.9978 - val_loss: 0.0913 - val_accuracy: 0.9757 - lr: 1.0000e-05
# Epoch 49/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0202 - accuracy: 0.9980 - val_loss: 0.0723 - val_accuracy: 0.9841 - lr: 1.0000e-05
# Epoch 50/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0181 - accuracy: 0.9982 - val_loss: 0.1278 - val_accuracy: 0.9640 - lr: 1.0000e-05
# Epoch 51/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0215 - accuracy: 0.9970 - val_loss: 0.0715 - val_accuracy: 0.9852 - lr: 1.0000e-05
# Epoch 52/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0154 - accuracy: 0.9986 - val_loss: 0.0675 - val_accuracy: 0.9838 - lr: 1.0000e-05
# Epoch 53/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0151 - accuracy: 0.9989 - val_loss: 0.0698 - val_accuracy: 0.9819 - lr: 1.0000e-05
# Epoch 54/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0162 - accuracy: 0.9986 - val_loss: 0.0968 - val_accuracy: 0.9734 - lr: 1.0000e-05
# Epoch 55/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0143 - accuracy: 0.9989 - val_loss: 0.0662 - val_accuracy: 0.9849 - lr: 1.0000e-05
# Epoch 56/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0152 - accuracy: 0.9985 - val_loss: 0.1115 - val_accuracy: 0.9692 - lr: 1.0000e-05
# Epoch 57/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0124 - accuracy: 0.9992 - val_loss: 0.0693 - val_accuracy: 0.9831 - lr: 1.0000e-05
# Epoch 58/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0116 - accuracy: 0.9994 - val_loss: 0.0722 - val_accuracy: 0.9823 - lr: 1.0000e-05
# Epoch 59/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0102 - accuracy: 0.9995 - val_loss: 0.0937 - val_accuracy: 0.9750 - lr: 1.0000e-05
# Epoch 60/60
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0102 - accuracy: 0.9994 - val_loss: 0.0916 - val_accuracy: 0.9763 - lr: 1.0000e-05

# %%
import tensorflow as tf
model.save_weights('weights\Inception.h5')

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 4s 4ms/step - loss: 0.0142 - accuracy: 0.9977
# 367/367 [==============================] - 1s 4ms/step - loss: 0.0916 - accuracy: 0.9763
# Train Loss:  0.014237991534173489
# Train Accuracy:  0.9976705312728882
# --------------------
# Test Loss:  0.0916263684630394
# Test Accuracy:  0.9763081669807434

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 2s 4ms/step

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#model.save('Skin Cancer.h5')

# %%
from keras import backend as K
import gc

del model

K.clear_session()
gc.collect()
# Out:
# 19935

# %%
#You need to install numba using 'pip install numba'

from numba import cuda

cuda.select_device(0)
cuda.close()
