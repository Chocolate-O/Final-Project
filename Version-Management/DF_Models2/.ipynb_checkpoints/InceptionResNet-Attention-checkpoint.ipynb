# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r'F:\MV\Dataset\HAM1000\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6], dtype=int64)

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Concatenate, AveragePooling2D, GlobalAveragePooling2D, Dense

def inception_resnet_block(x, scale=0.1):
    conv1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)

    conv2_1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)
    conv2_1 = Conv2D(32, (3, 3), padding='same', activation='relu')(conv2_1)

    conv3_1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)
    conv3_1 = Conv2D(32, (5, 5), padding='same', activation='relu')(conv3_1)

    inception_block = Concatenate(axis=-1)([conv1, conv2_1, conv3_1])

    # Residual connection
    scaled_block = Conv2D(int(x.shape[-1]), (1, 1), padding='same', activation='linear')(inception_block)
    scaled_block = BatchNormalization()(scaled_block)

    out = Concatenate(axis=-1)([x, scaled_block])
    out = ReLU()(out * scale)

    return out

def inception_resnet(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(input_tensor)

    # Inception-ResNet blocks
    for _ in range(4):  # You can adjust the number of blocks as needed
        x = inception_resnet_block(x)

    # Global average pooling and dense layer
    x = GlobalAveragePooling2D()(x)
    output_tensor = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=output_tensor)

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the Inception-ResNet model
model = inception_resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 28, 28, 64)   1792        ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 32)   9248        ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 32)   25632       ['conv2d_4[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 96)   0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 64)   6208        ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 28, 28, 64)  256         ['conv2d_6[0][0]']
#  alization)
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 128)  0           ['conv2d[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 28, 28, 128)  0           ['concatenate_1[0][0]']
#
#  re_lu (ReLU)                   (None, 28, 28, 128)  0           ['tf.math.multiply[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   4128        ['re_lu[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 32)   4128        ['re_lu[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   4128        ['re_lu[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 32)   9248        ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 32)   25632       ['conv2d_10[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 28, 28, 96)   0           ['conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  12416       ['concatenate_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  rmalization)
#
#  concatenate_3 (Concatenate)    (None, 28, 28, 256)  0           ['re_lu[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 28, 28, 256)  0          ['concatenate_3[0][0]']
#  )
#
#  re_lu_1 (ReLU)                 (None, 28, 28, 256)  0           ['tf.math.multiply_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 32)   8224        ['re_lu_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 32)   8224        ['re_lu_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 32)   8224        ['re_lu_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 32)   9248        ['conv2d_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 32)   25632       ['conv2d_16[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 96)   0           ['conv2d_13[0][0]',
#                                                                   'conv2d_15[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 256)  24832       ['concatenate_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 256)  1024       ['conv2d_18[0][0]']
#  rmalization)
#
#  concatenate_5 (Concatenate)    (None, 28, 28, 512)  0           ['re_lu_1[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 28, 28, 512)  0          ['concatenate_5[0][0]']
#  )
#
#  re_lu_2 (ReLU)                 (None, 28, 28, 512)  0           ['tf.math.multiply_2[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 32)   16416       ['re_lu_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 28, 28, 32)   16416       ['re_lu_2[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 32)   16416       ['re_lu_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 28, 32)   9248        ['conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 28, 28, 32)   25632       ['conv2d_22[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 28, 28, 96)   0           ['conv2d_19[0][0]',
#                                                                   'conv2d_21[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 28, 28, 512)  49664       ['concatenate_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 512)  2048       ['conv2d_24[0][0]']
#  rmalization)
#
#  concatenate_7 (Concatenate)    (None, 28, 28, 1024  0           ['re_lu_2[0][0]',
#                                 )                                 'batch_normalization_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 28, 28, 1024  0          ['concatenate_7[0][0]']
#  )                              )
#
#  re_lu_3 (ReLU)                 (None, 28, 28, 1024  0           ['tf.math.multiply_3[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['re_lu_3[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 7)            7175        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 337,991
# Trainable params: 336,071
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
tf.keras.backend.clear_session()

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=30 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction,EarlyStopping(monitor='loss', patience=3, restore_best_weights = True)])
# Out:
# Epoch 1/30
# 276/276 [==============================] - 48s 155ms/step - loss: 1.3392 - accuracy: 0.5040 - val_loss: 2.0584 - val_accuracy: 0.1667 - lr: 0.0010
# Epoch 2/30
# 276/276 [==============================] - 42s 153ms/step - loss: 0.9335 - accuracy: 0.6530 - val_loss: 1.4866 - val_accuracy: 0.4169 - lr: 0.0010
# Epoch 3/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.7260 - accuracy: 0.7350 - val_loss: 1.0864 - val_accuracy: 0.5858 - lr: 0.0010
# Epoch 4/30
# 276/276 [==============================] - 43s 154ms/step - loss: 0.5751 - accuracy: 0.7903 - val_loss: 0.8027 - val_accuracy: 0.6987 - lr: 0.0010
# Epoch 5/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.4683 - accuracy: 0.8316 - val_loss: 1.0856 - val_accuracy: 0.6662 - lr: 0.0010
# Epoch 6/30
# 275/276 [============================>.] - ETA: 0s - loss: 0.3962 - accuracy: 0.8584
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 276/276 [==============================] - 43s 154ms/step - loss: 0.3963 - accuracy: 0.8584 - val_loss: 1.1115 - val_accuracy: 0.5862 - lr: 0.0010
# Epoch 7/30
# 276/276 [==============================] - 43s 157ms/step - loss: 0.2849 - accuracy: 0.9040 - val_loss: 0.3713 - val_accuracy: 0.8691 - lr: 5.0000e-04
# Epoch 8/30
# 276/276 [==============================] - 43s 154ms/step - loss: 0.2343 - accuracy: 0.9224 - val_loss: 0.2911 - val_accuracy: 0.9053 - lr: 5.0000e-04
# Epoch 9/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.2087 - accuracy: 0.9332 - val_loss: 0.3394 - val_accuracy: 0.8890 - lr: 5.0000e-04
# Epoch 10/30
# 275/276 [============================>.] - ETA: 0s - loss: 0.1774 - accuracy: 0.9452
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 276/276 [==============================] - 43s 154ms/step - loss: 0.1775 - accuracy: 0.9452 - val_loss: 0.6414 - val_accuracy: 0.7624 - lr: 5.0000e-04
# Epoch 11/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.1392 - accuracy: 0.9586 - val_loss: 0.2119 - val_accuracy: 0.9299 - lr: 2.5000e-04
# Epoch 12/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.1217 - accuracy: 0.9655 - val_loss: 0.1532 - val_accuracy: 0.9542 - lr: 2.5000e-04
# Epoch 13/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.1080 - accuracy: 0.9707 - val_loss: 0.1914 - val_accuracy: 0.9402 - lr: 2.5000e-04
# Epoch 14/30
# 276/276 [==============================] - 43s 154ms/step - loss: 0.1003 - accuracy: 0.9733 - val_loss: 0.1206 - val_accuracy: 0.9671 - lr: 2.5000e-04
# Epoch 15/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0900 - accuracy: 0.9759 - val_loss: 0.3589 - val_accuracy: 0.8809 - lr: 2.5000e-04
# Epoch 16/30
# 275/276 [============================>.] - ETA: 0s - loss: 0.0858 - accuracy: 0.9778
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0859 - accuracy: 0.9778 - val_loss: 0.1725 - val_accuracy: 0.9451 - lr: 2.5000e-04
# Epoch 17/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0647 - accuracy: 0.9855 - val_loss: 0.1138 - val_accuracy: 0.9698 - lr: 1.2500e-04
# Epoch 18/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0581 - accuracy: 0.9873 - val_loss: 0.0926 - val_accuracy: 0.9749 - lr: 1.2500e-04
# Epoch 19/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0539 - accuracy: 0.9889 - val_loss: 0.0928 - val_accuracy: 0.9766 - lr: 1.2500e-04
# Epoch 20/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0504 - accuracy: 0.9901 - val_loss: 0.1070 - val_accuracy: 0.9686 - lr: 1.2500e-04
# Epoch 21/30
# 275/276 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9905
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0503 - accuracy: 0.9905 - val_loss: 0.0884 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 22/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0400 - accuracy: 0.9927 - val_loss: 0.0747 - val_accuracy: 0.9818 - lr: 6.2500e-05
# Epoch 23/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0380 - accuracy: 0.9945 - val_loss: 0.0761 - val_accuracy: 0.9787 - lr: 6.2500e-05
# Epoch 24/30
# 275/276 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9939
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0370 - accuracy: 0.9939 - val_loss: 0.0717 - val_accuracy: 0.9818 - lr: 6.2500e-05
# Epoch 25/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0340 - accuracy: 0.9953 - val_loss: 0.0663 - val_accuracy: 0.9819 - lr: 3.1250e-05
# Epoch 26/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0328 - accuracy: 0.9954 - val_loss: 0.0641 - val_accuracy: 0.9827 - lr: 3.1250e-05
# Epoch 27/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0318 - accuracy: 0.9959 - val_loss: 0.0654 - val_accuracy: 0.9812 - lr: 3.1250e-05
# Epoch 28/30
# 275/276 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9957
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0317 - accuracy: 0.9956 - val_loss: 0.0664 - val_accuracy: 0.9815 - lr: 3.1250e-05
# Epoch 29/30
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0300 - accuracy: 0.9960 - val_loss: 0.0658 - val_accuracy: 0.9799 - lr: 1.5625e-05
# Epoch 30/30
# 275/276 [============================>.] - ETA: 0s - loss: 0.0295 - accuracy: 0.9965
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1e-05.
# 276/276 [==============================] - 42s 154ms/step - loss: 0.0295 - accuracy: 0.9965 - val_loss: 0.0633 - val_accuracy: 0.9817 - lr: 1.5625e-05

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=10 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction,EarlyStopping(monitor='loss', patience=3, restore_best_weights = True)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 from tensorflow.keras.callbacks import EarlyStopping
# ----> 2 history = model.fit(X_train ,
#       3                     y_train ,
#       4                     epochs=10 ,
#       5                     batch_size=128,
#       6                     validation_data=(X_test , y_test) ,
#       7                     callbacks=[learning_rate_reduction,EarlyStopping(monitor='loss', patience=3, restore_best_weights = True)])
#
# NameError: name 'model' is not defined

# %%
import tensorflow as tf
model.save_weights('weights\InceptionResNet.h5')

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 14s 12ms/step - loss: 0.0236 - accuracy: 0.9979
# 367/367 [==============================] - 5s 13ms/step - loss: 0.0633 - accuracy: 0.9817
# Train Loss:  0.023637931793928146
# Train Accuracy:  0.9978693723678589
# --------------------
# Test Loss:  0.06327737867832184
# Test Accuracy:  0.9816771745681763

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 4s 11ms/step

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#model.save('Skin Cancer.h5')

# %%
from keras import backend as K
import gc

del model

K.clear_session()
gc.collect()
# Out:
# 19360

# %%
#You need to install numba using 'pip install numba'

from numba import cuda

cuda.select_device(0)
cuda.close()
