# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r'F:\MV\Dataset\HAM1000\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6], dtype=int64)

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense

# Define the depthwise separable CNN model
def depthwise_resnet(input_shape, num_classes):
    model = Sequential()

    # Depthwise separable convolution block 1
    model.add(DepthwiseConv2D(3, padding='same', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Conv2D(64, (1, 1)))
    model.add(BatchNormalization())
    model.add(ReLU())

    # Depthwise separable convolution block 2
    model.add(DepthwiseConv2D(3, strides=(2, 2), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Conv2D(128, (1, 1)))
    model.add(BatchNormalization())
    model.add(ReLU())

    # Depthwise separable convolution block 3
    model.add(DepthwiseConv2D(3, strides=(2, 2), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Conv2D(256, (1, 1)))
    model.add(BatchNormalization())
    model.add(ReLU())

    # Global average pooling and dense layers
    model.add(GlobalAveragePooling2D())
    model.add(Dense(num_classes, activation='softmax'))

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the depthwise separable CNN model
model = depthwise_resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  depthwise_conv2d (Depthwise  (None, 28, 28, 3)        30
#  Conv2D)
#
#  batch_normalization (BatchN  (None, 28, 28, 3)        12
#  ormalization)
#
#  re_lu (ReLU)                (None, 28, 28, 3)         0
#
#  conv2d (Conv2D)             (None, 28, 28, 64)        256
#
#  batch_normalization_1 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 28, 28, 64)        0
#
#  depthwise_conv2d_1 (Depthwi  (None, 14, 14, 64)       640
#  seConv2D)
#
#  batch_normalization_2 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 128)       8320
#
#  batch_normalization_3 (Batc  (None, 14, 14, 128)      512
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 14, 14, 128)       0
#
#  depthwise_conv2d_2 (Depthwi  (None, 7, 7, 128)        1280
#  seConv2D)
#
#  batch_normalization_4 (Batc  (None, 7, 7, 128)        512
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 7, 7, 128)         0
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 256)         33024
#
#  batch_normalization_5 (Batc  (None, 7, 7, 256)        1024
#  hNormalization)
#
#  re_lu_5 (ReLU)              (None, 7, 7, 256)         0
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                 1799
#
# =================================================================
# Total params: 47,921
# Trainable params: 46,635
# Non-trainable params: 1,286
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=100 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction,EarlyStopping(monitor='loss', patience=10, restore_best_weights = True)])
# Out:
# Epoch 1/100
# 276/276 [==============================] - 7s 13ms/step - loss: 1.2669 - accuracy: 0.5474 - val_loss: 2.9369 - val_accuracy: 0.1388 - lr: 0.0010
# Epoch 2/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.8182 - accuracy: 0.7267 - val_loss: 2.0021 - val_accuracy: 0.3694 - lr: 0.0010
# Epoch 3/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.6045 - accuracy: 0.7993 - val_loss: 0.8086 - val_accuracy: 0.7205 - lr: 0.0010
# Epoch 4/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.4854 - accuracy: 0.8410 - val_loss: 0.6475 - val_accuracy: 0.7427 - lr: 0.0010
# Epoch 5/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.4011 - accuracy: 0.8672 - val_loss: 0.5415 - val_accuracy: 0.8105 - lr: 0.0010
# Epoch 6/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.3480 - accuracy: 0.8864 - val_loss: 0.6761 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 7/100
# 274/276 [============================>.] - ETA: 0s - loss: 0.3121 - accuracy: 0.9000
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 276/276 [==============================] - 3s 11ms/step - loss: 0.3120 - accuracy: 0.9001 - val_loss: 0.6264 - val_accuracy: 0.7802 - lr: 0.0010
# Epoch 8/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.2473 - accuracy: 0.9241 - val_loss: 0.2875 - val_accuracy: 0.9020 - lr: 5.0000e-04
# Epoch 9/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.2254 - accuracy: 0.9309 - val_loss: 0.3171 - val_accuracy: 0.8972 - lr: 5.0000e-04
# Epoch 10/100
# 275/276 [============================>.] - ETA: 0s - loss: 0.2130 - accuracy: 0.9359
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 276/276 [==============================] - 3s 11ms/step - loss: 0.2131 - accuracy: 0.9359 - val_loss: 0.2926 - val_accuracy: 0.9003 - lr: 5.0000e-04
# Epoch 11/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1957 - accuracy: 0.9420 - val_loss: 0.2222 - val_accuracy: 0.9296 - lr: 2.5000e-04
# Epoch 12/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1828 - accuracy: 0.9466 - val_loss: 0.2206 - val_accuracy: 0.9313 - lr: 2.5000e-04
# Epoch 13/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1775 - accuracy: 0.9482 - val_loss: 0.2062 - val_accuracy: 0.9343 - lr: 2.5000e-04
# Epoch 14/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1737 - accuracy: 0.9506 - val_loss: 0.2032 - val_accuracy: 0.9380 - lr: 2.5000e-04
# Epoch 15/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1687 - accuracy: 0.9519 - val_loss: 0.2077 - val_accuracy: 0.9373 - lr: 2.5000e-04
# Epoch 16/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1625 - accuracy: 0.9531 - val_loss: 0.1944 - val_accuracy: 0.9399 - lr: 2.5000e-04
# Epoch 17/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1574 - accuracy: 0.9547 - val_loss: 0.2099 - val_accuracy: 0.9323 - lr: 2.5000e-04
# Epoch 18/100
# 275/276 [============================>.] - ETA: 0s - loss: 0.1479 - accuracy: 0.9580
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1479 - accuracy: 0.9580 - val_loss: 0.2098 - val_accuracy: 0.9363 - lr: 2.5000e-04
# Epoch 19/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1406 - accuracy: 0.9611 - val_loss: 0.1800 - val_accuracy: 0.9441 - lr: 1.2500e-04
# Epoch 20/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1372 - accuracy: 0.9633 - val_loss: 0.1872 - val_accuracy: 0.9409 - lr: 1.2500e-04
# Epoch 21/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1342 - accuracy: 0.9633 - val_loss: 0.1709 - val_accuracy: 0.9493 - lr: 1.2500e-04
# Epoch 22/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1356 - accuracy: 0.9634 - val_loss: 0.1861 - val_accuracy: 0.9434 - lr: 1.2500e-04
# Epoch 23/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1316 - accuracy: 0.9642 - val_loss: 0.1673 - val_accuracy: 0.9505 - lr: 1.2500e-04
# Epoch 24/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1293 - accuracy: 0.9642 - val_loss: 0.1707 - val_accuracy: 0.9492 - lr: 1.2500e-04
# Epoch 25/100
# 274/276 [============================>.] - ETA: 0s - loss: 0.1279 - accuracy: 0.9651
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1280 - accuracy: 0.9652 - val_loss: 0.1716 - val_accuracy: 0.9465 - lr: 1.2500e-04
# Epoch 26/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1228 - accuracy: 0.9674 - val_loss: 0.1644 - val_accuracy: 0.9489 - lr: 6.2500e-05
# Epoch 27/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1211 - accuracy: 0.9690 - val_loss: 0.1610 - val_accuracy: 0.9512 - lr: 6.2500e-05
# Epoch 28/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1199 - accuracy: 0.9684 - val_loss: 0.1663 - val_accuracy: 0.9513 - lr: 6.2500e-05
# Epoch 29/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1199 - accuracy: 0.9682 - val_loss: 0.1597 - val_accuracy: 0.9507 - lr: 6.2500e-05
# Epoch 30/100
# 273/276 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.9678
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1210 - accuracy: 0.9678 - val_loss: 0.1613 - val_accuracy: 0.9513 - lr: 6.2500e-05
# Epoch 31/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1157 - accuracy: 0.9705 - val_loss: 0.1560 - val_accuracy: 0.9530 - lr: 3.1250e-05
# Epoch 32/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1166 - accuracy: 0.9700 - val_loss: 0.1569 - val_accuracy: 0.9522 - lr: 3.1250e-05
# Epoch 33/100
# 274/276 [============================>.] - ETA: 0s - loss: 0.1155 - accuracy: 0.9700
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1158 - accuracy: 0.9699 - val_loss: 0.1565 - val_accuracy: 0.9521 - lr: 3.1250e-05
# Epoch 34/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1140 - accuracy: 0.9698 - val_loss: 0.1569 - val_accuracy: 0.9523 - lr: 1.5625e-05
# Epoch 35/100
# 272/276 [============================>.] - ETA: 0s - loss: 0.1138 - accuracy: 0.9705
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1e-05.
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1139 - accuracy: 0.9705 - val_loss: 0.1548 - val_accuracy: 0.9529 - lr: 1.5625e-05
# Epoch 36/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1136 - accuracy: 0.9706 - val_loss: 0.1543 - val_accuracy: 0.9535 - lr: 1.0000e-05
# Epoch 37/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1125 - accuracy: 0.9710 - val_loss: 0.1553 - val_accuracy: 0.9525 - lr: 1.0000e-05
# Epoch 38/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1137 - accuracy: 0.9710 - val_loss: 0.1551 - val_accuracy: 0.9522 - lr: 1.0000e-05
# Epoch 39/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1142 - accuracy: 0.9709 - val_loss: 0.1543 - val_accuracy: 0.9535 - lr: 1.0000e-05
# Epoch 40/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1119 - accuracy: 0.9717 - val_loss: 0.1554 - val_accuracy: 0.9530 - lr: 1.0000e-05
# Epoch 41/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1117 - accuracy: 0.9722 - val_loss: 0.1541 - val_accuracy: 0.9536 - lr: 1.0000e-05
# Epoch 42/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1123 - accuracy: 0.9716 - val_loss: 0.1534 - val_accuracy: 0.9535 - lr: 1.0000e-05
# Epoch 43/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1126 - accuracy: 0.9713 - val_loss: 0.1536 - val_accuracy: 0.9540 - lr: 1.0000e-05
# Epoch 44/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1111 - accuracy: 0.9715 - val_loss: 0.1534 - val_accuracy: 0.9536 - lr: 1.0000e-05
# Epoch 45/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1116 - accuracy: 0.9720 - val_loss: 0.1545 - val_accuracy: 0.9530 - lr: 1.0000e-05
# Epoch 46/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1114 - accuracy: 0.9724 - val_loss: 0.1539 - val_accuracy: 0.9536 - lr: 1.0000e-05
# Epoch 47/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1121 - accuracy: 0.9710 - val_loss: 0.1531 - val_accuracy: 0.9536 - lr: 1.0000e-05
# Epoch 48/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.1097 - accuracy: 0.9729 - val_loss: 0.1532 - val_accuracy: 0.9532 - lr: 1.0000e-05
# Epoch 49/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1098 - accuracy: 0.9719 - val_loss: 0.1539 - val_accuracy: 0.9540 - lr: 1.0000e-05
# Epoch 50/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1114 - accuracy: 0.9720 - val_loss: 0.1535 - val_accuracy: 0.9536 - lr: 1.0000e-05
# Epoch 51/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1085 - accuracy: 0.9720 - val_loss: 0.1530 - val_accuracy: 0.9551 - lr: 1.0000e-05
# Epoch 52/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1109 - accuracy: 0.9720 - val_loss: 0.1525 - val_accuracy: 0.9538 - lr: 1.0000e-05
# Epoch 53/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1116 - accuracy: 0.9719 - val_loss: 0.1531 - val_accuracy: 0.9542 - lr: 1.0000e-05
# Epoch 54/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1090 - accuracy: 0.9724 - val_loss: 0.1529 - val_accuracy: 0.9536 - lr: 1.0000e-05
# Epoch 55/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1090 - accuracy: 0.9726 - val_loss: 0.1524 - val_accuracy: 0.9542 - lr: 1.0000e-05
# Epoch 56/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1098 - accuracy: 0.9718 - val_loss: 0.1526 - val_accuracy: 0.9537 - lr: 1.0000e-05
# Epoch 57/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1104 - accuracy: 0.9721 - val_loss: 0.1522 - val_accuracy: 0.9549 - lr: 1.0000e-05
# Epoch 58/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1092 - accuracy: 0.9725 - val_loss: 0.1526 - val_accuracy: 0.9546 - lr: 1.0000e-05
# Epoch 59/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1075 - accuracy: 0.9730 - val_loss: 0.1520 - val_accuracy: 0.9538 - lr: 1.0000e-05
# Epoch 60/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1086 - accuracy: 0.9726 - val_loss: 0.1512 - val_accuracy: 0.9555 - lr: 1.0000e-05
# Epoch 61/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1085 - accuracy: 0.9725 - val_loss: 0.1522 - val_accuracy: 0.9549 - lr: 1.0000e-05
# Epoch 62/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1089 - accuracy: 0.9722 - val_loss: 0.1510 - val_accuracy: 0.9547 - lr: 1.0000e-05
# Epoch 63/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1069 - accuracy: 0.9721 - val_loss: 0.1518 - val_accuracy: 0.9543 - lr: 1.0000e-05
# Epoch 64/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1074 - accuracy: 0.9727 - val_loss: 0.1514 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 65/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1083 - accuracy: 0.9733 - val_loss: 0.1509 - val_accuracy: 0.9546 - lr: 1.0000e-05
# Epoch 66/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1084 - accuracy: 0.9735 - val_loss: 0.1513 - val_accuracy: 0.9548 - lr: 1.0000e-05
# Epoch 67/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1092 - accuracy: 0.9731 - val_loss: 0.1516 - val_accuracy: 0.9538 - lr: 1.0000e-05
# Epoch 68/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1073 - accuracy: 0.9736 - val_loss: 0.1516 - val_accuracy: 0.9544 - lr: 1.0000e-05
# Epoch 69/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1073 - accuracy: 0.9726 - val_loss: 0.1516 - val_accuracy: 0.9547 - lr: 1.0000e-05
# Epoch 70/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1062 - accuracy: 0.9731 - val_loss: 0.1524 - val_accuracy: 0.9545 - lr: 1.0000e-05
# Epoch 71/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1059 - accuracy: 0.9730 - val_loss: 0.1506 - val_accuracy: 0.9546 - lr: 1.0000e-05
# Epoch 72/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1062 - accuracy: 0.9736 - val_loss: 0.1505 - val_accuracy: 0.9547 - lr: 1.0000e-05
# Epoch 73/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1064 - accuracy: 0.9732 - val_loss: 0.1509 - val_accuracy: 0.9560 - lr: 1.0000e-05
# Epoch 74/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1084 - accuracy: 0.9731 - val_loss: 0.1510 - val_accuracy: 0.9553 - lr: 1.0000e-05
# Epoch 75/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1073 - accuracy: 0.9731 - val_loss: 0.1501 - val_accuracy: 0.9551 - lr: 1.0000e-05
# Epoch 76/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1061 - accuracy: 0.9733 - val_loss: 0.1514 - val_accuracy: 0.9557 - lr: 1.0000e-05
# Epoch 77/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1060 - accuracy: 0.9743 - val_loss: 0.1501 - val_accuracy: 0.9547 - lr: 1.0000e-05
# Epoch 78/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1054 - accuracy: 0.9737 - val_loss: 0.1496 - val_accuracy: 0.9552 - lr: 1.0000e-05
# Epoch 79/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1078 - accuracy: 0.9735 - val_loss: 0.1511 - val_accuracy: 0.9543 - lr: 1.0000e-05
# Epoch 80/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1081 - accuracy: 0.9725 - val_loss: 0.1501 - val_accuracy: 0.9547 - lr: 1.0000e-05
# Epoch 81/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1062 - accuracy: 0.9731 - val_loss: 0.1498 - val_accuracy: 0.9552 - lr: 1.0000e-05
# Epoch 82/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1059 - accuracy: 0.9728 - val_loss: 0.1506 - val_accuracy: 0.9547 - lr: 1.0000e-05
# Epoch 83/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1071 - accuracy: 0.9724 - val_loss: 0.1514 - val_accuracy: 0.9542 - lr: 1.0000e-05
# Epoch 84/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1052 - accuracy: 0.9736 - val_loss: 0.1491 - val_accuracy: 0.9546 - lr: 1.0000e-05
# Epoch 85/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1058 - accuracy: 0.9736 - val_loss: 0.1503 - val_accuracy: 0.9558 - lr: 1.0000e-05
# Epoch 86/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1030 - accuracy: 0.9748 - val_loss: 0.1498 - val_accuracy: 0.9546 - lr: 1.0000e-05
# Epoch 87/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1048 - accuracy: 0.9738 - val_loss: 0.1498 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 88/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1049 - accuracy: 0.9731 - val_loss: 0.1496 - val_accuracy: 0.9552 - lr: 1.0000e-05
# Epoch 89/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1030 - accuracy: 0.9746 - val_loss: 0.1492 - val_accuracy: 0.9565 - lr: 1.0000e-05
# Epoch 90/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1032 - accuracy: 0.9744 - val_loss: 0.1497 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 91/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1020 - accuracy: 0.9754 - val_loss: 0.1492 - val_accuracy: 0.9551 - lr: 1.0000e-05
# Epoch 92/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1047 - accuracy: 0.9737 - val_loss: 0.1500 - val_accuracy: 0.9546 - lr: 1.0000e-05
# Epoch 93/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1046 - accuracy: 0.9741 - val_loss: 0.1492 - val_accuracy: 0.9559 - lr: 1.0000e-05
# Epoch 94/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1038 - accuracy: 0.9738 - val_loss: 0.1498 - val_accuracy: 0.9553 - lr: 1.0000e-05
# Epoch 95/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1037 - accuracy: 0.9745 - val_loss: 0.1491 - val_accuracy: 0.9549 - lr: 1.0000e-05
# Epoch 96/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1025 - accuracy: 0.9743 - val_loss: 0.1482 - val_accuracy: 0.9560 - lr: 1.0000e-05
# Epoch 97/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1039 - accuracy: 0.9749 - val_loss: 0.1480 - val_accuracy: 0.9570 - lr: 1.0000e-05
# Epoch 98/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1044 - accuracy: 0.9747 - val_loss: 0.1485 - val_accuracy: 0.9563 - lr: 1.0000e-05
# Epoch 99/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1030 - accuracy: 0.9750 - val_loss: 0.1474 - val_accuracy: 0.9557 - lr: 1.0000e-05
# Epoch 100/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1040 - accuracy: 0.9742 - val_loss: 0.1494 - val_accuracy: 0.9549 - lr: 1.0000e-05

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=100 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction,EarlyStopping(monitor='loss', patience=10, restore_best_weights = True)])
# Out:
# Epoch 1/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1019 - accuracy: 0.9750 - val_loss: 0.1482 - val_accuracy: 0.9558 - lr: 1.0000e-05
# Epoch 2/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1025 - accuracy: 0.9740 - val_loss: 0.1483 - val_accuracy: 0.9561 - lr: 1.0000e-05
# Epoch 3/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1040 - accuracy: 0.9739 - val_loss: 0.1478 - val_accuracy: 0.9568 - lr: 1.0000e-05
# Epoch 4/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1021 - accuracy: 0.9748 - val_loss: 0.1487 - val_accuracy: 0.9559 - lr: 1.0000e-05
# Epoch 5/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1028 - accuracy: 0.9744 - val_loss: 0.1484 - val_accuracy: 0.9561 - lr: 1.0000e-05
# Epoch 6/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1017 - accuracy: 0.9757 - val_loss: 0.1479 - val_accuracy: 0.9564 - lr: 1.0000e-05
# Epoch 7/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1015 - accuracy: 0.9749 - val_loss: 0.1489 - val_accuracy: 0.9548 - lr: 1.0000e-05
# Epoch 8/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1014 - accuracy: 0.9750 - val_loss: 0.1490 - val_accuracy: 0.9560 - lr: 1.0000e-05
# Epoch 9/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1033 - accuracy: 0.9744 - val_loss: 0.1480 - val_accuracy: 0.9563 - lr: 1.0000e-05
# Epoch 10/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1024 - accuracy: 0.9743 - val_loss: 0.1475 - val_accuracy: 0.9561 - lr: 1.0000e-05
# Epoch 11/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1023 - accuracy: 0.9741 - val_loss: 0.1479 - val_accuracy: 0.9564 - lr: 1.0000e-05
# Epoch 12/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1014 - accuracy: 0.9749 - val_loss: 0.1465 - val_accuracy: 0.9565 - lr: 1.0000e-05
# Epoch 13/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1010 - accuracy: 0.9753 - val_loss: 0.1476 - val_accuracy: 0.9555 - lr: 1.0000e-05
# Epoch 14/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1026 - accuracy: 0.9745 - val_loss: 0.1470 - val_accuracy: 0.9563 - lr: 1.0000e-05
# Epoch 15/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1012 - accuracy: 0.9748 - val_loss: 0.1462 - val_accuracy: 0.9575 - lr: 1.0000e-05
# Epoch 16/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1014 - accuracy: 0.9750 - val_loss: 0.1465 - val_accuracy: 0.9559 - lr: 1.0000e-05
# Epoch 17/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1015 - accuracy: 0.9751 - val_loss: 0.1476 - val_accuracy: 0.9562 - lr: 1.0000e-05
# Epoch 18/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1007 - accuracy: 0.9744 - val_loss: 0.1457 - val_accuracy: 0.9570 - lr: 1.0000e-05
# Epoch 19/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1009 - accuracy: 0.9759 - val_loss: 0.1471 - val_accuracy: 0.9575 - lr: 1.0000e-05
# Epoch 20/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1032 - accuracy: 0.9740 - val_loss: 0.1465 - val_accuracy: 0.9560 - lr: 1.0000e-05
# Epoch 21/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1014 - accuracy: 0.9749 - val_loss: 0.1462 - val_accuracy: 0.9576 - lr: 1.0000e-05
# Epoch 22/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1012 - accuracy: 0.9742 - val_loss: 0.1458 - val_accuracy: 0.9570 - lr: 1.0000e-05
# Epoch 23/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1017 - accuracy: 0.9752 - val_loss: 0.1457 - val_accuracy: 0.9579 - lr: 1.0000e-05
# Epoch 24/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0999 - accuracy: 0.9759 - val_loss: 0.1455 - val_accuracy: 0.9569 - lr: 1.0000e-05
# Epoch 25/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1015 - accuracy: 0.9747 - val_loss: 0.1473 - val_accuracy: 0.9567 - lr: 1.0000e-05
# Epoch 26/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1010 - accuracy: 0.9755 - val_loss: 0.1468 - val_accuracy: 0.9567 - lr: 1.0000e-05
# Epoch 27/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0997 - accuracy: 0.9748 - val_loss: 0.1467 - val_accuracy: 0.9565 - lr: 1.0000e-05
# Epoch 28/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1001 - accuracy: 0.9754 - val_loss: 0.1458 - val_accuracy: 0.9570 - lr: 1.0000e-05
# Epoch 29/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1007 - accuracy: 0.9748 - val_loss: 0.1463 - val_accuracy: 0.9559 - lr: 1.0000e-05
# Epoch 30/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0993 - accuracy: 0.9754 - val_loss: 0.1461 - val_accuracy: 0.9566 - lr: 1.0000e-05
# Epoch 31/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0995 - accuracy: 0.9759 - val_loss: 0.1449 - val_accuracy: 0.9572 - lr: 1.0000e-05
# Epoch 32/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0995 - accuracy: 0.9754 - val_loss: 0.1457 - val_accuracy: 0.9570 - lr: 1.0000e-05
# Epoch 33/100
# 276/276 [==============================] - 3s 13ms/step - loss: 0.0995 - accuracy: 0.9751 - val_loss: 0.1472 - val_accuracy: 0.9562 - lr: 1.0000e-05
# Epoch 34/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0987 - accuracy: 0.9763 - val_loss: 0.1452 - val_accuracy: 0.9569 - lr: 1.0000e-05
# Epoch 35/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0991 - accuracy: 0.9750 - val_loss: 0.1453 - val_accuracy: 0.9565 - lr: 1.0000e-05
# Epoch 36/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0969 - accuracy: 0.9771 - val_loss: 0.1449 - val_accuracy: 0.9578 - lr: 1.0000e-05
# Epoch 37/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0988 - accuracy: 0.9757 - val_loss: 0.1447 - val_accuracy: 0.9566 - lr: 1.0000e-05
# Epoch 38/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0979 - accuracy: 0.9769 - val_loss: 0.1458 - val_accuracy: 0.9565 - lr: 1.0000e-05
# Epoch 39/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0981 - accuracy: 0.9767 - val_loss: 0.1456 - val_accuracy: 0.9556 - lr: 1.0000e-05
# Epoch 40/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0974 - accuracy: 0.9762 - val_loss: 0.1450 - val_accuracy: 0.9583 - lr: 1.0000e-05
# Epoch 41/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0982 - accuracy: 0.9767 - val_loss: 0.1448 - val_accuracy: 0.9570 - lr: 1.0000e-05
# Epoch 42/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0981 - accuracy: 0.9759 - val_loss: 0.1444 - val_accuracy: 0.9569 - lr: 1.0000e-05
# Epoch 43/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0979 - accuracy: 0.9759 - val_loss: 0.1435 - val_accuracy: 0.9574 - lr: 1.0000e-05
# Epoch 44/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0981 - accuracy: 0.9758 - val_loss: 0.1441 - val_accuracy: 0.9579 - lr: 1.0000e-05
# Epoch 45/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0982 - accuracy: 0.9759 - val_loss: 0.1440 - val_accuracy: 0.9574 - lr: 1.0000e-05
# Epoch 46/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0962 - accuracy: 0.9764 - val_loss: 0.1445 - val_accuracy: 0.9582 - lr: 1.0000e-05
# Epoch 47/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0966 - accuracy: 0.9771 - val_loss: 0.1444 - val_accuracy: 0.9579 - lr: 1.0000e-05
# Epoch 48/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0957 - accuracy: 0.9765 - val_loss: 0.1448 - val_accuracy: 0.9565 - lr: 1.0000e-05
# Epoch 49/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0976 - accuracy: 0.9763 - val_loss: 0.1444 - val_accuracy: 0.9567 - lr: 1.0000e-05
# Epoch 50/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0970 - accuracy: 0.9771 - val_loss: 0.1443 - val_accuracy: 0.9574 - lr: 1.0000e-05
# Epoch 51/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0989 - accuracy: 0.9747 - val_loss: 0.1440 - val_accuracy: 0.9571 - lr: 1.0000e-05
# Epoch 52/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0967 - accuracy: 0.9758 - val_loss: 0.1444 - val_accuracy: 0.9575 - lr: 1.0000e-05
# Epoch 53/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0957 - accuracy: 0.9762 - val_loss: 0.1452 - val_accuracy: 0.9572 - lr: 1.0000e-05
# Epoch 54/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.0965 - accuracy: 0.9766 - val_loss: 0.1436 - val_accuracy: 0.9584 - lr: 1.0000e-05
# Epoch 55/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0964 - accuracy: 0.9759 - val_loss: 0.1437 - val_accuracy: 0.9579 - lr: 1.0000e-05
# Epoch 56/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0976 - accuracy: 0.9754 - val_loss: 0.1442 - val_accuracy: 0.9578 - lr: 1.0000e-05
# Epoch 57/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0983 - accuracy: 0.9759 - val_loss: 0.1453 - val_accuracy: 0.9575 - lr: 1.0000e-05
# Epoch 58/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0968 - accuracy: 0.9761 - val_loss: 0.1453 - val_accuracy: 0.9578 - lr: 1.0000e-05
# Epoch 59/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0975 - accuracy: 0.9762 - val_loss: 0.1445 - val_accuracy: 0.9576 - lr: 1.0000e-05
# Epoch 60/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0955 - accuracy: 0.9765 - val_loss: 0.1437 - val_accuracy: 0.9583 - lr: 1.0000e-05
# Epoch 61/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0952 - accuracy: 0.9770 - val_loss: 0.1441 - val_accuracy: 0.9587 - lr: 1.0000e-05
# Epoch 62/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0943 - accuracy: 0.9771 - val_loss: 0.1438 - val_accuracy: 0.9588 - lr: 1.0000e-05
# Epoch 63/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0955 - accuracy: 0.9766 - val_loss: 0.1433 - val_accuracy: 0.9582 - lr: 1.0000e-05
# Epoch 64/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0956 - accuracy: 0.9764 - val_loss: 0.1437 - val_accuracy: 0.9578 - lr: 1.0000e-05
# Epoch 65/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0953 - accuracy: 0.9769 - val_loss: 0.1430 - val_accuracy: 0.9570 - lr: 1.0000e-05
# Epoch 66/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0958 - accuracy: 0.9768 - val_loss: 0.1439 - val_accuracy: 0.9579 - lr: 1.0000e-05
# Epoch 67/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0968 - accuracy: 0.9761 - val_loss: 0.1432 - val_accuracy: 0.9579 - lr: 1.0000e-05
# Epoch 68/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0947 - accuracy: 0.9768 - val_loss: 0.1447 - val_accuracy: 0.9570 - lr: 1.0000e-05
# Epoch 69/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0954 - accuracy: 0.9768 - val_loss: 0.1424 - val_accuracy: 0.9593 - lr: 1.0000e-05
# Epoch 70/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0949 - accuracy: 0.9770 - val_loss: 0.1429 - val_accuracy: 0.9584 - lr: 1.0000e-05
# Epoch 71/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0972 - accuracy: 0.9754 - val_loss: 0.1422 - val_accuracy: 0.9578 - lr: 1.0000e-05
# Epoch 72/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0949 - accuracy: 0.9769 - val_loss: 0.1428 - val_accuracy: 0.9586 - lr: 1.0000e-05

# %%
import tensorflow as tf
model.save_weights('weights\DCNN.h5')

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 3s 3ms/step - loss: 0.0767 - accuracy: 0.9821
# 367/367 [==============================] - 1s 3ms/step - loss: 0.1438 - accuracy: 0.9588
# Train Loss:  0.07672716677188873
# Train Accuracy:  0.9821027517318726
# --------------------
# Test Loss:  0.14377261698246002
# Test Accuracy:  0.9587523341178894

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 1s 2ms/step

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#model.save('Skin Cancer.h5')

# %%
from keras import backend as K
import gc

del model

K.clear_session()
gc.collect()
# Out:
# 19009

# %%
#You need to install numba using 'pip install numba'

from numba import cuda

cuda.select_device(0)
cuda.close()
