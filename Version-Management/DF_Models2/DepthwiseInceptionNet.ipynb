# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
data_dir = r'F:\MV\Dataset\HAM1000\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6], dtype=int64)

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Concatenate, Conv2D, MaxPooling2D, AveragePooling2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense

def depthwise_inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Inception module 1
    tower_1 = Conv2D(64, (1, 1), padding='same', activation='relu')(input_tensor)

    tower_2 = Conv2D(64, (1, 1), padding='same', activation='relu')(input_tensor)
    tower_2 = DepthwiseConv2D(3, padding='same', activation='relu')(tower_2)

    tower_3 = Conv2D(64, (1, 1), padding='same', activation='relu')(input_tensor)
    tower_3 = DepthwiseConv2D(5, padding='same', activation='relu')(tower_3)

    tower_4 = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(input_tensor)
    tower_4 = Conv2D(64, (1, 1), padding='same', activation='relu')(tower_4)

    inception_block_1 = Concatenate(axis=-1)([tower_1, tower_2, tower_3, tower_4])

    # Inception module 2
    tower_5 = Conv2D(128, (1, 1), padding='same', activation='relu')(inception_block_1)

    tower_6 = Conv2D(128, (1, 1), padding='same', activation='relu')(inception_block_1)
    tower_6 = DepthwiseConv2D(3, padding='same', activation='relu')(tower_6)

    tower_7 = Conv2D(128, (1, 1), padding='same', activation='relu')(inception_block_1)
    tower_7 = DepthwiseConv2D(5, padding='same', activation='relu')(tower_7)

    tower_8 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(inception_block_1)
    tower_8 = Conv2D(128, (1, 1), padding='same', activation='relu')(tower_8)

    inception_block_2 = Concatenate(axis=-1)([tower_5, tower_6, tower_7, tower_8])

    # Global average pooling and dense layers
    x = GlobalAveragePooling2D()(inception_block_2)
    output_tensor = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=output_tensor)

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the depthwise separable InceptionNet-style CNN model
model = depthwise_inception_net(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 3)]  0           []
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 64)   256         ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 64)   256         ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 3)    0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 28, 28, 64)   256         ['input_1[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 28, 28, 64)  640         ['conv2d_1[0][0]']
#  v2D)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 28, 28, 64)  1664        ['conv2d_2[0][0]']
#  onv2D)
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   256         ['max_pooling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 256)  0           ['conv2d[0][0]',
#                                                                   'depthwise_conv2d[0][0]',
#                                                                   'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  average_pooling2d (AveragePool  (None, 28, 28, 256)  0          ['concatenate[0][0]']
#  ing2D)
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 28, 28, 128)  1280       ['conv2d_5[0][0]']
#  onv2D)
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 28, 28, 128)  3328       ['conv2d_6[0][0]']
#  onv2D)
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 128)  32896       ['average_pooling2d[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 512)  0           ['conv2d_4[0][0]',
#                                                                   'depthwise_conv2d_2[0][0]',
#                                                                   'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['concatenate_1[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 7)            3591        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 143,111
# Trainable params: 143,111
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.backend.clear_session()

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=200,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[EarlyStopping(monitor='loss', patience=10, restore_best_weights = True)])
# Out:
# Epoch 1/200
# 276/276 [==============================] - 21s 73ms/step - loss: 2.4410 - accuracy: 0.3265 - val_loss: 6.5446 - val_accuracy: 0.1747
# Epoch 2/200
# 276/276 [==============================] - 20s 72ms/step - loss: 1.7656 - accuracy: 0.4034 - val_loss: 1.4790 - val_accuracy: 0.4301
# Epoch 3/200
# 276/276 [==============================] - 20s 71ms/step - loss: 1.4706 - accuracy: 0.4485 - val_loss: 1.3714 - val_accuracy: 0.4875
# Epoch 4/200
# 276/276 [==============================] - 19s 71ms/step - loss: 1.3298 - accuracy: 0.4897 - val_loss: 3.1767 - val_accuracy: 0.2903
# Epoch 5/200
# 276/276 [==============================] - 20s 71ms/step - loss: 1.2555 - accuracy: 0.5291 - val_loss: 3.5823 - val_accuracy: 0.2799
# Epoch 6/200
# 276/276 [==============================] - 20s 72ms/step - loss: 1.2454 - accuracy: 0.5383 - val_loss: 4.4663 - val_accuracy: 0.2243
# Epoch 7/200
# 276/276 [==============================] - 20s 72ms/step - loss: 1.2071 - accuracy: 0.5609 - val_loss: 1.1005 - val_accuracy: 0.5812
# Epoch 8/200
# 276/276 [==============================] - 20s 71ms/step - loss: 1.0653 - accuracy: 0.5907 - val_loss: 1.6178 - val_accuracy: 0.4432
# Epoch 9/200
# 276/276 [==============================] - 20s 71ms/step - loss: 1.0386 - accuracy: 0.6047 - val_loss: 3.3018 - val_accuracy: 0.3435
# Epoch 10/200
# 276/276 [==============================] - 20s 71ms/step - loss: 1.1179 - accuracy: 0.5987 - val_loss: 1.4486 - val_accuracy: 0.4769
# Epoch 11/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.9568 - accuracy: 0.6376 - val_loss: 1.2482 - val_accuracy: 0.5418
# Epoch 12/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.9254 - accuracy: 0.6507 - val_loss: 1.1351 - val_accuracy: 0.6198
# Epoch 13/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.8944 - accuracy: 0.6640 - val_loss: 1.9383 - val_accuracy: 0.3901
# Epoch 14/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.9110 - accuracy: 0.6633 - val_loss: 0.8654 - val_accuracy: 0.6975
# Epoch 15/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.8205 - accuracy: 0.6951 - val_loss: 1.0794 - val_accuracy: 0.6065
# Epoch 16/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.8125 - accuracy: 0.6986 - val_loss: 1.9467 - val_accuracy: 0.3757
# Epoch 17/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.8182 - accuracy: 0.6984 - val_loss: 0.7898 - val_accuracy: 0.7081
# Epoch 18/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.7541 - accuracy: 0.7217 - val_loss: 1.1544 - val_accuracy: 0.6099
# Epoch 19/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.7782 - accuracy: 0.7104 - val_loss: 1.1904 - val_accuracy: 0.5787
# Epoch 20/200
# 276/276 [==============================] - 20s 74ms/step - loss: 0.7198 - accuracy: 0.7376 - val_loss: 0.7825 - val_accuracy: 0.7029
# Epoch 21/200
# 276/276 [==============================] - 21s 74ms/step - loss: 0.6757 - accuracy: 0.7508 - val_loss: 0.6607 - val_accuracy: 0.7624
# Epoch 22/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.6580 - accuracy: 0.7575 - val_loss: 0.7066 - val_accuracy: 0.7276
# Epoch 23/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.6332 - accuracy: 0.7647 - val_loss: 0.8412 - val_accuracy: 0.6951
# Epoch 24/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.6612 - accuracy: 0.7567 - val_loss: 0.6585 - val_accuracy: 0.7598
# Epoch 25/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.6018 - accuracy: 0.7796 - val_loss: 0.6562 - val_accuracy: 0.7440
# Epoch 26/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.5914 - accuracy: 0.7805 - val_loss: 0.7772 - val_accuracy: 0.6755
# Epoch 27/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.5850 - accuracy: 0.7844 - val_loss: 0.7556 - val_accuracy: 0.7431
# Epoch 28/200
# 276/276 [==============================] - 20s 72ms/step - loss: 0.6132 - accuracy: 0.7792 - val_loss: 1.2926 - val_accuracy: 0.5866
# Epoch 29/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.6204 - accuracy: 0.7766 - val_loss: 0.6779 - val_accuracy: 0.7340
# Epoch 30/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.5635 - accuracy: 0.7940 - val_loss: 0.6152 - val_accuracy: 0.7714
# Epoch 31/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.5350 - accuracy: 0.8046 - val_loss: 0.5742 - val_accuracy: 0.7817
# Epoch 32/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.5081 - accuracy: 0.8142 - val_loss: 0.5447 - val_accuracy: 0.7945
# Epoch 33/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.4981 - accuracy: 0.8176 - val_loss: 0.8564 - val_accuracy: 0.6623
# Epoch 34/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.5317 - accuracy: 0.8075 - val_loss: 0.8204 - val_accuracy: 0.6949
# Epoch 35/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.5116 - accuracy: 0.8131 - val_loss: 0.7890 - val_accuracy: 0.7067
# Epoch 36/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.4879 - accuracy: 0.8236 - val_loss: 0.5824 - val_accuracy: 0.7903
# Epoch 37/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.4721 - accuracy: 0.8277 - val_loss: 0.4880 - val_accuracy: 0.8215
# Epoch 38/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.4458 - accuracy: 0.8394 - val_loss: 0.6578 - val_accuracy: 0.7321
# Epoch 39/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.4423 - accuracy: 0.8367 - val_loss: 0.5145 - val_accuracy: 0.8038
# Epoch 40/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.4392 - accuracy: 0.8397 - val_loss: 0.8272 - val_accuracy: 0.7350
# Epoch 41/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.4503 - accuracy: 0.8382 - val_loss: 0.4968 - val_accuracy: 0.8209
# Epoch 42/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.4039 - accuracy: 0.8552 - val_loss: 0.7258 - val_accuracy: 0.7379
# Epoch 43/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.4821 - accuracy: 0.8297 - val_loss: 0.4503 - val_accuracy: 0.8383
# Epoch 44/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3973 - accuracy: 0.8592 - val_loss: 0.4185 - val_accuracy: 0.8559
# Epoch 45/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3754 - accuracy: 0.8678 - val_loss: 0.6762 - val_accuracy: 0.7556
# Epoch 46/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.4195 - accuracy: 0.8520 - val_loss: 0.4840 - val_accuracy: 0.8367
# Epoch 47/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3597 - accuracy: 0.8740 - val_loss: 0.7593 - val_accuracy: 0.7601
# Epoch 48/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.4032 - accuracy: 0.8597 - val_loss: 0.4243 - val_accuracy: 0.8451
# Epoch 49/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3343 - accuracy: 0.8819 - val_loss: 0.4220 - val_accuracy: 0.8494
# Epoch 50/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3288 - accuracy: 0.8846 - val_loss: 0.5099 - val_accuracy: 0.8117
# Epoch 51/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3413 - accuracy: 0.8801 - val_loss: 0.5313 - val_accuracy: 0.7947
# Epoch 52/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3477 - accuracy: 0.8770 - val_loss: 0.3462 - val_accuracy: 0.8786
# Epoch 53/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3151 - accuracy: 0.8892 - val_loss: 0.3571 - val_accuracy: 0.8798
# Epoch 54/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3005 - accuracy: 0.8958 - val_loss: 0.4581 - val_accuracy: 0.8369
# Epoch 55/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3157 - accuracy: 0.8902 - val_loss: 0.3487 - val_accuracy: 0.8717
# Epoch 56/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.2898 - accuracy: 0.8997 - val_loss: 0.6347 - val_accuracy: 0.8105
# Epoch 57/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3144 - accuracy: 0.8907 - val_loss: 0.6466 - val_accuracy: 0.7548
# Epoch 58/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.3179 - accuracy: 0.8928 - val_loss: 0.3420 - val_accuracy: 0.8807
# Epoch 59/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.2603 - accuracy: 0.9131 - val_loss: 0.2955 - val_accuracy: 0.8979
# Epoch 60/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.2586 - accuracy: 0.9111 - val_loss: 0.3496 - val_accuracy: 0.8753
# Epoch 61/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.2559 - accuracy: 0.9127 - val_loss: 0.3001 - val_accuracy: 0.8912
# Epoch 62/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.2566 - accuracy: 0.9130 - val_loss: 0.3193 - val_accuracy: 0.8889
# Epoch 63/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.2542 - accuracy: 0.9134 - val_loss: 0.5117 - val_accuracy: 0.8426
# Epoch 64/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.2764 - accuracy: 0.9081 - val_loss: 0.3059 - val_accuracy: 0.8913
# Epoch 65/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.2307 - accuracy: 0.9234 - val_loss: 0.2958 - val_accuracy: 0.9068
# Epoch 66/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.2232 - accuracy: 0.9255 - val_loss: 0.5313 - val_accuracy: 0.8278
# Epoch 67/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.2666 - accuracy: 0.9094 - val_loss: 0.3402 - val_accuracy: 0.8896
# Epoch 68/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.2172 - accuracy: 0.9269 - val_loss: 0.4005 - val_accuracy: 0.8510
# Epoch 69/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.2294 - accuracy: 0.9240 - val_loss: 0.2677 - val_accuracy: 0.9083
# Epoch 70/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1997 - accuracy: 0.9349 - val_loss: 0.6235 - val_accuracy: 0.7874
# Epoch 71/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.2596 - accuracy: 0.9143 - val_loss: 0.2358 - val_accuracy: 0.9208
# Epoch 72/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.1992 - accuracy: 0.9349 - val_loss: 0.6646 - val_accuracy: 0.7975
# Epoch 73/200
# 276/276 [==============================] - 20s 74ms/step - loss: 0.3273 - accuracy: 0.8953 - val_loss: 0.3105 - val_accuracy: 0.8976
# Epoch 74/200
# 276/276 [==============================] - 21s 75ms/step - loss: 0.2009 - accuracy: 0.9344 - val_loss: 0.2210 - val_accuracy: 0.9305
# Epoch 75/200
# 276/276 [==============================] - 20s 73ms/step - loss: 0.1787 - accuracy: 0.9419 - val_loss: 0.2218 - val_accuracy: 0.9265
# Epoch 76/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1789 - accuracy: 0.9418 - val_loss: 0.3109 - val_accuracy: 0.8866
# Epoch 77/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1905 - accuracy: 0.9370 - val_loss: 0.2341 - val_accuracy: 0.9292
# Epoch 78/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1733 - accuracy: 0.9433 - val_loss: 0.2923 - val_accuracy: 0.9069
# Epoch 79/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1882 - accuracy: 0.9388 - val_loss: 0.2090 - val_accuracy: 0.9357
# Epoch 80/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1680 - accuracy: 0.9459 - val_loss: 0.3850 - val_accuracy: 0.8935
# Epoch 81/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.1878 - accuracy: 0.9390 - val_loss: 0.5704 - val_accuracy: 0.8085
# Epoch 82/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.2513 - accuracy: 0.9198 - val_loss: 0.2293 - val_accuracy: 0.9268
# Epoch 83/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1585 - accuracy: 0.9480 - val_loss: 0.2120 - val_accuracy: 0.9291
# Epoch 84/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1513 - accuracy: 0.9522 - val_loss: 0.3300 - val_accuracy: 0.8869
# Epoch 85/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1571 - accuracy: 0.9490 - val_loss: 0.1947 - val_accuracy: 0.9401
# Epoch 86/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1506 - accuracy: 0.9504 - val_loss: 0.2148 - val_accuracy: 0.9364
# Epoch 87/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1437 - accuracy: 0.9557 - val_loss: 0.2366 - val_accuracy: 0.9273
# Epoch 88/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1492 - accuracy: 0.9521 - val_loss: 0.2933 - val_accuracy: 0.8940
# Epoch 89/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1434 - accuracy: 0.9525 - val_loss: 0.2199 - val_accuracy: 0.9353
# Epoch 90/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1380 - accuracy: 0.9572 - val_loss: 0.2253 - val_accuracy: 0.9364
# Epoch 91/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.1843 - accuracy: 0.9404 - val_loss: 0.2831 - val_accuracy: 0.9294
# Epoch 92/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1269 - accuracy: 0.9603 - val_loss: 0.1910 - val_accuracy: 0.9462
# Epoch 93/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1301 - accuracy: 0.9594 - val_loss: 0.2066 - val_accuracy: 0.9298
# Epoch 94/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1317 - accuracy: 0.9590 - val_loss: 0.3031 - val_accuracy: 0.8872
# Epoch 95/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1550 - accuracy: 0.9497 - val_loss: 0.2132 - val_accuracy: 0.9406
# Epoch 96/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1250 - accuracy: 0.9587 - val_loss: 0.2512 - val_accuracy: 0.9252
# Epoch 97/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1127 - accuracy: 0.9652 - val_loss: 0.1750 - val_accuracy: 0.9523
# Epoch 98/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1121 - accuracy: 0.9657 - val_loss: 0.1506 - val_accuracy: 0.9583
# Epoch 99/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.1188 - accuracy: 0.9627 - val_loss: 0.1661 - val_accuracy: 0.9501
# Epoch 100/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1042 - accuracy: 0.9682 - val_loss: 0.3807 - val_accuracy: 0.8821
# Epoch 101/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1478 - accuracy: 0.9513 - val_loss: 0.1823 - val_accuracy: 0.9487
# Epoch 102/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0963 - accuracy: 0.9710 - val_loss: 0.1448 - val_accuracy: 0.9591
# Epoch 103/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1032 - accuracy: 0.9678 - val_loss: 0.1455 - val_accuracy: 0.9599
# Epoch 104/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0945 - accuracy: 0.9701 - val_loss: 0.1829 - val_accuracy: 0.9470
# Epoch 105/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.1301 - accuracy: 0.9568 - val_loss: 0.2919 - val_accuracy: 0.9015
# Epoch 106/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1571 - accuracy: 0.9516 - val_loss: 0.1654 - val_accuracy: 0.9583
# Epoch 107/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0923 - accuracy: 0.9710 - val_loss: 0.1458 - val_accuracy: 0.9525
# Epoch 108/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0853 - accuracy: 0.9751 - val_loss: 0.1364 - val_accuracy: 0.9628
# Epoch 109/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0861 - accuracy: 0.9741 - val_loss: 0.2260 - val_accuracy: 0.9361
# Epoch 110/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1444 - accuracy: 0.9543 - val_loss: 0.1426 - val_accuracy: 0.9628
# Epoch 111/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.0892 - accuracy: 0.9725 - val_loss: 0.1525 - val_accuracy: 0.9625
# Epoch 112/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0821 - accuracy: 0.9753 - val_loss: 0.2495 - val_accuracy: 0.9141
# Epoch 113/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0804 - accuracy: 0.9758 - val_loss: 0.1882 - val_accuracy: 0.9468
# Epoch 114/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1289 - accuracy: 0.9591 - val_loss: 0.1845 - val_accuracy: 0.9425
# Epoch 115/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.0838 - accuracy: 0.9755 - val_loss: 0.1988 - val_accuracy: 0.9309
# Epoch 116/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0802 - accuracy: 0.9754 - val_loss: 0.1690 - val_accuracy: 0.9426
# Epoch 117/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0805 - accuracy: 0.9757 - val_loss: 0.1366 - val_accuracy: 0.9640
# Epoch 118/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0708 - accuracy: 0.9798 - val_loss: 0.1409 - val_accuracy: 0.9663
# Epoch 119/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0746 - accuracy: 0.9767 - val_loss: 0.1319 - val_accuracy: 0.9668
# Epoch 120/200
# 276/276 [==============================] - 20s 74ms/step - loss: 0.1475 - accuracy: 0.9549 - val_loss: 0.1901 - val_accuracy: 0.9478
# Epoch 121/200
# 276/276 [==============================] - 20s 73ms/step - loss: 0.0932 - accuracy: 0.9717 - val_loss: 0.1895 - val_accuracy: 0.9432
# Epoch 122/200
# 276/276 [==============================] - 20s 74ms/step - loss: 0.0708 - accuracy: 0.9788 - val_loss: 0.1230 - val_accuracy: 0.9685
# Epoch 123/200
# 276/276 [==============================] - 20s 74ms/step - loss: 0.0677 - accuracy: 0.9795 - val_loss: 0.1269 - val_accuracy: 0.9706
# Epoch 124/200
# 276/276 [==============================] - 20s 73ms/step - loss: 0.0749 - accuracy: 0.9770 - val_loss: 0.2040 - val_accuracy: 0.9417
# Epoch 125/200
# 276/276 [==============================] - 20s 73ms/step - loss: 0.0796 - accuracy: 0.9753 - val_loss: 0.1834 - val_accuracy: 0.9569
# Epoch 126/200
# 276/276 [==============================] - 20s 74ms/step - loss: 0.0724 - accuracy: 0.9767 - val_loss: 0.1634 - val_accuracy: 0.9542
# Epoch 127/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0850 - accuracy: 0.9744 - val_loss: 0.1538 - val_accuracy: 0.9633
# Epoch 128/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.0666 - accuracy: 0.9796 - val_loss: 0.1237 - val_accuracy: 0.9697
# Epoch 129/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0621 - accuracy: 0.9815 - val_loss: 0.5920 - val_accuracy: 0.8543
# Epoch 130/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1421 - accuracy: 0.9591 - val_loss: 0.1076 - val_accuracy: 0.9727
# Epoch 131/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0552 - accuracy: 0.9843 - val_loss: 0.1270 - val_accuracy: 0.9698
# Epoch 132/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0535 - accuracy: 0.9845 - val_loss: 0.1165 - val_accuracy: 0.9674
# Epoch 133/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0602 - accuracy: 0.9823 - val_loss: 0.1299 - val_accuracy: 0.9684
# Epoch 134/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.0737 - accuracy: 0.9772 - val_loss: 0.1417 - val_accuracy: 0.9660
# Epoch 135/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0569 - accuracy: 0.9835 - val_loss: 0.1078 - val_accuracy: 0.9727
# Epoch 136/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0820 - accuracy: 0.9740 - val_loss: 0.2148 - val_accuracy: 0.9446
# Epoch 137/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0706 - accuracy: 0.9776 - val_loss: 0.1424 - val_accuracy: 0.9660
# Epoch 138/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0594 - accuracy: 0.9826 - val_loss: 0.1321 - val_accuracy: 0.9615
# Epoch 139/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0532 - accuracy: 0.9842 - val_loss: 0.1990 - val_accuracy: 0.9378
# Epoch 140/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1131 - accuracy: 0.9646 - val_loss: 0.2883 - val_accuracy: 0.9149
# Epoch 141/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0620 - accuracy: 0.9813 - val_loss: 0.1385 - val_accuracy: 0.9668
# Epoch 142/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0409 - accuracy: 0.9895 - val_loss: 0.1090 - val_accuracy: 0.9759
# Epoch 143/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0573 - accuracy: 0.9825 - val_loss: 0.6714 - val_accuracy: 0.8325
# Epoch 144/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1916 - accuracy: 0.9499 - val_loss: 0.1054 - val_accuracy: 0.9750
# Epoch 145/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0403 - accuracy: 0.9892 - val_loss: 0.1106 - val_accuracy: 0.9723
# Epoch 146/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0368 - accuracy: 0.9907 - val_loss: 0.0963 - val_accuracy: 0.9784
# Epoch 147/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0365 - accuracy: 0.9907 - val_loss: 0.1187 - val_accuracy: 0.9710
# Epoch 148/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0411 - accuracy: 0.9893 - val_loss: 0.1104 - val_accuracy: 0.9764
# Epoch 149/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.0814 - accuracy: 0.9737 - val_loss: 0.1151 - val_accuracy: 0.9710
# Epoch 150/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0687 - accuracy: 0.9780 - val_loss: 0.4247 - val_accuracy: 0.8737
# Epoch 151/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0521 - accuracy: 0.9844 - val_loss: 0.1191 - val_accuracy: 0.9721
# Epoch 152/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0412 - accuracy: 0.9883 - val_loss: 0.1082 - val_accuracy: 0.9712
# Epoch 153/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0359 - accuracy: 0.9906 - val_loss: 0.1171 - val_accuracy: 0.9731
# Epoch 154/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0398 - accuracy: 0.9884 - val_loss: 0.2076 - val_accuracy: 0.9369
# Epoch 155/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.1059 - accuracy: 0.9660 - val_loss: 0.1717 - val_accuracy: 0.9630
# Epoch 156/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0617 - accuracy: 0.9807 - val_loss: 0.1199 - val_accuracy: 0.9734
# Epoch 157/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0388 - accuracy: 0.9887 - val_loss: 0.1118 - val_accuracy: 0.9698
# Epoch 158/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0368 - accuracy: 0.9896 - val_loss: 0.0952 - val_accuracy: 0.9768
# Epoch 159/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0578 - accuracy: 0.9823 - val_loss: 0.3127 - val_accuracy: 0.9331
# Epoch 160/200
# 276/276 [==============================] - 20s 72ms/step - loss: 0.0656 - accuracy: 0.9790 - val_loss: 0.1040 - val_accuracy: 0.9767
# Epoch 161/200
# 276/276 [==============================] - 20s 72ms/step - loss: 0.0278 - accuracy: 0.9930 - val_loss: 0.0959 - val_accuracy: 0.9789
# Epoch 162/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0744 - accuracy: 0.9837 - val_loss: 1.0082 - val_accuracy: 0.7959
# Epoch 163/200
# 276/276 [==============================] - 20s 73ms/step - loss: 0.1342 - accuracy: 0.9607 - val_loss: 0.1214 - val_accuracy: 0.9668
# Epoch 164/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0574 - accuracy: 0.9849 - val_loss: 0.1027 - val_accuracy: 0.9746
# Epoch 165/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0281 - accuracy: 0.9932 - val_loss: 0.0890 - val_accuracy: 0.9795
# Epoch 166/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0247 - accuracy: 0.9943 - val_loss: 0.0953 - val_accuracy: 0.9812
# Epoch 167/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0280 - accuracy: 0.9930 - val_loss: 0.0967 - val_accuracy: 0.9807
# Epoch 168/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0230 - accuracy: 0.9947 - val_loss: 0.1003 - val_accuracy: 0.9801
# Epoch 169/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0524 - accuracy: 0.9839 - val_loss: 0.1081 - val_accuracy: 0.9740
# Epoch 170/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0567 - accuracy: 0.9833 - val_loss: 0.1659 - val_accuracy: 0.9640
# Epoch 171/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0520 - accuracy: 0.9841 - val_loss: 0.1260 - val_accuracy: 0.9753
# Epoch 172/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0455 - accuracy: 0.9868 - val_loss: 0.1541 - val_accuracy: 0.9658
# Epoch 173/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0269 - accuracy: 0.9934 - val_loss: 0.1063 - val_accuracy: 0.9785
# Epoch 174/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0268 - accuracy: 0.9926 - val_loss: 0.2317 - val_accuracy: 0.9354
# Epoch 175/200
# 276/276 [==============================] - 19s 71ms/step - loss: 0.0770 - accuracy: 0.9762 - val_loss: 0.1529 - val_accuracy: 0.9626
# Epoch 176/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0380 - accuracy: 0.9886 - val_loss: 0.1432 - val_accuracy: 0.9668
# Epoch 177/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0490 - accuracy: 0.9844 - val_loss: 0.1682 - val_accuracy: 0.9582
# Epoch 178/200
# 276/276 [==============================] - 20s 71ms/step - loss: 0.0397 - accuracy: 0.9883 - val_loss: 0.0997 - val_accuracy: 0.9772

# %%
import tensorflow as tf
model.save_weights('weights\DepWiseInception.h5')

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 8s 7ms/step - loss: 0.0243 - accuracy: 0.9939
# 367/367 [==============================] - 3s 7ms/step - loss: 0.1003 - accuracy: 0.9801
# Train Loss:  0.02429800108075142
# Train Accuracy:  0.9939490556716919
# --------------------
# Test Loss:  0.10030286014080048
# Test Accuracy:  0.980057954788208

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 3s 6ms/step

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#model.save('Skin Cancer.h5')

# %%
from keras import backend as K
import gc

del model

K.clear_session()
gc.collect()
# Out:
# 9114

# %%
# from numba import cuda

# cuda.select_device(0)
# cuda.close()
