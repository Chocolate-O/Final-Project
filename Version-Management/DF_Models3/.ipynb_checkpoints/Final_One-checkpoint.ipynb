# %%
#pip install imblearn

# %% [markdown]
# # Extract Dataset

# %%
# import zipfile
# import os

# # 定义压缩包路径和目标文件夹路径
# zip_file_path = 'archive.zip'
# extract_folder_path = r'archive'

# # 创建目标文件夹（如果不存在）
# os.makedirs(extract_folder_path, exist_ok=True)

# # 解压缩压缩包
# with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_folder_path)

# print(f"Successfully extracted to {extract_folder_path}")

# %% [markdown]
# # Improt library

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization,Multiply,Add
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# # Read CSV File

# %%
data_dir = r'F:\MV\Dataset\HAM1000\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_class_distribution(csv_file):
    # 读取csv文件
    df = pd.read_csv(csv_file)

    # 计算每个类别的数量
    class_counts = df['dx'].value_counts()

    # 绘制分布图
    plt.figure(figsize=(10, 5))
    plt.bar(class_counts.index, class_counts.values)
    plt.title('The distribution of the number of images for each category in the dataset.')
    plt.xlabel('Categories')
    plt.ylabel('Number')
    plt.show()

# 使用数据集调用函数
data_dir = r'F:\MV\Dataset\HAM1000\HAM10000_metadata.csv'
plot_class_distribution(data_dir)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6])

# %% [markdown]
# # Set Classes

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # Data Augmentation

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Concatenate, Conv2D, MaxPooling2D, AveragePooling2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense, Add


def squeeze_excitation_block(x, ratio=8):
    channels = int(x.shape[-1])
    se = GlobalAveragePooling2D()(x)
    se = Dense(channels // ratio, activation='relu')(se)
    se = Dense(channels, activation='sigmoid')(se)
    se = tf.keras.layers.Reshape((1, 1, channels))(se)
    scaled = Multiply()([x, se])
    return scaled



def depthwise_inception_resnet(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Inception-ResNet module
    def inception_resnet_block(x, filters,scale=1.0):
        # Inception block
        conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu')(x)
        conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu')(conv1x1)
    
        conv3x3 = Conv2D(filters[1], (1, 1), padding='same', activation='relu')(x)
        conv3x3 = DepthwiseConv2D((3, 3), padding='same', activation='relu')(conv3x3)
        conv3x3 = Conv2D(filters[2], (1, 1), padding='same', activation='relu')(conv3x3)
        conv3x3 = Conv2D(filters[2], (1, 1), padding='same', activation='relu')(conv3x3)
    
        conv5x5 = Conv2D(filters[3], (1, 1), padding='same', activation='relu')(x)
        conv5x5 = DepthwiseConv2D((5, 5), padding='same', activation='relu')(conv5x5)
        conv5x5 = Conv2D(filters[4], (1, 1), padding='same', activation='relu')(conv5x5)
        conv5x5 = Conv2D(filters[4], (1, 1), padding='same', activation='relu')(conv5x5)
    
        maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
        maxpool = Conv2D(filters[5], (1, 1), padding='same', activation='relu')(maxpool)
        maxpool = Conv2D(filters[5], (1, 1), padding='same', activation='relu')(maxpool)
    
        inception_block = Concatenate(axis=-1)([conv1x1, conv3x3, conv5x5, maxpool])
    
        # Adjust the number of filters in the first convolution to match the number of channels in the input tensor
        num_channels = x.shape[-1]
        conv1x1_res = Conv2D(num_channels, (1, 1), padding='same', activation='relu')(inception_block)
        conv1x1_res = Conv2D(num_channels, (1, 1), padding='same', activation='relu')(conv1x1_res)
    
        # Residual connection
        res_connect = Add()([conv1x1_res, x])


        return inception_block

    # Initial convolutional layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(input_tensor)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception ResNet blocks
    x = inception_resnet_block(x, filters=[64, 128, 128, 32, 32, 32])
    x = inception_resnet_block(x, filters=[128, 192, 192, 64, 64, 64])

    # MaxPooling and Fully Connected layers
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = squeeze_excitation_block(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=x)

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the depthwise separable CNN model
model = depthwise_inception_resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# 2023-12-25 07:01:02.473865: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-25 07:01:03.236660: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22290 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:04:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 14, 14, 64)   9472        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 7, 7, 64)     0           ['conv2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 7, 7, 128)    8320        ['max_pooling2d[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 7, 7, 32)     2080        ['max_pooling2d[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 7, 7, 128)   1280        ['conv2d_3[0][0]']
#  v2D)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 7, 7, 32)    832         ['conv2d_6[0][0]']
#  onv2D)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 64)    0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 64)     4160        ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 7, 7, 128)    16512       ['depthwise_conv2d[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 32)     1056        ['depthwise_conv2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 32)     2080        ['max_pooling2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 7, 7, 64)     4160        ['conv2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 7, 7, 128)    16512       ['conv2d_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 32)     1056        ['conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 32)     1056        ['conv2d_9[0][0]']
#
#  concatenate (Concatenate)      (None, 7, 7, 256)    0           ['conv2d_2[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_8[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 7, 7, 192)    49344       ['concatenate[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 7, 7, 64)     16448       ['concatenate[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 7, 7, 192)   1920        ['conv2d_15[0][0]']
#  onv2D)
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 7, 7, 64)    1664        ['conv2d_18[0][0]']
#  onv2D)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 256)   0           ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 7, 7, 128)    32896       ['concatenate[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 7, 7, 192)    37056       ['depthwise_conv2d_2[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 7, 7, 64)     4160        ['depthwise_conv2d_3[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 7, 7, 64)     16448       ['max_pooling2d_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 7, 7, 128)    16512       ['conv2d_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 7, 7, 192)    37056       ['conv2d_16[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 7, 7, 64)     4160        ['conv2d_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 7, 7, 64)     4160        ['conv2d_21[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 7, 7, 448)    0           ['conv2d_14[0][0]',
#                                                                   'conv2d_17[0][0]',
#                                                                   'conv2d_20[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 448)   0           ['concatenate_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 448)         0           ['max_pooling2d_3[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 56)           25144       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 448)          25536       ['dense[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 448)    0           ['dense_1[0][0]']
#
#  multiply (Multiply)            (None, 4, 4, 448)    0           ['max_pooling2d_3[0][0]',
#                                                                   'reshape[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 448)         0           ['multiply[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 7)            3143        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 344,223
# Trainable params: 344,223
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Data Augmentation

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %% [markdown]
# # Fit the model

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=400,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction,EarlyStopping(monitor='loss', patience=10, restore_best_weights = True)])
# Out:
# Epoch 1/400
# 2023-12-25 07:01:07.895369: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-25 07:01:09.411383: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 276/276 [==============================] - 9s 18ms/step - loss: 1.7160 - accuracy: 0.3591 - val_loss: 1.9420 - val_accuracy: 0.2992 - lr: 0.0010
# Epoch 2/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.2565 - accuracy: 0.5065 - val_loss: 1.4512 - val_accuracy: 0.4997 - lr: 0.0010
# Epoch 3/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.0282 - accuracy: 0.6011 - val_loss: 1.6588 - val_accuracy: 0.4276 - lr: 0.0010
# Epoch 4/400
# 274/276 [============================>.] - ETA: 0s - loss: 0.8456 - accuracy: 0.6781
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 276/276 [==============================] - 4s 16ms/step - loss: 0.8448 - accuracy: 0.6784 - val_loss: 1.7825 - val_accuracy: 0.4983 - lr: 0.0010
# Epoch 5/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.6300 - accuracy: 0.7647 - val_loss: 0.5947 - val_accuracy: 0.7723 - lr: 5.0000e-04
# Epoch 6/400
# 276/276 [==============================] - 4s 16ms/step - loss: 0.4942 - accuracy: 0.8160 - val_loss: 0.4498 - val_accuracy: 0.8272 - lr: 5.0000e-04
# Epoch 7/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.4246 - accuracy: 0.8409 - val_loss: 0.7847 - val_accuracy: 0.7033 - lr: 5.0000e-04
# Epoch 8/400
# 276/276 [==============================] - ETA: 0s - loss: 0.3789 - accuracy: 0.8593
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 276/276 [==============================] - 4s 15ms/step - loss: 0.3789 - accuracy: 0.8593 - val_loss: 1.5568 - val_accuracy: 0.5562 - lr: 5.0000e-04
# Epoch 9/400
# 276/276 [==============================] - 4s 16ms/step - loss: 0.3493 - accuracy: 0.8768 - val_loss: 0.3004 - val_accuracy: 0.8888 - lr: 2.5000e-04
# Epoch 10/400
# 276/276 [==============================] - 4s 16ms/step - loss: 0.2388 - accuracy: 0.9150 - val_loss: 0.2491 - val_accuracy: 0.9080 - lr: 2.5000e-04
# Epoch 11/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.2115 - accuracy: 0.9248 - val_loss: 0.5229 - val_accuracy: 0.7844 - lr: 2.5000e-04
# Epoch 12/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.2595 - accuracy: 0.9088 - val_loss: 0.2414 - val_accuracy: 0.9154 - lr: 2.5000e-04
# Epoch 13/400
# 276/276 [==============================] - 4s 16ms/step - loss: 0.1798 - accuracy: 0.9383 - val_loss: 0.4802 - val_accuracy: 0.8296 - lr: 2.5000e-04
# Epoch 14/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.2275 - accuracy: 0.9221 - val_loss: 0.2122 - val_accuracy: 0.9296 - lr: 2.5000e-04
# Epoch 15/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1502 - accuracy: 0.9483 - val_loss: 0.1772 - val_accuracy: 0.9389 - lr: 2.5000e-04
# Epoch 16/400
# 276/276 [==============================] - 5s 17ms/step - loss: 0.1501 - accuracy: 0.9483 - val_loss: 0.1797 - val_accuracy: 0.9367 - lr: 2.5000e-04
# Epoch 17/400
# 276/276 [==============================] - 5s 17ms/step - loss: 0.1401 - accuracy: 0.9517 - val_loss: 0.1714 - val_accuracy: 0.9425 - lr: 2.5000e-04
# Epoch 18/400
# 276/276 [==============================] - 5s 18ms/step - loss: 0.1262 - accuracy: 0.9566 - val_loss: 0.3591 - val_accuracy: 0.8867 - lr: 2.5000e-04
# Epoch 19/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1305 - accuracy: 0.9557 - val_loss: 0.1636 - val_accuracy: 0.9484 - lr: 2.5000e-04
# Epoch 20/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1112 - accuracy: 0.9629 - val_loss: 0.1540 - val_accuracy: 0.9501 - lr: 2.5000e-04
# Epoch 21/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0949 - accuracy: 0.9684 - val_loss: 0.1806 - val_accuracy: 0.9367 - lr: 2.5000e-04
# Epoch 22/400
# 276/276 [==============================] - 4s 16ms/step - loss: 0.0854 - accuracy: 0.9718 - val_loss: 0.1411 - val_accuracy: 0.9564 - lr: 2.5000e-04
# Epoch 23/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0786 - accuracy: 0.9738 - val_loss: 0.1311 - val_accuracy: 0.9587 - lr: 2.5000e-04
# Epoch 24/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1317 - accuracy: 0.9542 - val_loss: 0.1228 - val_accuracy: 0.9607 - lr: 2.5000e-04
# Epoch 25/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0609 - accuracy: 0.9808 - val_loss: 0.1149 - val_accuracy: 0.9653 - lr: 2.5000e-04
# Epoch 26/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0613 - accuracy: 0.9800 - val_loss: 0.1440 - val_accuracy: 0.9554 - lr: 2.5000e-04
# Epoch 27/400
# 273/276 [============================>.] - ETA: 0s - loss: 0.0708 - accuracy: 0.9769
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0717 - accuracy: 0.9765 - val_loss: 0.2695 - val_accuracy: 0.9011 - lr: 2.5000e-04
# Epoch 28/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0406 - accuracy: 0.9888 - val_loss: 0.1183 - val_accuracy: 0.9655 - lr: 1.2500e-04
# Epoch 29/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0437 - accuracy: 0.9874 - val_loss: 0.0836 - val_accuracy: 0.9754 - lr: 1.2500e-04
# Epoch 30/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0260 - accuracy: 0.9934 - val_loss: 0.0841 - val_accuracy: 0.9752 - lr: 1.2500e-04
# Epoch 31/400
# 275/276 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 0.9952
# Epoch 31: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 276/276 [==============================] - 4s 16ms/step - loss: 0.0213 - accuracy: 0.9952 - val_loss: 0.1087 - val_accuracy: 0.9680 - lr: 1.2500e-04
# Epoch 32/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0165 - accuracy: 0.9966 - val_loss: 0.0810 - val_accuracy: 0.9775 - lr: 6.2500e-05
# Epoch 33/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0151 - accuracy: 0.9971 - val_loss: 0.0763 - val_accuracy: 0.9790 - lr: 6.2500e-05
# Epoch 34/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0137 - accuracy: 0.9975 - val_loss: 0.0847 - val_accuracy: 0.9778 - lr: 6.2500e-05
# Epoch 35/400
# 275/276 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9976
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0130 - accuracy: 0.9976 - val_loss: 0.0915 - val_accuracy: 0.9762 - lr: 6.2500e-05
# Epoch 36/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0096 - accuracy: 0.9988 - val_loss: 0.0919 - val_accuracy: 0.9756 - lr: 3.1250e-05
# Epoch 37/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0099 - accuracy: 0.9984 - val_loss: 0.0770 - val_accuracy: 0.9814 - lr: 3.1250e-05
# Epoch 38/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0081 - accuracy: 0.9992 - val_loss: 0.0711 - val_accuracy: 0.9834 - lr: 3.1250e-05
# Epoch 39/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0078 - accuracy: 0.9992 - val_loss: 0.0925 - val_accuracy: 0.9744 - lr: 3.1250e-05
# Epoch 40/400
# 274/276 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9942
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 276/276 [==============================] - 4s 16ms/step - loss: 0.0226 - accuracy: 0.9942 - val_loss: 0.0810 - val_accuracy: 0.9802 - lr: 3.1250e-05
# Epoch 41/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0069 - accuracy: 0.9994 - val_loss: 0.0816 - val_accuracy: 0.9799 - lr: 1.5625e-05
# Epoch 42/400
# 276/276 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9996
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-05.
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0063 - accuracy: 0.9996 - val_loss: 0.0799 - val_accuracy: 0.9810 - lr: 1.5625e-05
# Epoch 43/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0059 - accuracy: 0.9996 - val_loss: 0.0852 - val_accuracy: 0.9796 - lr: 1.0000e-05
# Epoch 44/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0840 - val_accuracy: 0.9798 - lr: 1.0000e-05
# Epoch 45/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0879 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 46/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0838 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 47/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0052 - accuracy: 0.9997 - val_loss: 0.0840 - val_accuracy: 0.9804 - lr: 1.0000e-05
# Epoch 48/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0050 - accuracy: 0.9998 - val_loss: 0.0863 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 49/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0048 - accuracy: 0.9998 - val_loss: 0.0822 - val_accuracy: 0.9818 - lr: 1.0000e-05
# Epoch 50/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0046 - accuracy: 0.9998 - val_loss: 0.0883 - val_accuracy: 0.9797 - lr: 1.0000e-05
# Epoch 51/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0045 - accuracy: 0.9998 - val_loss: 0.0868 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 52/400
# 276/276 [==============================] - 4s 16ms/step - loss: 0.0043 - accuracy: 0.9998 - val_loss: 0.0927 - val_accuracy: 0.9779 - lr: 1.0000e-05
# Epoch 53/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0041 - accuracy: 0.9998 - val_loss: 0.0939 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 54/400
# 276/276 [==============================] - 4s 16ms/step - loss: 0.0038 - accuracy: 0.9999 - val_loss: 0.0888 - val_accuracy: 0.9802 - lr: 1.0000e-05
# Epoch 55/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0037 - accuracy: 0.9998 - val_loss: 0.0943 - val_accuracy: 0.9788 - lr: 1.0000e-05
# Epoch 56/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0035 - accuracy: 0.9999 - val_loss: 0.0898 - val_accuracy: 0.9798 - lr: 1.0000e-05
# Epoch 57/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0033 - accuracy: 0.9999 - val_loss: 0.0903 - val_accuracy: 0.9807 - lr: 1.0000e-05
# Epoch 58/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0032 - accuracy: 0.9999 - val_loss: 0.0883 - val_accuracy: 0.9806 - lr: 1.0000e-05
# Epoch 59/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0031 - accuracy: 0.9999 - val_loss: 0.0980 - val_accuracy: 0.9789 - lr: 1.0000e-05
# Epoch 60/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0028 - accuracy: 0.9999 - val_loss: 0.0875 - val_accuracy: 0.9813 - lr: 1.0000e-05
# Epoch 61/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 0.0990 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 62/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 0.1082 - val_accuracy: 0.9772 - lr: 1.0000e-05
# Epoch 63/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0024 - accuracy: 0.9999 - val_loss: 0.0957 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 64/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0965 - val_accuracy: 0.9804 - lr: 1.0000e-05
# Epoch 65/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0021 - accuracy: 0.9999 - val_loss: 0.0946 - val_accuracy: 0.9807 - lr: 1.0000e-05
# Epoch 66/400
# 276/276 [==============================] - 4s 16ms/step - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.1061 - val_accuracy: 0.9784 - lr: 1.0000e-05
# Epoch 67/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 0.9796 - lr: 1.0000e-05
# Epoch 68/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0974 - val_accuracy: 0.9806 - lr: 1.0000e-05
# Epoch 69/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9797 - lr: 1.0000e-05
# Epoch 70/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9781 - lr: 1.0000e-05
# Epoch 71/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1070 - val_accuracy: 0.9794 - lr: 1.0000e-05
# Epoch 72/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9811 - lr: 1.0000e-05
# Epoch 73/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1091 - val_accuracy: 0.9796 - lr: 1.0000e-05
# Epoch 74/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9812 - lr: 1.0000e-05
# Epoch 75/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9804 - lr: 1.0000e-05
# Epoch 76/400
# 276/276 [==============================] - 4s 15ms/step - loss: 9.9467e-04 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9787 - lr: 1.0000e-05
# Epoch 77/400
# 276/276 [==============================] - 4s 15ms/step - loss: 9.5880e-04 - accuracy: 1.0000 - val_loss: 0.1108 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 78/400
# 276/276 [==============================] - 4s 15ms/step - loss: 8.7309e-04 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9788 - lr: 1.0000e-05
# Epoch 79/400
# 276/276 [==============================] - 4s 15ms/step - loss: 8.0894e-04 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9791 - lr: 1.0000e-05
# Epoch 80/400
# 276/276 [==============================] - 4s 15ms/step - loss: 8.9698e-04 - accuracy: 1.0000 - val_loss: 0.1074 - val_accuracy: 0.9808 - lr: 1.0000e-05
# Epoch 81/400
# 276/276 [==============================] - 4s 15ms/step - loss: 6.8937e-04 - accuracy: 1.0000 - val_loss: 0.1075 - val_accuracy: 0.9814 - lr: 1.0000e-05
# Epoch 82/400
# 276/276 [==============================] - 4s 15ms/step - loss: 6.3701e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 83/400
# 276/276 [==============================] - 4s 15ms/step - loss: 6.1474e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9800 - lr: 1.0000e-05
# Epoch 84/400
# 276/276 [==============================] - 4s 15ms/step - loss: 5.6739e-04 - accuracy: 1.0000 - val_loss: 0.1084 - val_accuracy: 0.9812 - lr: 1.0000e-05
# Epoch 85/400
# 276/276 [==============================] - 4s 15ms/step - loss: 5.3216e-04 - accuracy: 1.0000 - val_loss: 0.1178 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 86/400
# 276/276 [==============================] - 4s 15ms/step - loss: 4.8417e-04 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9798 - lr: 1.0000e-05
# Epoch 87/400
# 276/276 [==============================] - 4s 16ms/step - loss: 4.6062e-04 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9805 - lr: 1.0000e-05
# Epoch 88/400
# 276/276 [==============================] - 4s 15ms/step - loss: 4.3145e-04 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9803 - lr: 1.0000e-05
# Epoch 89/400
# 276/276 [==============================] - 4s 15ms/step - loss: 3.9624e-04 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9813 - lr: 1.0000e-05
# Epoch 90/400
# 276/276 [==============================] - 4s 16ms/step - loss: 3.6894e-04 - accuracy: 1.0000 - val_loss: 0.1225 - val_accuracy: 0.9800 - lr: 1.0000e-05
# Epoch 91/400
# 276/276 [==============================] - 4s 16ms/step - loss: 3.2362e-04 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9794 - lr: 1.0000e-05
# Epoch 92/400
# 276/276 [==============================] - 4s 15ms/step - loss: 3.0458e-04 - accuracy: 1.0000 - val_loss: 0.1223 - val_accuracy: 0.9803 - lr: 1.0000e-05
# Epoch 93/400
# 276/276 [==============================] - 4s 15ms/step - loss: 2.8906e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9822 - lr: 1.0000e-05
# Epoch 94/400
# 276/276 [==============================] - 4s 15ms/step - loss: 2.7269e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9791 - lr: 1.0000e-05
# Epoch 95/400
# 276/276 [==============================] - 4s 15ms/step - loss: 2.3462e-04 - accuracy: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 96/400
# 276/276 [==============================] - 4s 15ms/step - loss: 2.1990e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 97/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.9970e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9793 - lr: 1.0000e-05
# Epoch 98/400
# 276/276 [==============================] - 4s 16ms/step - loss: 1.8054e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9796 - lr: 1.0000e-05
# Epoch 99/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.7055e-04 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9787 - lr: 1.0000e-05
# Epoch 100/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.1299 - val_accuracy: 0.9802 - lr: 1.0000e-05
# Epoch 101/400
# 276/276 [==============================] - 4s 15ms/step - loss: 6.3301e-04 - accuracy: 0.9999 - val_loss: 0.1362 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 102/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.9926e-04 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 103/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.7240e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9804 - lr: 1.0000e-05
# Epoch 104/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.5971e-04 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 105/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.5064e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 106/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.4251e-04 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 107/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.3710e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 108/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.3119e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9798 - lr: 1.0000e-05
# Epoch 109/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.2534e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 110/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.2198e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9802 - lr: 1.0000e-05
# Epoch 111/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.1803e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 112/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.1106e-04 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9792 - lr: 1.0000e-05
# Epoch 113/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.0622e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9791 - lr: 1.0000e-05
# Epoch 114/400
# 276/276 [==============================] - 4s 15ms/step - loss: 1.6908e-04 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9803 - lr: 1.0000e-05
# Epoch 115/400
# 276/276 [==============================] - 4s 16ms/step - loss: 9.8314e-05 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9796 - lr: 1.0000e-05
# Epoch 116/400
# 276/276 [==============================] - 4s 15ms/step - loss: 9.3482e-05 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 117/400
# 276/276 [==============================] - 4s 15ms/step - loss: 8.9891e-05 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9797 - lr: 1.0000e-05
# Epoch 118/400
# 276/276 [==============================] - 4s 15ms/step - loss: 8.4229e-05 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9806 - lr: 1.0000e-05
# Epoch 119/400
# 276/276 [==============================] - 4s 15ms/step - loss: 7.9226e-05 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9805 - lr: 1.0000e-05
# Epoch 120/400
# 276/276 [==============================] - 4s 15ms/step - loss: 7.4671e-05 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9800 - lr: 1.0000e-05
# Epoch 121/400
# 276/276 [==============================] - 4s 15ms/step - loss: 8.0675e-05 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9805 - lr: 1.0000e-05
# Epoch 122/400
# 276/276 [==============================] - 4s 16ms/step - loss: 6.8180e-05 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 123/400
# 276/276 [==============================] - 4s 15ms/step - loss: 6.4101e-05 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9797 - lr: 1.0000e-05
# Epoch 124/400
# 276/276 [==============================] - 4s 15ms/step - loss: 6.0351e-05 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 125/400
# 276/276 [==============================] - 4s 15ms/step - loss: 5.4487e-05 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9802 - lr: 1.0000e-05
# Epoch 126/400
# 276/276 [==============================] - 4s 15ms/step - loss: 5.0548e-05 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9803 - lr: 1.0000e-05
# Epoch 127/400
# 276/276 [==============================] - 4s 15ms/step - loss: 4.7948e-05 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 128/400
# 276/276 [==============================] - 4s 15ms/step - loss: 4.4049e-05 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9788 - lr: 1.0000e-05
# Epoch 129/400
# 276/276 [==============================] - 4s 15ms/step - loss: 4.0633e-05 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 130/400
# 276/276 [==============================] - 4s 16ms/step - loss: 3.7740e-05 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9802 - lr: 1.0000e-05
# Epoch 131/400
# 276/276 [==============================] - 4s 15ms/step - loss: 4.9945e-04 - accuracy: 0.9998 - val_loss: 0.1753 - val_accuracy: 0.9749 - lr: 1.0000e-05
# Epoch 132/400
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1594 - val_accuracy: 0.9798 - lr: 1.0000e-05
# Epoch 133/400
# 276/276 [==============================] - 4s 15ms/step - loss: 8.5059e-05 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 134/400
# 276/276 [==============================] - 4s 15ms/step - loss: 6.9869e-05 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.9798 - lr: 1.0000e-05
# Epoch 135/400
# 276/276 [==============================] - 4s 15ms/step - loss: 6.1515e-05 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.9800 - lr: 1.0000e-05
# Epoch 136/400
# 276/276 [==============================] - 4s 15ms/step - loss: 5.6591e-05 - accuracy: 1.0000 - val_loss: 0.1612 - val_accuracy: 0.9793 - lr: 1.0000e-05
# Epoch 137/400
# 276/276 [==============================] - 4s 15ms/step - loss: 5.1624e-05 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9802 - lr: 1.0000e-05
# Epoch 138/400
# 276/276 [==============================] - 4s 16ms/step - loss: 4.8221e-05 - accuracy: 1.0000 - val_loss: 0.1593 - val_accuracy: 0.9796 - lr: 1.0000e-05
# Epoch 139/400
# 276/276 [==============================] - 4s 15ms/step - loss: 4.5212e-05 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.9800 - lr: 1.0000e-05
# Epoch 140/400
# 276/276 [==============================] - 4s 15ms/step - loss: 4.2898e-05 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.9801 - lr: 1.0000e-05

# %% [markdown]
# # Grad-CAM (Gradient-weighted Class Activation Mapping)

# %%
def preprocess_input(x):
    return x / 255.0

# %%
# Set input shape and number of classes
input_shape = (224, 224, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the depthwise separable CNN model
model2 = depthwise_inception_resnet(input_shape, num_classes)

# Compile the model
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# model2.summary()

# %%
# last_conv_layer_name = [layer.name for layer in model2.layers if 'conv' in layer.name][-1]
# last_conv_layer = model.get_layer(last_conv_layer_name)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
import tensorflow as tf

# 假设你的数据集是一个字典，其中键是类别，值是图像路径的列表
dataset = {
    'bkl': ['archive/HAM10000_images_part_1/ISIC_0027419.jpg'],
    'nv': ['archive/HAM10000_images_part_1/ISIC_0028239.jpg'],
    'mel': ['archive/HAM10000_images_part_1/ISIC_0027190.jpg'],
    'bcc': ['archive/HAM10000_images_part_1/ISIC_0026574.jpg'],
    'vasc': ['archive/HAM10000_images_part_1/ISIC_0025321.jpg'],
    'akiec': ['archive/HAM10000_images_part_1/ISIC_0026872.jpg'],
    'df': ['archive/HAM10000_images_part_1/ISIC_0025954.jpg'],
}

# 获取最后一个卷积层的名称
last_conv_layer_name = [layer.name for layer in model2.layers if 'conv' in layer.name][-1]



# 对于每个类别，选择一个图像路径
for class_name, image_paths in dataset.items():
    img_path = image_paths[0]  # 选择第一个图像路径
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)  # 如果您的模型需要特定的预处理，请在这里进行

    # 获取模型的预测
    preds = model2.predict(x)

    # 获取预测类别的索引
    class_idx = np.argmax(preds[0])

    # 计算类别相对于最后一个卷积层输出的梯度
    with tf.GradientTape() as tape:
        last_conv_layer_output = model2.get_layer(last_conv_layer_name).output
        model_with_conv_output = tf.keras.models.Model([model2.inputs], [model2.output, last_conv_layer_output])
        preds, last_conv_output = model_with_conv_output(x)
        class_channel = preds[:, class_idx]

    # 计算梯度
    grads = tape.gradient(class_channel, last_conv_output)

    # 对梯度进行全局平均池化，得到每个通道的重要性权重
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # 对最后一个卷积层的输出进行加权求和，得到一个类激活映射
    heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_output), axis=-1)

    # 对类激活映射进行归一化
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)

    # 将PIL图像转换为NumPy数组
    img = tf.keras.preprocessing.image.img_to_array(img)

    # 将类激活映射上采样到输入图像的大小
    heatmap = cv2.resize(heatmap[0], (img.shape[1], img.shape[0]))

    # 将类激活映射转换为RGB
    heatmap = np.uint8(255 * heatmap)

    # 应用颜色映射
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

    # 将热力图叠加到原始图像上
    superimposed_img = cv2.addWeighted(img.astype('uint8'), 0.6, heatmap, 0.4, 0)

    # 创建一个新的图像
    plt.figure()

    plt.subplot(1, 2, 1)
    plt.imshow(img.astype(np.uint8))
    plt.title(f'Original Image - {class_name}')

    # 在第二个子图中显示热力图
    plt.subplot(1, 2, 2)
    plt.imshow(superimposed_img)
    plt.title(f'Heatmap - {class_name}')

    # 显示图像
    plt.show()
# Out:
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step

# %% [markdown]
# # Plot Accuracy and Loss

# %%
import matplotlib.pyplot as plt

def plot_accuracy_and_loss(history):
    # Get training and testing accuracy and loss histories
    training_accuracy = history.history['accuracy']
    testing_accuracy = history.history['val_accuracy']
    training_loss = history.history['loss']
    testing_loss = history.history['val_loss']

    # Plot training and testing accuracy curves
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(training_accuracy, label='Training Accuracy')
    plt.plot(testing_accuracy, label='Testing Accuracy')
    plt.title('Training vs Testing Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()

    # Plot training and testing loss curves
    plt.subplot(1, 2, 2)
    plt.plot(training_loss, label='Training Loss')
    plt.plot(testing_loss, label='Testing Loss')
    plt.title('Training vs Testing Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_accuracy_and_loss(history)

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 7s 6ms/step - loss: 3.4701e-05 - accuracy: 1.0000
# 367/367 [==============================] - 2s 6ms/step - loss: 0.1565 - accuracy: 0.9802
# Train Loss:  3.470071533229202e-05
# Train Accuracy:  1.0
# --------------------
# Test Loss:  0.1564503163099289
# Test Accuracy:  0.9802284240722656

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 2s 5ms/step

# %% [markdown]
# # Plot ROC , Recall , Precision , Sensitivity , Specificity , F1 Score , Precision-Recall with average value

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, auc, recall_score, precision_score, f1_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import label_binarize

def plot_curves(y_true, y_scores):
    num_classes = y_scores.shape[1]
    
    # Binarize the labels
    y_true_bin = label_binarize(y_true, classes=np.arange(num_classes))
    
    # Initialize figure
    plt.figure(figsize=(30, 30))
    
    # Plot ROC curve for each class
    plt.subplot(3, 3, 1)
    avg_auc = 0
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        avg_auc += roc_auc
        plt.plot(fpr, tpr, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
    avg_auc /= num_classes
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curves (Multi-class, Average AUC = {avg_auc:.2f})')
    plt.legend(loc="lower right")
    
    # Plot Recall curve for each class
    plt.subplot(3, 3, 2)
    avg_recall = 0
    recall_values_avg = []
    for i in range(num_classes):
        recall_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_recall += np.mean(recall_values)
        recall_values_avg.append(recall_values)
        plt.plot(np.linspace(0, 1, 100), recall_values, label=f'Class {i}')
    avg_recall /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(recall_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('Recall')
    plt.title(f'Recall Curves (Multi-class, Average Recall = {avg_recall:.2f})')
    plt.legend(loc="lower right")

    # Plot Precision curve for each class
    plt.subplot(3, 3, 3)
    avg_precision = 0
    precision_values_avg = []
    for i in range(num_classes):
        precision_values = [precision_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_precision += np.mean(precision_values)
        precision_values_avg.append(precision_values)
        plt.plot(np.linspace(0, 1, 100), precision_values, label=f'Class {i}')
    avg_precision /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(precision_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('Precision')
    plt.title(f'Precision Curves (Multi-class, Average Precision = {avg_precision:.2f})')
    plt.legend(loc="lower right")

    # Plot Sensitivity curve for each class
    plt.subplot(3, 3, 4)
    avg_sensitivity = 0
    sensitivity_values_avg = []
    for i in range(num_classes):
        sensitivity_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_sensitivity += np.mean(sensitivity_values)
        sensitivity_values_avg.append(sensitivity_values)
        plt.plot(np.linspace(0, 1, 100), sensitivity_values, label=f'Class {i}')
    avg_sensitivity /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(sensitivity_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('Sensitivity')
    plt.title(f'Sensitivity Curves (Multi-class, Average Sensitivity = {avg_sensitivity:.2f})')
    plt.legend(loc="lower right")

    # Plot Specificity curve for each class
    plt.subplot(3, 3, 5)
    avg_specificity = 0
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        tnr = 1 - fpr
        avg_specificity += np.mean(tnr)
        plt.plot(tnr, tpr, label=f'Class {i}')
    avg_specificity /= num_classes
    plt.xlabel('Specificity (True Negative Rate)')
    plt.ylabel('Sensitivity (True Positive Rate)')
    plt.title(f'Specificity Curves (Multi-class, Average Specificity = {avg_specificity:.2f})')
    plt.legend(loc='lower right')

    # Plot F1 Score curve for each class
    plt.subplot(3, 3, 6)
    avg_f1 = 0
    f1_values_avg = []
    for i in range(num_classes):
        f1_values = [f1_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_f1 += np.mean(f1_values)
        f1_values_avg.append(f1_values)
        plt.plot(np.linspace(0, 1, 100), f1_values, label=f'Class {i}')
    avg_f1 /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(f1_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('F1 Score')
    plt.title(f'F1 Score Curves (Multi-class, Average F1 Score = {avg_f1:.2f})')
    plt.legend(loc="lower right")

    # Plot Precision-Recall curve for each class
    plt.subplot(3, 3, 7)
    avg_precision_recall = 0
    for i in range(num_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_scores[:, i])
        avg_precision_recall += auc(recall, precision)
        plt.plot(recall, precision, lw=2, label=f'Class {i}')
    avg_precision_recall /= num_classes
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curves (Multi-class, Average AUC = {avg_precision_recall:.2f})')
    plt.legend(loc="lower right")

    plt.tight_layout()
    plt.show()

y_pred_probs = model.predict(X_test)
# Assuming y_pred_probs contains probabilities for each class
plot_curves(y_true, y_pred_probs)
# Out:
# 367/367 [==============================] - 2s 5ms/step

# %% [markdown]
# # Plot ROC , Recall , Precision , Sensitivity , Specificity , F1 Score , Precision-Recall with mean value

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, auc, recall_score, precision_score, f1_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import label_binarize

def plot_curves2(y_true, y_scores):
    num_classes = y_scores.shape[1]
    
    # Binarize the labels
    y_true_bin = label_binarize(y_true, classes=np.arange(num_classes))
    
    # Initialize figure
    plt.figure(figsize=(30, 30))
    
    # Lists to store mean values
    mean_fpr, mean_tpr = np.linspace(0, 1, 100), np.linspace(0, 1, 100)
    mean_recall, mean_precision = np.linspace(0, 1, 100), np.linspace(0, 1, 100)
    mean_sensitivity, mean_f1 = np.linspace(0, 1, 100), np.linspace(0, 1, 100)
    
    # Plot ROC curve for each class
    plt.subplot(3, 3, 1)
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
        mean_tpr += np.interp(mean_fpr, fpr, tpr)
    mean_tpr /= num_classes
    mean_auc = auc(mean_fpr, mean_tpr)
    plt.plot(mean_fpr, mean_tpr, color='black', linestyle='--', lw=2, label=f'Mean ROC (AUC = {mean_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves (Multi-class)')
    plt.legend(loc="lower right")
    
    # Plot Recall curve for each class
    plt.subplot(3, 3, 2)
    for i in range(num_classes):
        recall_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), recall_values, label=f'Class {i}')
        mean_recall += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), recall_values)
    mean_recall /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_recall, color='black', linestyle='--', lw=2, label='Mean Recall')
    plt.xlabel('Threshold')
    plt.ylabel('Recall')
    plt.title('Recall Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Precision curve for each class
    plt.subplot(3, 3, 3)
    for i in range(num_classes):
        precision_values = [precision_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), precision_values, label=f'Class {i}')
        mean_precision += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), precision_values)
    mean_precision /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_precision, color='black', linestyle='--', lw=2, label='Mean Precision')
    plt.xlabel('Threshold')
    plt.ylabel('Precision')
    plt.title('Precision Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Sensitivity curve for each class
    plt.subplot(3, 3, 4)
    for i in range(num_classes):
        sensitivity_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), sensitivity_values, label=f'Class {i}')
        mean_sensitivity += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), sensitivity_values)
    mean_sensitivity /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_sensitivity, color='black', linestyle='--', lw=2, label='Mean Sensitivity')
    plt.xlabel('Threshold')
    plt.ylabel('Sensitivity')
    plt.title('Sensitivity Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Specificity curve for each class
    plt.subplot(3, 3, 5)
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        tnr = 1 - fpr
        plt.plot(tnr, tpr, label=f'Class {i}')
    plt.xlabel('Specificity (True Negative Rate)')
    plt.ylabel('Sensitivity (True Positive Rate)')
    plt.title('Specificity Curves (Multi-class)')
    plt.legend(loc='lower right')

    # Plot F1 Score curve for each class
    plt.subplot(3, 3, 6)
    for i in range(num_classes):
        f1_values = [f1_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), f1_values, label=f'Class {i}')
        mean_f1 += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), f1_values)
    mean_f1 /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_f1, color='black', linestyle='--', lw=2, label='Mean F1 Score')
    plt.xlabel('Threshold')
    plt.ylabel('F1 Score')
    plt.title('F1 Score Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Precision-Recall curve for each class
    plt.subplot(3, 3, 7)
    for i in range(num_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_scores[:, i])
        plt.plot(recall, precision, lw=2, label=f'Class {i}')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curves (Multi-class)')
    plt.legend(loc="lower right")

    plt.tight_layout()
    plt.show()

# Assuming y_pred

plot_curves2(y_true, y_pred_probs)

# %% [markdown]
# # Plot Confusion Matrix

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %% [markdown]
# # Store the Weights

# %%
# import tensorflow as tf
# model.save_weights('model_weights/DCNN.h5')

# %% [markdown]
# # Clear the session

# %%
# from keras import backend as K
# import gc

# del model

# K.clear_session()
# gc.collect()

# %%
# #You need to install numba using 'pip install numba'

# from numba import cuda

# cuda.select_device(0)
# cuda.close()
