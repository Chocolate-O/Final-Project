# %%
#pip install imblearn

# %%
# import zipfile
# import os

# # 定义压缩包路径和目标文件夹路径
# zip_file_path = 'archive.zip'
# extract_folder_path = r'archive'

# # 创建目标文件夹（如果不存在）
# os.makedirs(extract_folder_path, exist_ok=True)

# # 解压缩压缩包
# with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_folder_path)

# print(f"Successfully extracted to {extract_folder_path}")

# %%
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# 2023-12-24 12:44:37.181224: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 12:44:37.339897: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# modules loaded

# %%
data_dir = r'archive/hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Columns: 2353 entries, pixel0000 to label
# dtypes: int64(2353)
# memory usage: 179.8 MB

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %%
data["label"].value_counts()
# Out:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6])

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2: ('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (35201, 28, 28, 3)
# (35201,)
# (11734, 28, 28, 3)
# (11734,)

# %%
from tensorflow.python.keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Concatenate, AveragePooling2D, GlobalAveragePooling2D, Dense

def inception_resnet_block(x, scale=0.1):
    conv1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)

    conv2_1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)
    conv2_1 = Conv2D(32, (3, 3), padding='same', activation='relu')(conv2_1)

    conv3_1 = Conv2D(32, (1, 1), padding='same', activation='relu')(x)
    conv3_1 = Conv2D(32, (5, 5), padding='same', activation='relu')(conv3_1)

    inception_block = Concatenate(axis=-1)([conv1, conv2_1, conv3_1])

    # Residual connection
    scaled_block = Conv2D(int(x.shape[-1]), (1, 1), padding='same', activation='linear')(inception_block)
    scaled_block = BatchNormalization()(scaled_block)

    out = Concatenate(axis=-1)([x, scaled_block])
    out = ReLU()(out * scale)

    return out

def inception_resnet(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(input_tensor)

    # Inception-ResNet blocks
    for _ in range(3):  # You can adjust the number of blocks as needed
        x = inception_resnet_block(x)

    # Global average pooling and dense layer
    x = GlobalAveragePooling2D()(x)
    output_tensor = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=output_tensor)

    return model

# %%
# Set input shape and number of classes
input_shape = (28, 28, 3)  # Example input shape, adjust based on your requirements
num_classes = 7  # Adjust based on your classification task

# Create the depthwise separable CNN model
model = inception_resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# 2023-12-24 12:44:45.846914: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 12:44:46.460586: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22292 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:03:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 28, 28, 64)   1792        ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 32)   2080        ['conv2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 32)   9248        ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 32)   25632       ['conv2d_4[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 96)   0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 64)   6208        ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 28, 28, 64)  256         ['conv2d_6[0][0]']
#  alization)
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 128)  0           ['conv2d[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 28, 28, 128)  0           ['concatenate_1[0][0]']
#
#  re_lu (ReLU)                   (None, 28, 28, 128)  0           ['tf.math.multiply[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   4128        ['re_lu[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 32)   4128        ['re_lu[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   4128        ['re_lu[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 32)   9248        ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 32)   25632       ['conv2d_10[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 28, 28, 96)   0           ['conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  12416       ['concatenate_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  rmalization)
#
#  concatenate_3 (Concatenate)    (None, 28, 28, 256)  0           ['re_lu[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 28, 28, 256)  0          ['concatenate_3[0][0]']
#  )
#
#  re_lu_1 (ReLU)                 (None, 28, 28, 256)  0           ['tf.math.multiply_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 32)   8224        ['re_lu_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 32)   8224        ['re_lu_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 32)   8224        ['re_lu_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 32)   9248        ['conv2d_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 32)   25632       ['conv2d_16[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 96)   0           ['conv2d_13[0][0]',
#                                                                   'conv2d_15[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 256)  24832       ['concatenate_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 256)  1024       ['conv2d_18[0][0]']
#  rmalization)
#
#  concatenate_5 (Concatenate)    (None, 28, 28, 512)  0           ['re_lu_1[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 28, 28, 512)  0          ['concatenate_5[0][0]']
#  )
#
#  re_lu_2 (ReLU)                 (None, 28, 28, 512)  0           ['tf.math.multiply_2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['re_lu_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 7)            3591        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 198,567
# Trainable params: 197,671
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
history = model.fit(X_train ,
                    y_train ,
                    epochs=250 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction,EarlyStopping(monitor='loss', patience=10, restore_best_weights = True)])
# Out:
# 2023-12-24 12:44:47.342440: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 662342016 exceeds 10% of free system memory.
# 2023-12-24 12:44:47.862704: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 662342016 exceeds 10% of free system memory.
# Epoch 1/250
# 2023-12-24 12:44:50.597254: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-24 12:44:52.020075: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 276/276 [==============================] - 14s 37ms/step - loss: 1.4962 - accuracy: 0.4620 - val_loss: 1.4801 - val_accuracy: 0.4415 - lr: 0.0010
# Epoch 2/250
# 276/276 [==============================] - 9s 34ms/step - loss: 1.0983 - accuracy: 0.5878 - val_loss: 1.5438 - val_accuracy: 0.4161 - lr: 0.0010
# Epoch 3/250
# 275/276 [============================>.] - ETA: 0s - loss: 0.9345 - accuracy: 0.6502
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 276/276 [==============================] - 9s 34ms/step - loss: 0.9346 - accuracy: 0.6502 - val_loss: 1.7874 - val_accuracy: 0.4300 - lr: 0.0010
# Epoch 4/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.7779 - accuracy: 0.7165 - val_loss: 0.8765 - val_accuracy: 0.6864 - lr: 5.0000e-04
# Epoch 5/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.6852 - accuracy: 0.7543 - val_loss: 0.8496 - val_accuracy: 0.6926 - lr: 5.0000e-04
# Epoch 6/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.6097 - accuracy: 0.7877 - val_loss: 0.7901 - val_accuracy: 0.7038 - lr: 5.0000e-04
# Epoch 7/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.5430 - accuracy: 0.8115 - val_loss: 0.7965 - val_accuracy: 0.6953 - lr: 5.0000e-04
# Epoch 8/250
# 275/276 [============================>.] - ETA: 0s - loss: 0.4903 - accuracy: 0.8324
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 276/276 [==============================] - 9s 34ms/step - loss: 0.4903 - accuracy: 0.8324 - val_loss: 0.7963 - val_accuracy: 0.6999 - lr: 5.0000e-04
# Epoch 9/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.4092 - accuracy: 0.8674 - val_loss: 0.4931 - val_accuracy: 0.8250 - lr: 2.5000e-04
# Epoch 10/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.3722 - accuracy: 0.8820 - val_loss: 0.4032 - val_accuracy: 0.8619 - lr: 2.5000e-04
# Epoch 11/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.3467 - accuracy: 0.8928 - val_loss: 0.4717 - val_accuracy: 0.8361 - lr: 2.5000e-04
# Epoch 12/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.3209 - accuracy: 0.9021 - val_loss: 0.4576 - val_accuracy: 0.8655 - lr: 2.5000e-04
# Epoch 13/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.2992 - accuracy: 0.9082 - val_loss: 0.4180 - val_accuracy: 0.8482 - lr: 2.5000e-04
# Epoch 14/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.2742 - accuracy: 0.9157 - val_loss: 0.3473 - val_accuracy: 0.8899 - lr: 2.5000e-04
# Epoch 15/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.2550 - accuracy: 0.9237 - val_loss: 0.4217 - val_accuracy: 0.8527 - lr: 2.5000e-04
# Epoch 16/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.2396 - accuracy: 0.9297 - val_loss: 0.3197 - val_accuracy: 0.8950 - lr: 2.5000e-04
# Epoch 17/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.2189 - accuracy: 0.9375 - val_loss: 0.2793 - val_accuracy: 0.9086 - lr: 2.5000e-04
# Epoch 18/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.2084 - accuracy: 0.9401 - val_loss: 0.4546 - val_accuracy: 0.8438 - lr: 2.5000e-04
# Epoch 19/250
# 275/276 [============================>.] - ETA: 0s - loss: 0.1974 - accuracy: 0.9422
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 276/276 [==============================] - 9s 34ms/step - loss: 0.1974 - accuracy: 0.9421 - val_loss: 0.3399 - val_accuracy: 0.8821 - lr: 2.5000e-04
# Epoch 20/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.1639 - accuracy: 0.9557 - val_loss: 0.2426 - val_accuracy: 0.9333 - lr: 1.2500e-04
# Epoch 21/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.1580 - accuracy: 0.9583 - val_loss: 0.2740 - val_accuracy: 0.9063 - lr: 1.2500e-04
# Epoch 22/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.1517 - accuracy: 0.9611 - val_loss: 0.2049 - val_accuracy: 0.9348 - lr: 1.2500e-04
# Epoch 23/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.1434 - accuracy: 0.9636 - val_loss: 0.1829 - val_accuracy: 0.9468 - lr: 1.2500e-04
# Epoch 24/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.1377 - accuracy: 0.9652 - val_loss: 0.1674 - val_accuracy: 0.9542 - lr: 1.2500e-04
# Epoch 25/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.1319 - accuracy: 0.9678 - val_loss: 0.1781 - val_accuracy: 0.9484 - lr: 1.2500e-04
# Epoch 26/250
# 275/276 [============================>.] - ETA: 0s - loss: 0.1275 - accuracy: 0.9682
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 276/276 [==============================] - 9s 34ms/step - loss: 0.1276 - accuracy: 0.9682 - val_loss: 0.1744 - val_accuracy: 0.9512 - lr: 1.2500e-04
# Epoch 27/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.1147 - accuracy: 0.9730 - val_loss: 0.1653 - val_accuracy: 0.9612 - lr: 6.2500e-05
# Epoch 28/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.1123 - accuracy: 0.9737 - val_loss: 0.1371 - val_accuracy: 0.9644 - lr: 6.2500e-05
# Epoch 29/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.1095 - accuracy: 0.9746 - val_loss: 0.1701 - val_accuracy: 0.9439 - lr: 6.2500e-05
# Epoch 30/250
# 275/276 [============================>.] - ETA: 0s - loss: 0.1090 - accuracy: 0.9749
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 276/276 [==============================] - 9s 34ms/step - loss: 0.1091 - accuracy: 0.9748 - val_loss: 0.1429 - val_accuracy: 0.9605 - lr: 6.2500e-05
# Epoch 31/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.1006 - accuracy: 0.9780 - val_loss: 0.1347 - val_accuracy: 0.9618 - lr: 3.1250e-05
# Epoch 32/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0984 - accuracy: 0.9785 - val_loss: 0.1262 - val_accuracy: 0.9668 - lr: 3.1250e-05
# Epoch 33/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0975 - accuracy: 0.9799 - val_loss: 0.1308 - val_accuracy: 0.9652 - lr: 3.1250e-05
# Epoch 34/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0973 - accuracy: 0.9786 - val_loss: 0.1244 - val_accuracy: 0.9693 - lr: 3.1250e-05
# Epoch 35/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0952 - accuracy: 0.9798 - val_loss: 0.1252 - val_accuracy: 0.9634 - lr: 3.1250e-05
# Epoch 36/250
# 275/276 [============================>.] - ETA: 0s - loss: 0.0941 - accuracy: 0.9800
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0942 - accuracy: 0.9800 - val_loss: 0.1242 - val_accuracy: 0.9659 - lr: 3.1250e-05
# Epoch 37/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0913 - accuracy: 0.9806 - val_loss: 0.1191 - val_accuracy: 0.9688 - lr: 1.5625e-05
# Epoch 38/250
# 275/276 [============================>.] - ETA: 0s - loss: 0.0908 - accuracy: 0.9808
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1e-05.
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0909 - accuracy: 0.9808 - val_loss: 0.1208 - val_accuracy: 0.9690 - lr: 1.5625e-05
# Epoch 39/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0889 - accuracy: 0.9814 - val_loss: 0.1164 - val_accuracy: 0.9696 - lr: 1.0000e-05
# Epoch 40/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0882 - accuracy: 0.9818 - val_loss: 0.1162 - val_accuracy: 0.9691 - lr: 1.0000e-05
# Epoch 41/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0874 - accuracy: 0.9822 - val_loss: 0.1168 - val_accuracy: 0.9697 - lr: 1.0000e-05
# Epoch 42/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0868 - accuracy: 0.9822 - val_loss: 0.1153 - val_accuracy: 0.9693 - lr: 1.0000e-05
# Epoch 43/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0872 - accuracy: 0.9820 - val_loss: 0.1166 - val_accuracy: 0.9692 - lr: 1.0000e-05
# Epoch 44/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0863 - accuracy: 0.9826 - val_loss: 0.1144 - val_accuracy: 0.9706 - lr: 1.0000e-05
# Epoch 45/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0865 - accuracy: 0.9823 - val_loss: 0.1157 - val_accuracy: 0.9707 - lr: 1.0000e-05
# Epoch 46/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0855 - accuracy: 0.9822 - val_loss: 0.1150 - val_accuracy: 0.9702 - lr: 1.0000e-05
# Epoch 47/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0849 - accuracy: 0.9832 - val_loss: 0.1137 - val_accuracy: 0.9707 - lr: 1.0000e-05
# Epoch 48/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0852 - accuracy: 0.9829 - val_loss: 0.1128 - val_accuracy: 0.9709 - lr: 1.0000e-05
# Epoch 49/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0845 - accuracy: 0.9832 - val_loss: 0.1132 - val_accuracy: 0.9707 - lr: 1.0000e-05
# Epoch 50/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0841 - accuracy: 0.9837 - val_loss: 0.1131 - val_accuracy: 0.9707 - lr: 1.0000e-05
# Epoch 51/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0836 - accuracy: 0.9835 - val_loss: 0.1150 - val_accuracy: 0.9701 - lr: 1.0000e-05
# Epoch 52/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0830 - accuracy: 0.9836 - val_loss: 0.1129 - val_accuracy: 0.9695 - lr: 1.0000e-05
# Epoch 53/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0825 - accuracy: 0.9838 - val_loss: 0.1113 - val_accuracy: 0.9715 - lr: 1.0000e-05
# Epoch 54/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0825 - accuracy: 0.9834 - val_loss: 0.1122 - val_accuracy: 0.9703 - lr: 1.0000e-05
# Epoch 55/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0825 - accuracy: 0.9837 - val_loss: 0.1121 - val_accuracy: 0.9700 - lr: 1.0000e-05
# Epoch 56/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0820 - accuracy: 0.9837 - val_loss: 0.1118 - val_accuracy: 0.9704 - lr: 1.0000e-05
# Epoch 57/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0809 - accuracy: 0.9839 - val_loss: 0.1095 - val_accuracy: 0.9713 - lr: 1.0000e-05
# Epoch 58/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0804 - accuracy: 0.9842 - val_loss: 0.1102 - val_accuracy: 0.9709 - lr: 1.0000e-05
# Epoch 59/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0807 - accuracy: 0.9841 - val_loss: 0.1127 - val_accuracy: 0.9705 - lr: 1.0000e-05
# Epoch 60/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0792 - accuracy: 0.9847 - val_loss: 0.1109 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 61/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0801 - accuracy: 0.9844 - val_loss: 0.1130 - val_accuracy: 0.9704 - lr: 1.0000e-05
# Epoch 62/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0790 - accuracy: 0.9847 - val_loss: 0.1077 - val_accuracy: 0.9718 - lr: 1.0000e-05
# Epoch 63/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0788 - accuracy: 0.9845 - val_loss: 0.1085 - val_accuracy: 0.9715 - lr: 1.0000e-05
# Epoch 64/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0795 - accuracy: 0.9846 - val_loss: 0.1083 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 65/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0786 - accuracy: 0.9845 - val_loss: 0.1089 - val_accuracy: 0.9714 - lr: 1.0000e-05
# Epoch 66/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0783 - accuracy: 0.9850 - val_loss: 0.1073 - val_accuracy: 0.9719 - lr: 1.0000e-05
# Epoch 67/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0774 - accuracy: 0.9851 - val_loss: 0.1082 - val_accuracy: 0.9724 - lr: 1.0000e-05
# Epoch 68/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0767 - accuracy: 0.9854 - val_loss: 0.1075 - val_accuracy: 0.9718 - lr: 1.0000e-05
# Epoch 69/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0773 - accuracy: 0.9860 - val_loss: 0.1080 - val_accuracy: 0.9724 - lr: 1.0000e-05
# Epoch 70/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0768 - accuracy: 0.9855 - val_loss: 0.1057 - val_accuracy: 0.9731 - lr: 1.0000e-05
# Epoch 71/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0767 - accuracy: 0.9856 - val_loss: 0.1064 - val_accuracy: 0.9728 - lr: 1.0000e-05
# Epoch 72/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0757 - accuracy: 0.9857 - val_loss: 0.1065 - val_accuracy: 0.9712 - lr: 1.0000e-05
# Epoch 73/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0755 - accuracy: 0.9856 - val_loss: 0.1056 - val_accuracy: 0.9719 - lr: 1.0000e-05
# Epoch 74/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0749 - accuracy: 0.9859 - val_loss: 0.1090 - val_accuracy: 0.9730 - lr: 1.0000e-05
# Epoch 75/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0753 - accuracy: 0.9857 - val_loss: 0.1055 - val_accuracy: 0.9720 - lr: 1.0000e-05
# Epoch 76/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0744 - accuracy: 0.9858 - val_loss: 0.1058 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 77/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0747 - accuracy: 0.9859 - val_loss: 0.1052 - val_accuracy: 0.9720 - lr: 1.0000e-05
# Epoch 78/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0743 - accuracy: 0.9859 - val_loss: 0.1036 - val_accuracy: 0.9730 - lr: 1.0000e-05
# Epoch 79/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0732 - accuracy: 0.9861 - val_loss: 0.1054 - val_accuracy: 0.9742 - lr: 1.0000e-05
# Epoch 80/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0734 - accuracy: 0.9873 - val_loss: 0.1038 - val_accuracy: 0.9719 - lr: 1.0000e-05
# Epoch 81/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0727 - accuracy: 0.9861 - val_loss: 0.1044 - val_accuracy: 0.9717 - lr: 1.0000e-05
# Epoch 82/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0722 - accuracy: 0.9868 - val_loss: 0.1029 - val_accuracy: 0.9727 - lr: 1.0000e-05
# Epoch 83/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0723 - accuracy: 0.9865 - val_loss: 0.1026 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 84/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0717 - accuracy: 0.9869 - val_loss: 0.1053 - val_accuracy: 0.9723 - lr: 1.0000e-05
# Epoch 85/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0717 - accuracy: 0.9869 - val_loss: 0.1011 - val_accuracy: 0.9720 - lr: 1.0000e-05
# Epoch 86/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0716 - accuracy: 0.9869 - val_loss: 0.1021 - val_accuracy: 0.9729 - lr: 1.0000e-05
# Epoch 87/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0706 - accuracy: 0.9868 - val_loss: 0.1018 - val_accuracy: 0.9734 - lr: 1.0000e-05
# Epoch 88/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0703 - accuracy: 0.9874 - val_loss: 0.1020 - val_accuracy: 0.9730 - lr: 1.0000e-05
# Epoch 89/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0698 - accuracy: 0.9874 - val_loss: 0.1024 - val_accuracy: 0.9745 - lr: 1.0000e-05
# Epoch 90/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0695 - accuracy: 0.9874 - val_loss: 0.1003 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 91/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0690 - accuracy: 0.9877 - val_loss: 0.1025 - val_accuracy: 0.9720 - lr: 1.0000e-05
# Epoch 92/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0691 - accuracy: 0.9876 - val_loss: 0.1011 - val_accuracy: 0.9742 - lr: 1.0000e-05
# Epoch 93/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0682 - accuracy: 0.9875 - val_loss: 0.1007 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 94/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0683 - accuracy: 0.9880 - val_loss: 0.1003 - val_accuracy: 0.9726 - lr: 1.0000e-05
# Epoch 95/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0688 - accuracy: 0.9878 - val_loss: 0.0996 - val_accuracy: 0.9739 - lr: 1.0000e-05
# Epoch 96/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0674 - accuracy: 0.9876 - val_loss: 0.1002 - val_accuracy: 0.9737 - lr: 1.0000e-05
# Epoch 97/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0671 - accuracy: 0.9881 - val_loss: 0.0994 - val_accuracy: 0.9738 - lr: 1.0000e-05
# Epoch 98/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0666 - accuracy: 0.9879 - val_loss: 0.0988 - val_accuracy: 0.9749 - lr: 1.0000e-05
# Epoch 99/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0674 - accuracy: 0.9883 - val_loss: 0.0983 - val_accuracy: 0.9747 - lr: 1.0000e-05
# Epoch 100/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0661 - accuracy: 0.9886 - val_loss: 0.0993 - val_accuracy: 0.9738 - lr: 1.0000e-05
# Epoch 101/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0669 - accuracy: 0.9879 - val_loss: 0.0982 - val_accuracy: 0.9749 - lr: 1.0000e-05
# Epoch 102/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0665 - accuracy: 0.9872 - val_loss: 0.1015 - val_accuracy: 0.9736 - lr: 1.0000e-05
# Epoch 103/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0653 - accuracy: 0.9881 - val_loss: 0.0964 - val_accuracy: 0.9746 - lr: 1.0000e-05
# Epoch 104/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0655 - accuracy: 0.9887 - val_loss: 0.0989 - val_accuracy: 0.9737 - lr: 1.0000e-05
# Epoch 105/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0650 - accuracy: 0.9883 - val_loss: 0.0963 - val_accuracy: 0.9750 - lr: 1.0000e-05
# Epoch 106/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0647 - accuracy: 0.9884 - val_loss: 0.0987 - val_accuracy: 0.9751 - lr: 1.0000e-05
# Epoch 107/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0643 - accuracy: 0.9890 - val_loss: 0.0974 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 108/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0635 - accuracy: 0.9891 - val_loss: 0.0972 - val_accuracy: 0.9752 - lr: 1.0000e-05
# Epoch 109/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0632 - accuracy: 0.9890 - val_loss: 0.0972 - val_accuracy: 0.9746 - lr: 1.0000e-05
# Epoch 110/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0639 - accuracy: 0.9888 - val_loss: 0.0966 - val_accuracy: 0.9751 - lr: 1.0000e-05
# Epoch 111/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0632 - accuracy: 0.9889 - val_loss: 0.1013 - val_accuracy: 0.9738 - lr: 1.0000e-05
# Epoch 112/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0636 - accuracy: 0.9886 - val_loss: 0.0948 - val_accuracy: 0.9753 - lr: 1.0000e-05
# Epoch 113/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0628 - accuracy: 0.9892 - val_loss: 0.0955 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 114/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0619 - accuracy: 0.9894 - val_loss: 0.0944 - val_accuracy: 0.9754 - lr: 1.0000e-05
# Epoch 115/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0625 - accuracy: 0.9893 - val_loss: 0.0945 - val_accuracy: 0.9768 - lr: 1.0000e-05
# Epoch 116/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0615 - accuracy: 0.9894 - val_loss: 0.0959 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 117/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0613 - accuracy: 0.9893 - val_loss: 0.0941 - val_accuracy: 0.9759 - lr: 1.0000e-05
# Epoch 118/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0614 - accuracy: 0.9896 - val_loss: 0.0951 - val_accuracy: 0.9760 - lr: 1.0000e-05
# Epoch 119/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0607 - accuracy: 0.9898 - val_loss: 0.0927 - val_accuracy: 0.9764 - lr: 1.0000e-05
# Epoch 120/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0611 - accuracy: 0.9892 - val_loss: 0.0948 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 121/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0606 - accuracy: 0.9902 - val_loss: 0.0947 - val_accuracy: 0.9754 - lr: 1.0000e-05
# Epoch 122/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0596 - accuracy: 0.9897 - val_loss: 0.0940 - val_accuracy: 0.9760 - lr: 1.0000e-05
# Epoch 123/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0594 - accuracy: 0.9896 - val_loss: 0.0928 - val_accuracy: 0.9768 - lr: 1.0000e-05
# Epoch 124/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0596 - accuracy: 0.9903 - val_loss: 0.0932 - val_accuracy: 0.9755 - lr: 1.0000e-05
# Epoch 125/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0596 - accuracy: 0.9897 - val_loss: 0.0916 - val_accuracy: 0.9774 - lr: 1.0000e-05
# Epoch 126/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0589 - accuracy: 0.9903 - val_loss: 0.0918 - val_accuracy: 0.9769 - lr: 1.0000e-05
# Epoch 127/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0590 - accuracy: 0.9903 - val_loss: 0.0929 - val_accuracy: 0.9755 - lr: 1.0000e-05
# Epoch 128/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0586 - accuracy: 0.9905 - val_loss: 0.0937 - val_accuracy: 0.9756 - lr: 1.0000e-05
# Epoch 129/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0584 - accuracy: 0.9902 - val_loss: 0.0907 - val_accuracy: 0.9766 - lr: 1.0000e-05
# Epoch 130/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0575 - accuracy: 0.9898 - val_loss: 0.0917 - val_accuracy: 0.9769 - lr: 1.0000e-05
# Epoch 131/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0582 - accuracy: 0.9906 - val_loss: 0.0927 - val_accuracy: 0.9760 - lr: 1.0000e-05
# Epoch 132/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0578 - accuracy: 0.9904 - val_loss: 0.0906 - val_accuracy: 0.9762 - lr: 1.0000e-05
# Epoch 133/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0571 - accuracy: 0.9906 - val_loss: 0.0906 - val_accuracy: 0.9773 - lr: 1.0000e-05
# Epoch 134/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0575 - accuracy: 0.9905 - val_loss: 0.0895 - val_accuracy: 0.9775 - lr: 1.0000e-05
# Epoch 135/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0575 - accuracy: 0.9904 - val_loss: 0.0885 - val_accuracy: 0.9775 - lr: 1.0000e-05
# Epoch 136/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0562 - accuracy: 0.9904 - val_loss: 0.0900 - val_accuracy: 0.9766 - lr: 1.0000e-05
# Epoch 137/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0577 - accuracy: 0.9904 - val_loss: 0.0909 - val_accuracy: 0.9755 - lr: 1.0000e-05
# Epoch 138/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0559 - accuracy: 0.9908 - val_loss: 0.0895 - val_accuracy: 0.9769 - lr: 1.0000e-05
# Epoch 139/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0555 - accuracy: 0.9908 - val_loss: 0.0921 - val_accuracy: 0.9757 - lr: 1.0000e-05
# Epoch 140/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0553 - accuracy: 0.9909 - val_loss: 0.0901 - val_accuracy: 0.9772 - lr: 1.0000e-05
# Epoch 141/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0549 - accuracy: 0.9911 - val_loss: 0.0898 - val_accuracy: 0.9766 - lr: 1.0000e-05
# Epoch 142/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0552 - accuracy: 0.9913 - val_loss: 0.0912 - val_accuracy: 0.9768 - lr: 1.0000e-05
# Epoch 143/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0549 - accuracy: 0.9913 - val_loss: 0.0907 - val_accuracy: 0.9768 - lr: 1.0000e-05
# Epoch 144/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0543 - accuracy: 0.9913 - val_loss: 0.0884 - val_accuracy: 0.9769 - lr: 1.0000e-05
# Epoch 145/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0550 - accuracy: 0.9908 - val_loss: 0.0908 - val_accuracy: 0.9766 - lr: 1.0000e-05
# Epoch 146/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0538 - accuracy: 0.9910 - val_loss: 0.0884 - val_accuracy: 0.9770 - lr: 1.0000e-05
# Epoch 147/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0539 - accuracy: 0.9912 - val_loss: 0.0872 - val_accuracy: 0.9776 - lr: 1.0000e-05
# Epoch 148/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0536 - accuracy: 0.9914 - val_loss: 0.0867 - val_accuracy: 0.9787 - lr: 1.0000e-05
# Epoch 149/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0537 - accuracy: 0.9915 - val_loss: 0.0862 - val_accuracy: 0.9786 - lr: 1.0000e-05
# Epoch 150/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0526 - accuracy: 0.9913 - val_loss: 0.0876 - val_accuracy: 0.9772 - lr: 1.0000e-05
# Epoch 151/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0529 - accuracy: 0.9911 - val_loss: 0.0859 - val_accuracy: 0.9773 - lr: 1.0000e-05
# Epoch 152/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0532 - accuracy: 0.9920 - val_loss: 0.0897 - val_accuracy: 0.9761 - lr: 1.0000e-05
# Epoch 153/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0520 - accuracy: 0.9915 - val_loss: 0.0874 - val_accuracy: 0.9770 - lr: 1.0000e-05
# Epoch 154/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0518 - accuracy: 0.9919 - val_loss: 0.0872 - val_accuracy: 0.9786 - lr: 1.0000e-05
# Epoch 155/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0518 - accuracy: 0.9918 - val_loss: 0.0870 - val_accuracy: 0.9772 - lr: 1.0000e-05
# Epoch 156/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0514 - accuracy: 0.9917 - val_loss: 0.0880 - val_accuracy: 0.9765 - lr: 1.0000e-05
# Epoch 157/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0518 - accuracy: 0.9916 - val_loss: 0.0858 - val_accuracy: 0.9781 - lr: 1.0000e-05
# Epoch 158/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0516 - accuracy: 0.9919 - val_loss: 0.0858 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 159/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0515 - accuracy: 0.9918 - val_loss: 0.0846 - val_accuracy: 0.9786 - lr: 1.0000e-05
# Epoch 160/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0510 - accuracy: 0.9919 - val_loss: 0.0838 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 161/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0500 - accuracy: 0.9922 - val_loss: 0.0854 - val_accuracy: 0.9782 - lr: 1.0000e-05
# Epoch 162/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0503 - accuracy: 0.9921 - val_loss: 0.0833 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 163/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0498 - accuracy: 0.9919 - val_loss: 0.0849 - val_accuracy: 0.9777 - lr: 1.0000e-05
# Epoch 164/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0495 - accuracy: 0.9924 - val_loss: 0.0851 - val_accuracy: 0.9773 - lr: 1.0000e-05
# Epoch 165/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0499 - accuracy: 0.9920 - val_loss: 0.0854 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 166/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0492 - accuracy: 0.9925 - val_loss: 0.0845 - val_accuracy: 0.9779 - lr: 1.0000e-05
# Epoch 167/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0492 - accuracy: 0.9922 - val_loss: 0.0830 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 168/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0491 - accuracy: 0.9927 - val_loss: 0.0828 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 169/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0489 - accuracy: 0.9926 - val_loss: 0.0844 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 170/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0485 - accuracy: 0.9927 - val_loss: 0.0840 - val_accuracy: 0.9784 - lr: 1.0000e-05
# Epoch 171/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0479 - accuracy: 0.9923 - val_loss: 0.0823 - val_accuracy: 0.9791 - lr: 1.0000e-05
# Epoch 172/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0481 - accuracy: 0.9928 - val_loss: 0.0850 - val_accuracy: 0.9772 - lr: 1.0000e-05
# Epoch 173/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0477 - accuracy: 0.9930 - val_loss: 0.0836 - val_accuracy: 0.9780 - lr: 1.0000e-05
# Epoch 174/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0474 - accuracy: 0.9929 - val_loss: 0.0812 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 175/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0472 - accuracy: 0.9928 - val_loss: 0.0819 - val_accuracy: 0.9792 - lr: 1.0000e-05
# Epoch 176/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0472 - accuracy: 0.9930 - val_loss: 0.0832 - val_accuracy: 0.9787 - lr: 1.0000e-05
# Epoch 177/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0468 - accuracy: 0.9930 - val_loss: 0.0836 - val_accuracy: 0.9780 - lr: 1.0000e-05
# Epoch 178/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0465 - accuracy: 0.9930 - val_loss: 0.0849 - val_accuracy: 0.9780 - lr: 1.0000e-05
# Epoch 179/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0469 - accuracy: 0.9929 - val_loss: 0.0810 - val_accuracy: 0.9802 - lr: 1.0000e-05
# Epoch 180/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0464 - accuracy: 0.9936 - val_loss: 0.0821 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 181/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0456 - accuracy: 0.9933 - val_loss: 0.0812 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 182/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0462 - accuracy: 0.9931 - val_loss: 0.0824 - val_accuracy: 0.9783 - lr: 1.0000e-05
# Epoch 183/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0453 - accuracy: 0.9938 - val_loss: 0.0812 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 184/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0458 - accuracy: 0.9935 - val_loss: 0.0811 - val_accuracy: 0.9799 - lr: 1.0000e-05
# Epoch 185/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0449 - accuracy: 0.9934 - val_loss: 0.0807 - val_accuracy: 0.9791 - lr: 1.0000e-05
# Epoch 186/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0450 - accuracy: 0.9937 - val_loss: 0.0800 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 187/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0441 - accuracy: 0.9932 - val_loss: 0.0798 - val_accuracy: 0.9792 - lr: 1.0000e-05
# Epoch 188/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0447 - accuracy: 0.9934 - val_loss: 0.0802 - val_accuracy: 0.9798 - lr: 1.0000e-05
# Epoch 189/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0435 - accuracy: 0.9939 - val_loss: 0.0794 - val_accuracy: 0.9807 - lr: 1.0000e-05
# Epoch 190/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0445 - accuracy: 0.9934 - val_loss: 0.0792 - val_accuracy: 0.9794 - lr: 1.0000e-05
# Epoch 191/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0439 - accuracy: 0.9934 - val_loss: 0.0790 - val_accuracy: 0.9804 - lr: 1.0000e-05
# Epoch 192/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0433 - accuracy: 0.9938 - val_loss: 0.0785 - val_accuracy: 0.9800 - lr: 1.0000e-05
# Epoch 193/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0439 - accuracy: 0.9935 - val_loss: 0.0781 - val_accuracy: 0.9815 - lr: 1.0000e-05
# Epoch 194/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0433 - accuracy: 0.9937 - val_loss: 0.0811 - val_accuracy: 0.9784 - lr: 1.0000e-05
# Epoch 195/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0428 - accuracy: 0.9938 - val_loss: 0.0793 - val_accuracy: 0.9798 - lr: 1.0000e-05
# Epoch 196/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0429 - accuracy: 0.9940 - val_loss: 0.0785 - val_accuracy: 0.9804 - lr: 1.0000e-05
# Epoch 197/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0439 - accuracy: 0.9934 - val_loss: 0.0783 - val_accuracy: 0.9812 - lr: 1.0000e-05
# Epoch 198/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0417 - accuracy: 0.9939 - val_loss: 0.0805 - val_accuracy: 0.9786 - lr: 1.0000e-05
# Epoch 199/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0429 - accuracy: 0.9943 - val_loss: 0.0799 - val_accuracy: 0.9797 - lr: 1.0000e-05
# Epoch 200/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0418 - accuracy: 0.9939 - val_loss: 0.0790 - val_accuracy: 0.9796 - lr: 1.0000e-05
# Epoch 201/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0419 - accuracy: 0.9941 - val_loss: 0.0787 - val_accuracy: 0.9791 - lr: 1.0000e-05
# Epoch 202/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0421 - accuracy: 0.9940 - val_loss: 0.0777 - val_accuracy: 0.9799 - lr: 1.0000e-05
# Epoch 203/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0413 - accuracy: 0.9939 - val_loss: 0.0780 - val_accuracy: 0.9798 - lr: 1.0000e-05
# Epoch 204/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0421 - accuracy: 0.9939 - val_loss: 0.0785 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 205/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0413 - accuracy: 0.9943 - val_loss: 0.0772 - val_accuracy: 0.9814 - lr: 1.0000e-05
# Epoch 206/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0408 - accuracy: 0.9941 - val_loss: 0.0767 - val_accuracy: 0.9808 - lr: 1.0000e-05
# Epoch 207/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0409 - accuracy: 0.9943 - val_loss: 0.0772 - val_accuracy: 0.9792 - lr: 1.0000e-05
# Epoch 208/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0410 - accuracy: 0.9941 - val_loss: 0.0780 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 209/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0408 - accuracy: 0.9944 - val_loss: 0.0759 - val_accuracy: 0.9818 - lr: 1.0000e-05
# Epoch 210/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0408 - accuracy: 0.9941 - val_loss: 0.0794 - val_accuracy: 0.9798 - lr: 1.0000e-05
# Epoch 211/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0403 - accuracy: 0.9941 - val_loss: 0.0780 - val_accuracy: 0.9802 - lr: 1.0000e-05
# Epoch 212/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0398 - accuracy: 0.9943 - val_loss: 0.0800 - val_accuracy: 0.9791 - lr: 1.0000e-05
# Epoch 213/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0404 - accuracy: 0.9945 - val_loss: 0.0761 - val_accuracy: 0.9804 - lr: 1.0000e-05
# Epoch 214/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0402 - accuracy: 0.9946 - val_loss: 0.0796 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 215/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0398 - accuracy: 0.9944 - val_loss: 0.0758 - val_accuracy: 0.9803 - lr: 1.0000e-05
# Epoch 216/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0394 - accuracy: 0.9942 - val_loss: 0.0767 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 217/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0394 - accuracy: 0.9949 - val_loss: 0.0792 - val_accuracy: 0.9792 - lr: 1.0000e-05
# Epoch 218/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0386 - accuracy: 0.9947 - val_loss: 0.0785 - val_accuracy: 0.9787 - lr: 1.0000e-05
# Epoch 219/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0386 - accuracy: 0.9948 - val_loss: 0.0758 - val_accuracy: 0.9813 - lr: 1.0000e-05
# Epoch 220/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0389 - accuracy: 0.9947 - val_loss: 0.0742 - val_accuracy: 0.9818 - lr: 1.0000e-05
# Epoch 221/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0382 - accuracy: 0.9949 - val_loss: 0.0774 - val_accuracy: 0.9805 - lr: 1.0000e-05
# Epoch 222/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0381 - accuracy: 0.9952 - val_loss: 0.0770 - val_accuracy: 0.9796 - lr: 1.0000e-05
# Epoch 223/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0383 - accuracy: 0.9950 - val_loss: 0.0776 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 224/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0378 - accuracy: 0.9954 - val_loss: 0.0750 - val_accuracy: 0.9803 - lr: 1.0000e-05
# Epoch 225/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0373 - accuracy: 0.9950 - val_loss: 0.0755 - val_accuracy: 0.9809 - lr: 1.0000e-05
# Epoch 226/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0384 - accuracy: 0.9951 - val_loss: 0.0758 - val_accuracy: 0.9784 - lr: 1.0000e-05
# Epoch 227/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0369 - accuracy: 0.9955 - val_loss: 0.0738 - val_accuracy: 0.9807 - lr: 1.0000e-05
# Epoch 228/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0374 - accuracy: 0.9950 - val_loss: 0.0729 - val_accuracy: 0.9819 - lr: 1.0000e-05
# Epoch 229/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0375 - accuracy: 0.9949 - val_loss: 0.0809 - val_accuracy: 0.9781 - lr: 1.0000e-05
# Epoch 230/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0367 - accuracy: 0.9950 - val_loss: 0.0724 - val_accuracy: 0.9818 - lr: 1.0000e-05
# Epoch 231/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0368 - accuracy: 0.9956 - val_loss: 0.0768 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 232/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0363 - accuracy: 0.9955 - val_loss: 0.0737 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 233/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0361 - accuracy: 0.9951 - val_loss: 0.0724 - val_accuracy: 0.9825 - lr: 1.0000e-05
# Epoch 234/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0362 - accuracy: 0.9954 - val_loss: 0.0723 - val_accuracy: 0.9815 - lr: 1.0000e-05
# Epoch 235/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0366 - accuracy: 0.9953 - val_loss: 0.0728 - val_accuracy: 0.9813 - lr: 1.0000e-05
# Epoch 236/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0363 - accuracy: 0.9957 - val_loss: 0.0720 - val_accuracy: 0.9811 - lr: 1.0000e-05
# Epoch 237/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0358 - accuracy: 0.9954 - val_loss: 0.0755 - val_accuracy: 0.9796 - lr: 1.0000e-05
# Epoch 238/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0359 - accuracy: 0.9957 - val_loss: 0.0722 - val_accuracy: 0.9816 - lr: 1.0000e-05
# Epoch 239/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0358 - accuracy: 0.9956 - val_loss: 0.0737 - val_accuracy: 0.9812 - lr: 1.0000e-05
# Epoch 240/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0350 - accuracy: 0.9958 - val_loss: 0.0728 - val_accuracy: 0.9811 - lr: 1.0000e-05
# Epoch 241/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0353 - accuracy: 0.9957 - val_loss: 0.0724 - val_accuracy: 0.9810 - lr: 1.0000e-05
# Epoch 242/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0349 - accuracy: 0.9955 - val_loss: 0.0739 - val_accuracy: 0.9813 - lr: 1.0000e-05
# Epoch 243/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0347 - accuracy: 0.9956 - val_loss: 0.0718 - val_accuracy: 0.9828 - lr: 1.0000e-05
# Epoch 244/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0345 - accuracy: 0.9959 - val_loss: 0.0729 - val_accuracy: 0.9809 - lr: 1.0000e-05
# Epoch 245/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0349 - accuracy: 0.9953 - val_loss: 0.0726 - val_accuracy: 0.9818 - lr: 1.0000e-05
# Epoch 246/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0343 - accuracy: 0.9963 - val_loss: 0.0733 - val_accuracy: 0.9810 - lr: 1.0000e-05
# Epoch 247/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0343 - accuracy: 0.9956 - val_loss: 0.0721 - val_accuracy: 0.9817 - lr: 1.0000e-05
# Epoch 248/250
# 276/276 [==============================] - 10s 34ms/step - loss: 0.0341 - accuracy: 0.9961 - val_loss: 0.0736 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 249/250
# 276/276 [==============================] - 10s 35ms/step - loss: 0.0337 - accuracy: 0.9960 - val_loss: 0.0721 - val_accuracy: 0.9818 - lr: 1.0000e-05
# Epoch 250/250
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0341 - accuracy: 0.9961 - val_loss: 0.0711 - val_accuracy: 0.9821 - lr: 1.0000e-05

# %%
import matplotlib.pyplot as plt

def plot_accuracy_and_loss(history):
    # Get training and testing accuracy and loss histories
    training_accuracy = history.history['accuracy']
    testing_accuracy = history.history['val_accuracy']
    training_loss = history.history['loss']
    testing_loss = history.history['val_loss']

    # Plot training and testing accuracy curves
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(training_accuracy, label='Training Accuracy')
    plt.plot(testing_accuracy, label='Testing Accuracy')
    plt.title('Training vs Testing Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()

    # Plot training and testing loss curves
    plt.subplot(1, 2, 2)
    plt.plot(training_loss, label='Training Loss')
    plt.plot(testing_loss, label='Testing Loss')
    plt.title('Training vs Testing Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_accuracy_and_loss(history)

# %%
# import tensorflow as tf
# model.save_weights('weights\DCNN.h5')

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 2023-12-24 13:24:26.885054: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 662342016 exceeds 10% of free system memory.
# 2023-12-24 13:24:27.376654: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 662342016 exceeds 10% of free system memory.
# 1101/1101 [==============================] - 9s 9ms/step - loss: 0.0274 - accuracy: 0.9970
# 367/367 [==============================] - 3s 9ms/step - loss: 0.0711 - accuracy: 0.9821
# Train Loss:  0.027390873059630394
# Train Accuracy:  0.9969603419303894
# --------------------
# Test Loss:  0.07107620686292648
# Test Accuracy:  0.9821032881736755

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 3s 7ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, auc, recall_score, precision_score, f1_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import label_binarize

def plot_curves(y_true, y_scores):
    num_classes = y_scores.shape[1]
    
    # Binarize the labels
    y_true_bin = label_binarize(y_true, classes=np.arange(num_classes))
    
    # Initialize figure
    plt.figure(figsize=(30, 30))
    
    # Plot ROC curve for each class
    plt.subplot(3, 3, 1)
    avg_auc = 0
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        avg_auc += roc_auc
        plt.plot(fpr, tpr, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
    avg_auc /= num_classes
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curves (Multi-class, Average AUC = {avg_auc:.2f})')
    plt.legend(loc="lower right")
    
    # Plot Recall curve for each class
    plt.subplot(3, 3, 2)
    avg_recall = 0
    recall_values_avg = []
    for i in range(num_classes):
        recall_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_recall += np.mean(recall_values)
        recall_values_avg.append(recall_values)
        plt.plot(np.linspace(0, 1, 100), recall_values, label=f'Class {i}')
    avg_recall /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(recall_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('Recall')
    plt.title(f'Recall Curves (Multi-class, Average Recall = {avg_recall:.2f})')
    plt.legend(loc="lower right")

    # Plot Precision curve for each class
    plt.subplot(3, 3, 3)
    avg_precision = 0
    precision_values_avg = []
    for i in range(num_classes):
        precision_values = [precision_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_precision += np.mean(precision_values)
        precision_values_avg.append(precision_values)
        plt.plot(np.linspace(0, 1, 100), precision_values, label=f'Class {i}')
    avg_precision /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(precision_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('Precision')
    plt.title(f'Precision Curves (Multi-class, Average Precision = {avg_precision:.2f})')
    plt.legend(loc="lower right")

    # Plot Sensitivity curve for each class
    plt.subplot(3, 3, 4)
    avg_sensitivity = 0
    sensitivity_values_avg = []
    for i in range(num_classes):
        sensitivity_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_sensitivity += np.mean(sensitivity_values)
        sensitivity_values_avg.append(sensitivity_values)
        plt.plot(np.linspace(0, 1, 100), sensitivity_values, label=f'Class {i}')
    avg_sensitivity /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(sensitivity_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('Sensitivity')
    plt.title(f'Sensitivity Curves (Multi-class, Average Sensitivity = {avg_sensitivity:.2f})')
    plt.legend(loc="lower right")

    # Plot Specificity curve for each class
    plt.subplot(3, 3, 5)
    avg_specificity = 0
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        tnr = 1 - fpr
        avg_specificity += np.mean(tnr)
        plt.plot(tnr, tpr, label=f'Class {i}')
    avg_specificity /= num_classes
    plt.xlabel('Specificity (True Negative Rate)')
    plt.ylabel('Sensitivity (True Positive Rate)')
    plt.title(f'Specificity Curves (Multi-class, Average Specificity = {avg_specificity:.2f})')
    plt.legend(loc='lower right')

    # Plot F1 Score curve for each class
    plt.subplot(3, 3, 6)
    avg_f1 = 0
    f1_values_avg = []
    for i in range(num_classes):
        f1_values = [f1_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        avg_f1 += np.mean(f1_values)
        f1_values_avg.append(f1_values)
        plt.plot(np.linspace(0, 1, 100), f1_values, label=f'Class {i}')
    avg_f1 /= num_classes
    plt.plot(np.linspace(0, 1, 100), np.mean(f1_values_avg, axis=0), label='Average', linestyle='--')
    plt.xlabel('Threshold')
    plt.ylabel('F1 Score')
    plt.title(f'F1 Score Curves (Multi-class, Average F1 Score = {avg_f1:.2f})')
    plt.legend(loc="lower right")

    # Plot Precision-Recall curve for each class
    plt.subplot(3, 3, 7)
    avg_precision_recall = 0
    for i in range(num_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_scores[:, i])
        avg_precision_recall += auc(recall, precision)
        plt.plot(recall, precision, lw=2, label=f'Class {i}')
    avg_precision_recall /= num_classes
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curves (Multi-class, Average AUC = {avg_precision_recall:.2f})')
    plt.legend(loc="lower right")

    plt.tight_layout()
    plt.show()

y_pred_probs = model.predict(X_test)
# Assuming y_pred_probs contains probabilities for each class
plot_curves(y_true, y_pred_probs)
# Out:
# 367/367 [==============================] - 2s 6ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, auc, recall_score, precision_score, f1_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import label_binarize

def plot_curves2(y_true, y_scores):
    num_classes = y_scores.shape[1]
    
    # Binarize the labels
    y_true_bin = label_binarize(y_true, classes=np.arange(num_classes))
    
    # Initialize figure
    plt.figure(figsize=(30, 30))
    
    # Lists to store mean values
    mean_fpr, mean_tpr = np.linspace(0, 1, 100), np.linspace(0, 1, 100)
    mean_recall, mean_precision = np.linspace(0, 1, 100), np.linspace(0, 1, 100)
    mean_sensitivity, mean_f1 = np.linspace(0, 1, 100), np.linspace(0, 1, 100)
    
    # Plot ROC curve for each class
    plt.subplot(3, 3, 1)
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
        mean_tpr += np.interp(mean_fpr, fpr, tpr)
    mean_tpr /= num_classes
    mean_auc = auc(mean_fpr, mean_tpr)
    plt.plot(mean_fpr, mean_tpr, color='black', linestyle='--', lw=2, label=f'Mean ROC (AUC = {mean_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves (Multi-class)')
    plt.legend(loc="lower right")
    
    # Plot Recall curve for each class
    plt.subplot(3, 3, 2)
    for i in range(num_classes):
        recall_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), recall_values, label=f'Class {i}')
        mean_recall += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), recall_values)
    mean_recall /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_recall, color='black', linestyle='--', lw=2, label='Mean Recall')
    plt.xlabel('Threshold')
    plt.ylabel('Recall')
    plt.title('Recall Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Precision curve for each class
    plt.subplot(3, 3, 3)
    for i in range(num_classes):
        precision_values = [precision_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), precision_values, label=f'Class {i}')
        mean_precision += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), precision_values)
    mean_precision /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_precision, color='black', linestyle='--', lw=2, label='Mean Precision')
    plt.xlabel('Threshold')
    plt.ylabel('Precision')
    plt.title('Precision Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Sensitivity curve for each class
    plt.subplot(3, 3, 4)
    for i in range(num_classes):
        sensitivity_values = [recall_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), sensitivity_values, label=f'Class {i}')
        mean_sensitivity += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), sensitivity_values)
    mean_sensitivity /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_sensitivity, color='black', linestyle='--', lw=2, label='Mean Sensitivity')
    plt.xlabel('Threshold')
    plt.ylabel('Sensitivity')
    plt.title('Sensitivity Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Specificity curve for each class
    plt.subplot(3, 3, 5)
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        tnr = 1 - fpr
        plt.plot(tnr, tpr, label=f'Class {i}')
    plt.xlabel('Specificity (True Negative Rate)')
    plt.ylabel('Sensitivity (True Positive Rate)')
    plt.title('Specificity Curves (Multi-class)')
    plt.legend(loc='lower right')

    # Plot F1 Score curve for each class
    plt.subplot(3, 3, 6)
    for i in range(num_classes):
        f1_values = [f1_score(y_true_bin[:, i], (y_scores[:, i] >= threshold).astype(int)) for threshold in np.linspace(0, 1, 100)]
        plt.plot(np.linspace(0, 1, 100), f1_values, label=f'Class {i}')
        mean_f1 += np.interp(np.linspace(0, 1, 100), np.linspace(0, 1, 100), f1_values)
    mean_f1 /= num_classes
    plt.plot(np.linspace(0, 1, 100), mean_f1, color='black', linestyle='--', lw=2, label='Mean F1 Score')
    plt.xlabel('Threshold')
    plt.ylabel('F1 Score')
    plt.title('F1 Score Curves (Multi-class)')
    plt.legend(loc="lower right")

    # Plot Precision-Recall curve for each class
    plt.subplot(3, 3, 7)
    for i in range(num_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_scores[:, i])
        plt.plot(recall, precision, lw=2, label=f'Class {i}')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curves (Multi-class)')
    plt.legend(loc="lower right")

    plt.tight_layout()
    plt.show()

# Assuming y_pred

plot_curves2(y_true, y_pred_probs)

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %%
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#model.save('Skin Cancer.h5')

# %%
# from keras import backend as K
# import gc

# del model

# K.clear_session()
# gc.collect()
# Out:
# 40596

# %%
# #You need to install numba using 'pip install numba'

# from numba import cuda

# cuda.select_device(0)
# cuda.close()

# %%
# import tensorflow as tf
# model.save_weights('model_weights/InceptionResNet.h5')
